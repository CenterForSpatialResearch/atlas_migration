# %%
import requests
import csv
from io import open as iopen

# %%
# defining a function, it takes four parameters:
# the path to a csv file containing lat/lon coordinates
# your API key
# the zoom level you would your images to be downloaded as
# the size, in pixels of your images, the maximum is 640

def satellite_squares(csvforimport,APIkey,zoom,size):
    API_KEY = APIkey
    base = "https://maps.googleapis.com/maps/api/staticmap?scale=2&size="
    locations = []
    # this section reads the csv file
    with open(csvforimport, 'rt') as f:
        reader = csv.reader(f)
        for row in reader:
            ind, lat, lng = str(row[0]),float(row[1]),float(row[2])
            location = (ind, lat, lng)
            locations.append(location)
    # here we format a url to pass to the API for each row in the csv file
    for location in locations:
        ind, lat, lng = location
        latlng = "center={},{}".format(lat, lng)
        view = "zoom={}&maptype=satellite".format(zoom)
        keys = "key={}".format(API_KEY)
        url = "{}{}x{}&{}&{}&{}".format(base,size,size, latlng, view, keys)
        # defining the name for the image files that will be downloaded
        filename = "{}_{}.png".format(ind,zoom)
        res = requests.get(url)
        if res.status_code == requests.codes.ok:  
            with iopen(filename, 'wb') as file:
                file.write(res.content)
            print(filename)
        #here we tell the function to show us an error message if it is unable to download an image
        else:
            print(res.status_code)
            print(url)
            return False

# %%
result = satellite_squares("../python-data-sorting/index.csv","AIzaSyD6-CJ9pIY0-UzN6wjMCRDLxpfqLWk8cFk",13,640)
# Out:
# 1_13.png
# 2_13.png
# 3_13.png
# 4_13.png
# 5_13.png
# 6_13.png
# 7_13.png
# 8_13.png
# 9_13.png
# 10_13.png
# 11_13.png
# 12_13.png
# 13_13.png
# 14_13.png
# 15_13.png
# 16_13.png
# 17_13.png
# 18_13.png
# 19_13.png
# 20_13.png
# 21_13.png
# 22_13.png
# 23_13.png
# 24_13.png
# 25_13.png
# 26_13.png
# 27_13.png
# 28_13.png
# 29_13.png
# 30_13.png
# 31_13.png
# 32_13.png
# 33_13.png
# 34_13.png
# 35_13.png
# 36_13.png
# 37_13.png
# 38_13.png
# 39_13.png
# 40_13.png
# 41_13.png
# 42_13.png
# 43_13.png
# 44_13.png
# 45_13.png
# 46_13.png
# 47_13.png
# 48_13.png
# 49_13.png
# 50_13.png
# 51_13.png
# 52_13.png
# 53_13.png
# 54_13.png
# 55_13.png
# 56_13.png
# 57_13.png
# 58_13.png
# 59_13.png
# 60_13.png
# 61_13.png
# 62_13.png
# 63_13.png
# 64_13.png
# 65_13.png
# 66_13.png
# 67_13.png
# 68_13.png
# 69_13.png
# 70_13.png
# 71_13.png
# 72_13.png
# 73_13.png
# 74_13.png
# 75_13.png
# 76_13.png
# 77_13.png
# 78_13.png
# 79_13.png
# 80_13.png
# 81_13.png
# 82_13.png
# 83_13.png
# 84_13.png
# 85_13.png
# 86_13.png
# 87_13.png
# 88_13.png
# 89_13.png
# 90_13.png
# 91_13.png
# 92_13.png
# 93_13.png
# 94_13.png
# 95_13.png
# 96_13.png
# 97_13.png
# 98_13.png
# 99_13.png
# 100_13.png
# 101_13.png
# 102_13.png
# 103_13.png
# 104_13.png
# 105_13.png
# 106_13.png
# 107_13.png
# 108_13.png
# 109_13.png
# 110_13.png
# 111_13.png
# 112_13.png
# 113_13.png
# 114_13.png
# 115_13.png
# 116_13.png
# 117_13.png
# 118_13.png
# 119_13.png
# 120_13.png
# 121_13.png
# 122_13.png
# 123_13.png
# 124_13.png
# 125_13.png
# 126_13.png
# 127_13.png
# 128_13.png
# 129_13.png
# 130_13.png
# 131_13.png
# 132_13.png
# 133_13.png
# 134_13.png

# %%
# Format the name of the files
import os
import pandas as pd

# %%
# Load the CSV file
csv_file = '../python-data-sorting/index_location.csv'
data = pd.read_csv(csv_file)

# %%
# Specify the folder containing the PNG files to be renamed
folder_path = '../python-data-sorting/image'

# %%
# Iterate through each row in the CSV file
for index, row in data.iterrows():
    # Extract the ID and location from the row
    file_id = str(row['ID'])
    location_name = row['location']  # Keep the original format with commas and spaces
    
    # Search for the matching PNG file in the folder
    for filename in os.listdir(folder_path):
        if filename.startswith(file_id + '_') and filename.endswith('.png'):
            # Create a new file name using the location name
            new_filename = f"{location_name}.png"
            
            # Rename the file
            old_file_path = os.path.join(folder_path, filename)
            new_file_path = os.path.join(folder_path, new_filename)
            
            os.rename(old_file_path, new_file_path)
            print(f"Renamed {filename} to {new_filename}")
            break
# Out:
# Renamed 1_13.png to Tumu, Wa, Ghana.png
# Renamed 2_13.png to Aboabo, Aboabo, Ghana.png
# Renamed 3_13.png to Saltpond, Cape Coast, Ghana.png
# Renamed 4_13.png to Orlu, Orlu, Nigeria.png
# Renamed 5_13.png to Diffa, Diffa, Niger.png
# Renamed 6_13.png to Miri, Bauchi, Nigeria.png
# Renamed 7_13.png to Aflao, Aflao, Ghana.png
# Renamed 8_13.png to Niame, Niamey, Niger.png
# Renamed 9_13.png to Techaoudjo, Sokode, Togo.png
# Renamed 10_13.png to Kpalime, Kpalime, Togo.png
# Renamed 11_13.png to Abomey, Abomey, Benin.png
# Renamed 12_13.png to Agbara, Agbara, Nigeria.png
# Renamed 13_13.png to Obo Kwahu, Obo, Ghana.png
# Renamed 14_13.png to Abakalliki, Abakaliki, Nigeria.png
# Renamed 15_13.png to Agbani, Agbani, Nigeria.png
# Renamed 16_13.png to Maradi, Maradi, Niger.png
# Renamed 17_13.png to Ojo, Ilesa, Nigeria.png
# Renamed 18_13.png to Allada, Allada, Benin.png
# Renamed 19_13.png to Epe, Epe, Nigeria.png
# Renamed 20_13.png to Aflao, Aflao, Togo.png
# Renamed 21_13.png to Makueni, Wote, Kenya.png
# Renamed 22_13.png to nan, Goria, Uganda.png
# Renamed 23_13.png to nan, Kibaya, Rwanda.png
# Renamed 24_13.png to nan, Sagana, Kenya.png
# Renamed 25_13.png to nan, Gucha, Kenya.png
# Renamed 26_13.png to nan, Siaya Town, Kenya.png
# Renamed 27_13.png to nan, Sabatia, Kenya.png
# Renamed 28_13.png to nan, Ogembo, Kenya.png
# Renamed 29_13.png to nan, Voi, Kenya.png
# Renamed 30_13.png to nan, Mbaale, Uganda.png
# Renamed 31_13.png to nan, Machakos, Kenya.png
# Renamed 32_13.png to nan, Busia, Kenya.png
# Renamed 33_13.png to nan, Kiambu, Kenya.png
# Renamed 34_13.png to nan, Malaba, Kenya.png
# Renamed 35_13.png to nan, Gisambai, Kenya.png
# Renamed 36_13.png to nan, Naivasha, Kenya.png
# Renamed 37_13.png to nan, Makindu, Kenya.png
# Renamed 38_13.png to nan, Bondo, Kenya.png
# Renamed 39_13.png to nan, Bulambuli, Uganda.png
# Renamed 40_13.png to nan, Ugunja, Kenya.png
# Renamed 41_13.png to nan, Gombe, Uganda.png
# Renamed 42_13.png to nan, Kangema, Kenya.png
# Renamed 43_13.png to nan, Mwingi, Kenya.png
# Renamed 44_13.png to nan, Lwanda, Kenya.png
# Renamed 45_13.png to nan, Githunguri, Kenya.png
# Renamed 46_13.png to nan, Kattio, Kenya.png
# Renamed 47_13.png to nan, Bumala, Kenya.png
# Renamed 48_13.png to nan, Nyamira, Kenya.png
# Renamed 49_13.png to nan, Funyula, Kenya.png
# Renamed 50_13.png to nan, Kakamega, Kenya.png
# Renamed 51_13.png to nan, Sondu, Kenya.png
# Renamed 52_13.png to Ngaramtoni, Tanzania.png
# Renamed 53_13.png to nan, Awendo, Kenya.png
# Renamed 54_13.png to nan, Kisii, Kenya.png
# Renamed 55_13.png to nan, Kisumu, Kenya.png
# Renamed 56_13.png to nan, Rabuor, Kenya.png
# Renamed 57_13.png to Baraka, Democratic Republic of the Congo.png
# Renamed 58_13.png to nan, Meru, Kenya.png
# Renamed 59_13.png to nan, Kimilili, Kenya.png
# Renamed 60_13.png to Migori Town, Kenya.png
# Renamed 61_13.png to nan, Maua, Kenya.png
# Renamed 62_13.png to nan, Karatina, Kenya.png
# Renamed 63_13.png to nan, Vihiga, Kenya.png
# Renamed 64_13.png to nan, Mumias, Kenya.png
# Renamed 65_13.png to nan, Thika, Kenya.png
# Renamed 66_13.png to Bukavu, Democratic Republic of the Congo.png
# Renamed 67_13.png to nan, Bushika, Uganda.png
# Renamed 68_13.png to nan, Eldoret, Kenya.png
# Renamed 69_13.png to Moyale, Ethiopia.png
# Renamed 70_13.png to nan, Mombasa, Kenya.png
# Renamed 71_13.png to nan, Webuye, Kenya.png
# Renamed 72_13.png to Meru Town, Kenya.png
# Renamed 73_13.png to nan, Nyeri, Kenya.png
# Renamed 74_13.png to Kinshasa, Democratic Republic of the Congo.png
# Renamed 75_13.png to Gaza, Gaza, Mozambique.png
# Renamed 76_13.png to Blk, Block, Malawi.png
# Renamed 77_13.png to Bilene, Mozambique.png
# Renamed 78_13.png to Macia, Mozambique.png
# Renamed 79_13.png to Madibong, South Africa.png
# Renamed 80_13.png to Lusikisiki, South Africa.png
# Renamed 81_13.png to Malamulele, South Africa.png
# Renamed 82_13.png to Elim, South Africa.png
# Renamed 83_13.png to Mondlo, South Africa.png
# Renamed 84_13.png to Chingola, Zambia.png
# Renamed 85_13.png to Fort Beaufort, South Africa.png
# Renamed 86_13.png to Lira City, Uganda.png
# Renamed 87_13.png to Matatiele, South Africa.png
# Renamed 88_13.png to Embangweni, Malawi.png
# Renamed 89_13.png to Bushbuckridge, South Africa.png
# Renamed 90_13.png to Vryheid, South Africa.png
# Renamed 91_13.png to Morogoro, Tanzania.png
# Renamed 92_13.png to Bangou, Cameroon.png
# Renamed 93_13.png to Leribe, Lesotho.png
# Renamed 94_13.png to Amsterdam, South Africa.png
# Renamed 95_13.png to Thohoyandou, South Africa.png
# Renamed 96_13.png to Rustenburg, South Africa.png
# Renamed 97_13.png to Matadi, Democratic Republic of the Congo.png
# Renamed 98_13.png to Mannies, Welkom, South Africa.png
# Renamed 99_13.png to Hloste, Lesotho.png
# Renamed 100_13.png to Tlakgameng, South Africa.png
# Renamed 101_13.png to Nkandla, South Africa.png
# Renamed 102_13.png to Xai-Xai, Mozambique.png
# Renamed 103_13.png to Beira, Mozambique.png
# Renamed 104_13.png to Mafeteng, Lesotho.png
# Renamed 105_13.png to Maddadeni, Emadadeni, South Africa.png
# Renamed 106_13.png to Makhado, South Africa.png
# Renamed 107_13.png to Kwamhlanga, South Africa.png
# Renamed 108_13.png to Bulawayo, Zimbabwe.png
# Renamed 109_13.png to Maseru, Lesotho.png
# Renamed 110_13.png to Mafikeng, South Africa.png
# Renamed 111_13.png to Nqutu, South Africa.png
# Renamed 112_13.png to Pietersburg, South Africa.png
# Renamed 113_13.png to KwaMashu, South Africa.png
# Renamed 114_13.png to Krugersdorp, South Africa.png
# Renamed 115_13.png to Dundee, South Africa.png
# Renamed 116_13.png to Queenstown, South Africa.png
# Renamed 117_13.png to Dutywa, South Africa.png
# Renamed 118_13.png to Lethabong, South Africa.png
# Renamed 119_13.png to Mkhuhlu, South Africa.png
# Renamed 120_13.png to Muzuzu, Malawi.png
# Renamed 121_13.png to Ermelo, South Africa.png
# Renamed 122_13.png to Dikeni, South Africa.png
# Renamed 123_13.png to Maputo, Mozambique.png
# Renamed 124_13.png to Greytown, South Africa.png
# Renamed 125_13.png to Thulamahashe, South Africa.png
# Renamed 126_13.png to Nelspruit, South Africa.png
# Renamed 127_13.png to Pietermaritzburg, South Africa.png
# Renamed 128_13.png to Giyani, South Africa.png
# Renamed 129_13.png to Natalspruit, South Africa.png
# Renamed 130_13.png to nan, Orsumoghu, Nigeria.png
# Renamed 131_13.png to nan, Nsukka, Nigeria.png
# Renamed 132_13.png to Polokwane, South Africa.png
# Renamed 133_13.png to Bloemfontein, South Africa.png
# Renamed 134_13.png to Lahore, Ethiopia.png
