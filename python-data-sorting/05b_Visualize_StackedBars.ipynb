# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#I.-Data" data-toc-modified-id="I.-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>I. Data</a></span></li><li><span><a href="#II.-Test" data-toc-modified-id="II.-Test-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>II. Test</a></span></li><li><span><a href="#III.-Variables" data-toc-modified-id="III.-Variables-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>III. Variables</a></span><ul class="toc-item"><li><span><a href="#156-Change-in-lifestyle" data-toc-modified-id="156-Change-in-lifestyle-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>156 Change in lifestyle</a></span></li><li><span><a href="#100-Village,-City,-or-Town" data-toc-modified-id="100-Village,-City,-or-Town-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>100 Village, City, or Town</a></span></li><li><span><a href="#203.-Reason-for-Location" data-toc-modified-id="203.-Reason-for-Location-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>203. Reason for Location</a></span></li><li><span><a href="#303.-Current-Employment-Status" data-toc-modified-id="303.-Current-Employment-Status-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>303. Current Employment Status</a></span></li><li><span><a href="#310-Send-Money" data-toc-modified-id="310-Send-Money-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>310 Send Money</a></span></li><li><span><a href="#334-Optimism" data-toc-modified-id="334-Optimism-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>334 Optimism</a></span></li><li><span><a href="#700-Stay-or-go" data-toc-modified-id="700-Stay-or-go-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>700 Stay or go</a></span></li><li><span><a href="#226-COVID-Impact-on-Mobility" data-toc-modified-id="226-COVID-Impact-on-Mobility-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>226 COVID Impact on Mobility</a></span></li></ul></li></ul></div>

# %% [markdown]
# *Last Updated: 2023.09.25, Will Cao (wpc2106@columbia.edu)*
#
# **Notes:** \
# These were quick, non-presentation visualization to identify general trends. \
# Conclusions were outlined in the document on GDrive:
#
# **Used in:**
# * [**04_analysis > 230912_brainstorm_sketch_meeting > 230912_charts**](https://docs.google.com/document/d/1ab9bcfrNpGMqzBnjeG0QZHGfXWQ2h8NnbVS4ik9dbmo/edit?usp=sharing)

# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# import seaborn as sns
import matplotlib.pyplot as plt
# import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. Data

# %%
# original survey data
survey_ = pd.read_csv('data_raw/raw_survey/210615_raw_survey.csv')
survey = survey_.copy()

# check for any potential row-wise errors
print('\nDuplicate rows?:')
print(survey.duplicated().value_counts())

print('\nUnique SITE_CODE column?:')
print(survey['SITE_CODE'].is_unique)

# duplicate the respondent ID column and set it as the index
survey['ID'] = survey['SITE_CODE']
survey = survey.set_index('ID')

# check if the uniqueness was maintained
print('\nUnique ID index?:')
print(survey.index.is_unique)

survey
# Out:
# Duplicate rows?:
# False    1644
# Name: count, dtype: int64
#
# Unique SITE_CODE column?:
# True
#
# Unique ID index?:
# True
#         SITE_CODE  TARGET_LATITUDE  TARGET_LONGITUDE  SITE_LATITUDE  \
# ID
# 276785     276785         -1.21003          36.78920       -1.28892
# 276788     276788         -1.21010          36.78923       -1.28872
# 276802     276802         -1.21010          36.78923       -1.28884
# 276814     276814         -1.20987          36.78899       -1.28885
# 276822     276822         -1.20976          36.78888       -1.28873
# ...           ...              ...               ...            ...
# 297661     297661        -26.18491          28.05547      -26.18380
# 297663     297663        -26.18395          28.05459      -26.18328
# 297666     297666        -26.18565          28.05295      -26.18387
# 297667     297667        -26.18630          28.05320      -26.18374
# 297668     297668        -26.18634          28.05294      -26.18391
#
#         SITE_LONGITUDE  SURVEY DURATION IN MINUTES DATE_UPLOADED 3 Migrant  \
# ID
# 276785        36.80449                      139.96        3/4/21       Yes
# 276788        36.80430                       74.59        3/4/21       Yes
# 276802        36.80433                      244.90        3/5/21       Yes
# 276814        36.80435                      125.87        3/4/21       Yes
# 276822        36.80428                       80.18        3/4/21       Yes
# ...                ...                         ...           ...       ...
# 297661        28.05302                       62.78       4/16/21       Yes
# 297663        28.05690                       73.30       4/16/21        No
# 297666        28.05308                       72.04       4/16/21        No
# 297667        28.05300                       54.73       4/16/21        No
# 297668        28.05626                       63.45       4/16/21       Yes
#
#        4 Gender  4 Other Gender  ...                 236 Current Residence  \
# ID                               ...
# 276785     Male              -1  ...                     More than 2 years
# 276788     Male              -1  ...                                    -1
# 276802     Male              -1  ...  One year exactly or/More than a year
# 276814     Male              -1  ...                     More than 2 years
# 276822   Female              -1  ...  One year exactly or/More than a year
# ...         ...             ...  ...                                   ...
# 297661   Female              -1  ...                                    -1
# 297663     Male              -1  ...                     More than 2 years
# 297666     Male              -1  ...                     More than 2 years
# 297667     Male              -1  ...  One year exactly or/More than a year
# 297668   Female              -1  ...  One year exactly or/More than a year
#
#        Migrant Quota Category 237 Returned      238 Places Returned To   \
# ID
# 276785   Medium-Term Resident           No                           -1
# 276788                    NaN           -1                           -1
# 276802           New Resident           No                           -1
# 276814   Medium-Term Resident  Yes& I Have          Nakuru^1^~Kisumu^2^
# 276822           New Resident           No                           -1
# ...                       ...          ...                          ...
# 297661                    NaN           -1                           -1
# 297663   Medium-Term Resident           No                           -1
# 297666   Medium-Term Resident  Yes& I Have  Yeoville^4^~Bloemfontein^2^
# 297667           New Resident  Yes& I Have                  Sandton^10^
# 297668           New Resident  Yes& I Have               Khayelitsha^3^
#
#        Unnamed: 326 Unnamed: 327 Unnamed: 328  Unnamed: 329 Unnamed: 330  \
# ID
# 276785          NaN          NaN          NaN           NaN          NaN
# 276788          NaN          NaN          NaN           NaN          NaN
# 276802          NaN          NaN          NaN           NaN          NaN
# 276814          NaN          NaN          NaN           NaN          NaN
# 276822          NaN          NaN          NaN           NaN          NaN
# ...             ...          ...          ...           ...          ...
# 297661          NaN          NaN          NaN           NaN          NaN
# 297663          NaN          NaN          NaN           NaN          NaN
# 297666          NaN          NaN          NaN           NaN          NaN
# 297667          NaN          NaN          NaN           NaN          NaN
# 297668          NaN          NaN          NaN           NaN          NaN
#
#        Unnamed: 331
# ID
# 276785          NaN
# 276788          NaN
# 276802          NaN
# 276814          NaN
# 276822          NaN
# ...             ...
# 297661          NaN
# 297663          NaN
# 297666          NaN
# 297667          NaN
# 297668          NaN
#
# [1644 rows x 332 columns]

# %%
traj_ = pd.read_csv("C:/Users/willy/python/mobilities-narratives/data_gen/trajectories/trajectories.csv")
traj = traj_.copy()

traj = traj.set_index('Unnamed: 0')
# traj = traj.dropna(subset=['duration', 'interval', 'location_name'], how='all')
traj
# Out:
#             respondentID  birthyear  age  duration  interval  \
# Unnamed: 0
# 276785.00         276785       1996   25       0.0     204.0
# 276785.01         276785       1996   25     204.0      48.0
# 276785.02         276785       1996   25     252.0      51.0
# 276785.03         276785       1996   25       NaN       NaN
# 276785.04         276785       1996   25       NaN       NaN
# ...                  ...        ...  ...       ...       ...
# 297668.06         297668       1991   30     380.0      16.0
# 297668.07         297668       1991   30     386.0       6.0
# 297668.08         297668       1991   30     404.0      18.0
# 297668.09         297668       1991   30     500.0      96.0
# 297668.10         297668       1991   30     620.0     120.0
#
#                                         location_name  \
# Unnamed: 0
# 276785.00              ('Kawango', 'Kisumu', 'Kenya')
# 276785.01             ('Manyatta', 'Kisumu', 'Kenya')
# 276785.02          ('Kawangware', 'Nairobi', 'Kenya')
# 276785.03                                         NaN
# 276785.04                                         NaN
# ...                                               ...
# 297668.06   ('Berea', 'Johannesburg', 'South Africa')
# 297668.07                                         NaN
# 297668.08                                         NaN
# 297668.09                                         NaN
# 297668.10                                         NaN
#
#                       location_type                    location_latlon  \
# Unnamed: 0
# 276785.00                    origin          (0.0, 31.983333000000002)
# 276785.01    1st migration location  (0.33330859999999995, 34.4813935)
# 276785.02    2nd migration location   (-1.2784631000000002, 36.751643)
# 276785.03    3rd migration location                                NaN
# 276785.04    4th migration location                                NaN
# ...                             ...                                ...
# 297668.06          current location          (-26.1822222, 28.0533333)
# 297668.07     aspiration 2-6 months                                NaN
# 297668.08        planned move 2 yrs                                NaN
# 297668.09       planned move 10 yrs                                NaN
# 297668.10   planned move retirement                                NaN
#
#             distance_from_origin_location_km  \
# Unnamed: 0
# 276785.00                           0.000000
# 276785.01                         280.512936
# 276785.02                         549.265452
# 276785.03                                NaN
# 276785.04                                NaN
# ...                                      ...
# 297668.06                        1254.648626
# 297668.07                                NaN
# 297668.08                                NaN
# 297668.09                                NaN
# 297668.10                                NaN
#
#             distance_from_previous_location_km  ...  work_aspiration  \
# Unnamed: 0                                      ...
# 276785.00                             0.000000  ...               -3
# 276785.01                           280.512936  ...               -3
# 276785.02                           309.229771  ...               -3
# 276785.03                                  NaN  ...               -3
# 276785.04                                  NaN  ...               -3
# ...                                        ...  ...              ...
# 297668.06                             0.000000  ...    Hr Specialist
# 297668.07                                  NaN  ...    Hr Specialist
# 297668.08                                  NaN  ...    Hr Specialist
# 297668.09                                  NaN  ...    Hr Specialist
# 297668.10                                  NaN  ...    Hr Specialist
#
#            financial_support  children children_since_leaving     p_kmGeo  \
# Unnamed: 0
# 276785.00                NaN        No                     -1    0.000000
# 276785.01                NaN        No                     -1  280.512936
# 276785.02                NaN        No                     -1  309.229771
# 276785.03                NaN        No                     -1         NaN
# 276785.04                NaN        No                     -1         NaN
# ...                      ...       ...                    ...         ...
# 297668.06             2000.0       Yes                      0    0.000000
# 297668.07             2000.0       Yes                      0         NaN
# 297668.08             2000.0       Yes                      0         NaN
# 297668.09             2000.0       Yes                      0         NaN
# 297668.10             2000.0       Yes                      0         NaN
#
#                p_kmGrC      O_kmGeo      O_kmGrC        lat        lon
# Unnamed: 0
# 276785.00     0.000000     0.000000     0.000000   0.000000  31.983333
# 276785.01   280.232139   280.512936   280.232139   0.333309  34.481394
# 276785.02   309.576982   549.265452   548.896968  -1.278463  36.751643
# 276785.03          NaN          NaN          NaN        NaN        NaN
# 276785.04          NaN          NaN          NaN        NaN        NaN
# ...                ...          ...          ...        ...        ...
# 297668.06     0.000000  1254.648626  1255.233886 -26.182222  28.053333
# 297668.07          NaN          NaN          NaN        NaN        NaN
# 297668.08          NaN          NaN          NaN        NaN        NaN
# 297668.09          NaN          NaN          NaN        NaN        NaN
# 297668.10          NaN          NaN          NaN        NaN        NaN
#
# [11748 rows x 25 columns]

# %%
orig = traj[traj['location_type'].eq('origin')].reset_index().drop(columns=['Unnamed: 0']).set_index('respondentID')
display(orig)

curL = traj[traj['location_type'].eq('current location') & traj['interval'].eq(0.0)].reset_index().drop(columns=['Unnamed: 0']).set_index('respondentID')
display(curL)
# Out:
#               birthyear  age  duration  interval  \
# respondentID
# 276785             1996   25       0.0     204.0
# 276802             1994   27       0.0      56.0
# 276814             1988   33       0.0     300.0
# 276822             1995   26       0.0     246.0
# 276931             1988   33       0.0     301.0
# ...                 ...  ...       ...       ...
# 297657             1978   43       0.0     650.0
# 297663             1979   42       NaN       NaN
# 297666             1984   37       0.0     372.0
# 297667             2001   20       0.0     192.0
# 297668             1991   30       0.0     348.0
#
#                                                   location_name location_type  \
# respondentID
# 276785                           ('Kawango', 'Kisumu', 'Kenya')        origin
# 276802                        ('Machakos', 'Machakos', 'Kenya')        origin
# 276814                         ('Wathorego', 'Kisumu', 'Kenya')        origin
# 276822                           ('Kawango', 'Maseno', 'Kenya')        origin
# 276931                          ('Mamboleo', 'Kisumu', 'Kenya')        origin
# ...                                                         ...           ...
# 297657                       ('Chingola', 'Chingola', 'Zambia')        origin
# 297663                         ('Sesambo', 'Sesambo', 'Uganda')        origin
# 297666        ('Lububamshi', 'Katsanga', 'Democratic Republi...        origin
# 297667                           ('Lusaka', 'Lusaka', 'Zambia')        origin
# 297668             ('Khayelitsha', 'Cape Town', 'South Africa')        origin
#
#                                         location_latlon  \
# respondentID
# 276785                        (0.0, 31.983333000000002)
# 276802                 (-1.27900465, 37.39526976452546)
# 276814              (51.52066515, -0.14577657494447913)
# 276822                        (0.0, 31.983333000000002)
# 276931                 (-0.05541535, 34.78619684046177)
# ...                                                 ...
# 297657                (-12.5474926, 27.860042200000002)
# 297663                                              NaN
# 297666                          (-29.116395, 26.215496)
# 297667        (-15.416448800000001, 28.282153499999996)
# 297668                        (-34.0405905, 18.6674201)
#
#               distance_from_origin_location_km  \
# respondentID
# 276785                                     0.0
# 276802                                     0.0
# 276814                                     0.0
# 276822                                     0.0
# 276931                                     0.0
# ...                                        ...
# 297657                                     0.0
# 297663                                     NaN
# 297666                                     0.0
# 297667                                     0.0
# 297668                                     0.0
#
#               distance_from_previous_location_km  \
# respondentID
# 276785                                       0.0
# 276802                                       0.0
# 276814                                       0.0
# 276822                                       0.0
# 276931                                       0.0
# ...                                          ...
# 297657                                       0.0
# 297663                                       NaN
# 297666                                       0.0
# 297667                                       0.0
# 297668                                       0.0
#
#               distance_from_properties_owned_km  ...  \
# respondentID                                     ...
# 276785                                      NaN  ...
# 276802                                      NaN  ...
# 276814                                      NaN  ...
# 276822                                      NaN  ...
# 276931                                      NaN  ...
# ...                                         ...  ...
# 297657                                      NaN  ...
# 297663                                      NaN  ...
# 297666                                      NaN  ...
# 297667                                      NaN  ...
# 297668                                      NaN  ...
#
#                                                 work_aspiration  \
# respondentID
# 276785                                                       -3
# 276802                                               Accountant
# 276814                                                       -3
# 276822                                                 Teaching
# 276931                                                 Teaching
# ...                                                         ...
# 297657        He Said He Like Working With His Hands So He D...
# 297663                                                  Soldier
# 297666                                             Psychologist
# 297667                                                  Dentist
# 297668                                            Hr Specialist
#
#               financial_support children children_since_leaving p_kmGeo  \
# respondentID
# 276785                      NaN       No                     -1     0.0
# 276802                   3000.0       No                     -1     0.0
# 276814                      NaN      Yes                      1     0.0
# 276822                  10000.0       No                     -1     0.0
# 276931                    500.0      Yes                      2     0.0
# ...                         ...      ...                    ...     ...
# 297657                    500.0       No                     -1     0.0
# 297663                      NaN      Yes                      1     NaN
# 297666                   1500.0      Yes                      0     0.0
# 297667                      NaN       No                     -1     0.0
# 297668                   2000.0      Yes                      0     0.0
#
#               p_kmGrC O_kmGeo  O_kmGrC        lat        lon
# respondentID
# 276785            0.0     0.0      0.0   0.000000  31.983333
# 276802            0.0     0.0      0.0  -1.279005  37.395270
# 276814            0.0     0.0      0.0  51.520665  -0.145777
# 276822            0.0     0.0      0.0   0.000000  31.983333
# 276931            0.0     0.0      0.0  -0.055415  34.786197
# ...               ...     ...      ...        ...        ...
# 297657            0.0     0.0      0.0 -12.547493  27.860042
# 297663            NaN     NaN      NaN        NaN        NaN
# 297666            0.0     0.0      0.0 -29.116395  26.215496
# 297667            0.0     0.0      0.0 -15.416449  28.282153
# 297668            0.0     0.0      0.0 -34.040591  18.667420
#
# [1068 rows x 24 columns]
#               birthyear  age  duration  interval  \
# respondentID
# 276785             1996   25     303.0       0.0
# 276802             1994   27      64.0       0.0
# 276814             1988   33     319.0       0.0
# 276822             1995   26     249.0       0.0
# 276931             1988   33     301.0       0.0
# ...                 ...  ...       ...       ...
# 297657             1978   43    1034.0       0.0
# 297663             1979   42       0.0       0.0
# 297666             1984   37     404.0       0.0
# 297667             2001   20     240.0       0.0
# 297668             1991   30     364.0       0.0
#
#                                           location_name     location_type  \
# respondentID
# 276785               ('Kawangware', 'Nairobi', 'Kenya')  current location
# 276802               ('Kawangware', 'Nairobi', 'Kenya')  current location
# 276814                   ('Kayole', 'Nairobi', 'Kenya')  current location
# 276822                   ('Kayole', 'Nairobi', 'Kenya')  current location
# 276931               ('Kawangware', 'Nairobi', 'Kenya')  current location
# ...                                                 ...               ...
# 297657        ('Berea', 'Johannesburg', 'South Africa')  current location
# 297663        ('Berea', 'Johannesburg', 'South Africa')  current location
# 297666        ('Berea', 'Johannesburg', 'South Africa')  current location
# 297667        ('Berea', 'Johannesburg', 'South Africa')  current location
# 297668        ('Berea', 'Johannesburg', 'South Africa')  current location
#
#                                location_latlon  \
# respondentID
# 276785        (-1.2784631000000002, 36.751643)
# 276802        (-1.2784631000000002, 36.751643)
# 276814        (-1.2659842, 36.916945500000004)
# 276822        (-1.2659842, 36.916945500000004)
# 276931        (-1.2784631000000002, 36.751643)
# ...                                        ...
# 297657               (-26.1822222, 28.0533333)
# 297663               (-26.1822222, 28.0533333)
# 297666               (-26.1822222, 28.0533333)
# 297667               (-26.1822222, 28.0533333)
# 297668               (-26.1822222, 28.0533333)
#
#               distance_from_origin_location_km  \
# respondentID
# 276785                              549.265452
# 276802                               71.630505
# 276814                             6810.632065
# 276822                              566.723692
# 276931                              257.198700
# ...                                        ...
# 297657                             1509.508024
# 297663                                0.000000
# 297666                              372.285757
# 297667                             1192.189932
# 297668                             1254.648626
#
#               distance_from_previous_location_km  \
# respondentID
# 276785                                  0.000000
# 276802                                 24.717927
# 276814                                191.121340
# 276822                                190.235284
# 276931                                257.198700
# ...                                          ...
# 297657                                  0.000000
# 297663                                  0.000000
# 297666                                  0.000000
# 297667                                  0.000000
# 297668                                  0.000000
#
#               distance_from_properties_owned_km  ...  \
# respondentID                                     ...
# 276785                                      NaN  ...
# 276802                                      NaN  ...
# 276814                                      NaN  ...
# 276822                                      NaN  ...
# 276931                                      NaN  ...
# ...                                         ...  ...
# 297657                                      NaN  ...
# 297663                                      NaN  ...
# 297666                                      NaN  ...
# 297667                                      NaN  ...
# 297668                                      NaN  ...
#
#                                                 work_aspiration  \
# respondentID
# 276785                                                       -3
# 276802                                               Accountant
# 276814                                                       -3
# 276822                                                 Teaching
# 276931                                                 Teaching
# ...                                                         ...
# 297657        He Said He Like Working With His Hands So He D...
# 297663                                                  Soldier
# 297666                                             Psychologist
# 297667                                                  Dentist
# 297668                                            Hr Specialist
#
#               financial_support children children_since_leaving     p_kmGeo  \
# respondentID
# 276785                      NaN       No                     -1    0.000000
# 276802                   3000.0       No                     -1   24.717927
# 276814                      NaN      Yes                      1  191.121340
# 276822                  10000.0       No                     -1  190.235284
# 276931                    500.0      Yes                      2  257.198700
# ...                         ...      ...                    ...         ...
# 297657                    500.0       No                     -1    0.000000
# 297663                      NaN      Yes                      1    0.000000
# 297666                   1500.0      Yes                      0    0.000000
# 297667                      NaN       No                     -1    0.000000
# 297668                   2000.0      Yes                      0    0.000000
#
#                  p_kmGrC      O_kmGeo      O_kmGrC        lat        lon
# respondentID
# 276785          0.000000   549.265452   548.896968  -1.278463  36.751643
# 276802         24.690264    71.630505    71.550334  -1.278463  36.751643
# 276814        191.428415  6810.632065  6824.346017  -1.265984  36.916945
# 276822        190.484877   566.723692   566.323505  -1.265984  36.916945
# 276931        257.390902   257.198700   257.390902  -1.278463  36.751643
# ...                  ...          ...          ...        ...        ...
# 297657          0.000000  1509.508024  1516.249611 -26.182222  28.053333
# 297663          0.000000     0.000000     0.000000 -26.182222  28.053333
# 297666          0.000000   372.285757   373.101076 -26.182222  28.053333
# 297667          0.000000  1192.189932  1197.336354 -26.182222  28.053333
# 297668          0.000000  1254.648626  1255.233886 -26.182222  28.053333
#
# [1139 rows x 24 columns]

# %% [markdown]
# # II. Test

# %%
survey[['156 Change in lifestyle', '303 Current Employment Status']]

# %%
sns.countplot(y='303 Current Employment Status',
              hue='156 Change in lifestyle',
              data=survey,
              orient='h')

# %%
V = ['156 Change in lifestyle', '303 Current Employment Status']

subset = survey[V]
subset['count'] = 1
counts = subset.groupby(V).count()

counts.plot(kind='bar',
           stacked=True)

# %%
V = ['156 Change in lifestyle', '303 Current Employment Status']

subset = survey[V]
subset['count'] = 1
counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)

display(counts)

counts.plot(kind='barh', stacked=True, color=['grey', 'darkgrey', 'red', 'gold', 'green'],
            figsize=(8.5,5))

# %%
V = ['100: Village, City or Town', '706 Plans to move']

subset = survey[V]
subset['count'] = 1
counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)

display(counts)

counts.plot(kind='barh', stacked=True, color=['darkblue', 'blue', 'lightblue'],
            figsize=(8.5,5))

# %%
def sbar(variables, palette):
    V = variables
    P = palette

    subset = survey[V]
    subset.loc[:, 'count'] = 1
    counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)

    display(counts)

    counts.plot(kind='barh', stacked=True, color=P,
                figsize=(8.5,5))

# %% [markdown]
# * https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html
#
# * https://seaborn.pydata.org/tutorial/function_overview.html
# * https://seaborn.pydata.org/generated/seaborn.barplot.html

# %% [markdown]
# # III. Variables

# %% [markdown]
# ## 156 Change in lifestyle

# %%
sbar(['156 Change in lifestyle', '303 Current Employment Status'], ['grey', 'darkgrey', 'red', 'gold', 'green'])
# Out:
# 156 Change in lifestyle                              -3  DK/RA     No  \
# 303 Current Employment Status
# -1                                                  1.0    0.0    1.0
# -3                                                  0.0    0.0    1.0
# Casual employment/temporary worker                  0.0    2.0   51.0
# Doing casual jobs                                   0.0    3.0   72.0
# Housewife/homemaker                                 0.0    0.0   15.0
# Other                                               0.0    9.0   41.0
# Self-employed (run small business/income genera...  0.0    8.0  372.0
# Unemployed                                          0.0    6.0  176.0
# University/technikon/correspondence student         0.0    1.0   48.0
# Voluntary worker (receive no money)                 0.0    0.0    4.0
# Working full-time (formal/informal sector)          1.0    2.0  168.0
# Working part-time (formal/informal sector)          0.0    1.0   60.0
#
# 156 Change in lifestyle                             Remain the same   Yes
# 303 Current Employment Status
# -1                                                              0.0   1.0
# -3                                                              0.0   1.0
# Casual employment/temporary worker                             14.0  22.0
# Doing casual jobs                                              22.0  17.0
# Housewife/homemaker                                             5.0   5.0
# Other                                                          28.0   9.0
# Self-employed (run small business/income genera...            120.0  87.0
# Unemployed                                                     68.0  75.0
# University/technikon/correspondence student                     9.0   4.0
# Voluntary worker (receive no money)                             3.0   2.0
# Working full-time (formal/informal sector)                     52.0  27.0
# Working part-time (formal/informal sector)                     21.0   9.0

# %% [markdown]
# ## 100 Village, City, or Town

# %%
survey[['100: Village, City or Town', '8 Identify City ', '700 Stay or go', '706 Plans to move']]
# Out:
#        100: Village, City or Town 8 Identify City   \
# ID
# 276785                       Town         Nairobi
# 276788                    Village         Nairobi
# 276802                       Town         Nairobi
# 276814                    Village         Nairobi
# 276822                       City         Nairobi
# ...                           ...              ...
# 297661                       City     Johannesburg
# 297663                    Village     Johannesburg
# 297666                    Village     Johannesburg
# 297667                       City     Johannesburg
# 297668                       Town     Johannesburg
#
#                                            700 Stay or go 706 Plans to move
# ID
# 276785                                                 -1                -1
# 276788                                                 -1                -1
# 276802  Stay in country but move to another neighbourhood                No
# 276814                                                 -1                -1
# 276822                                                 -1                -1
# ...                                                   ...               ...
# 297661  Stay in country but move to another neighbourhood                No
# 297663                         Stay here in neighbourhood                No
# 297666                         Stay here in neighbourhood                No
# 297667  Stay in country but move to another neighbourhood                No
# 297668  Stay in country but move to another neighbourhood                No
#
# [1644 rows x 4 columns]

# %%
sbar(['100: Village, City or Town', '8 Identify City '], ['darkblue', 'blue', 'lightblue'])
# Out:
# 100: Village, City or Town  City  Town  Village
# 8 Identify City
# Accra                        135   339      107
# Johannesburg                 125   182      208
# Nairobi                       29   121      398

# %%
sbar(['100: Village, City or Town', '700 Stay or go'], ['darkblue', 'blue', 'lightblue'])
# Out:
# 100: Village, City or Town                         City  Town  Village
# 700 Stay or go
# -1                                                    9    10       12
# Leave the country                                    48   129       98
# Stay here in neighbourhood                          166   343      486
# Stay in country but move to another neighbourhood    66   160      117

# %%
sbar(['100: Village, City or Town', '706 Plans to move'], ['darkblue', 'blue', 'lightblue'])
# Out:
# 100: Village, City or Town  City  Town  Village
# 706 Plans to move
# -1                             9    10       12
# Dk/Ra                         11    12       44
# No                           253   582      630
# Yes                           16    38       27

# %% [markdown]
# ## 203. Reason for Location

# %%
survey[['203a Reason for Location', '205b Reason for leaving', '300 Means to Generate Income', '303 Current Employment Status', '307 Kind of Work']]
# Out:
#                      203a Reason for Location  \
# ID
# 276785                         Access to work
# 276788                                     -3
# 276802                                     -1
# 276814  Family reasons (unification / escape)
# 276822                         Access to work
# ...                                       ...
# 297661                                     -1
# 297663                                     -1
# 297666                                  Other
# 297667  Family reasons (unification / escape)
# 297668                         Access to work
#
#                       205b Reason for leaving  \
# ID
# 276785                                     -1
# 276788                                     -3
# 276802                                     -1
# 276814                         Access to work
# 276822                                     -1
# ...                                       ...
# 297661                                     -1
# 297663                                     -1
# 297666                         Access to work
# 297667  Family reasons (unification / escape)
# 297668                                     -1
#
#                300 Means to Generate Income  \
# ID
# 276785                                   -3
# 276788                                   -1
# 276802                              Teacher
# 276814           Hawker (no fixed location)
# 276822                              Teacher
# ...                                     ...
# 297661                                DK/RA
# 297663                          Not working
# 297666           Hawker (no fixed location)
# 297667  Primary or Secondary School Student
# 297668                          Not working
#
#                             303 Current Employment Status  \
# ID
# 276785                                                 -3
# 276788                                                 -1
# 276802                                  Doing casual jobs
# 276814                                  Doing casual jobs
# 276822         Working part-time (formal/informal sector)
# ...                                                   ...
# 297661        University/technikon/correspondence student
# 297663  Self-employed (run small business/income gener...
# 297666         Working full-time (formal/informal sector)
# 297667        University/technikon/correspondence student
# 297668         Working full-time (formal/informal sector)
#
#                                          307 Kind of Work
# ID
# 276785                                                 -3
# 276788                                                 -1
# 276802                                                 -3
# 276814                                                 -3
# 276822                                                 -3
# ...                                                   ...
# 297661        University/technikon/correspondence student
# 297663  Self-employed (run small business/income gener...
# 297666         Working full-time (formal/informal sector)
# 297667        University/technikon/correspondence student
# 297668         Working full-time (formal/informal sector)
#
# [1644 rows x 5 columns]

# %%
V = ['203a Reason for Location', '205b Reason for leaving']

# group and pivot table
subset = survey[V]
subset['count'] = 1
counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)
display(counts)

# remove missing data
counts = counts.drop(axis='columns', labels=['-1', '-3']).drop(axis='rows', labels=['-1', '-3'])

counts.plot(kind='barh', stacked=True,
            figsize=(8.5,5))
# Out:
# 203a Reason for Location                               -1   -3  \
# 205b Reason for leaving
# -1                                                  819.0  0.0
# -3                                                    0.0  1.0
# Access to work                                        0.0  0.0
# Cost of rent (too high& somewhere else much che...    0.0  0.0
# Crime or insecurity                                   0.0  0.0
# DK/RA                                                 0.0  0.0
# Education (for self or others)                        0.0  0.0
# Evicted                                               0.0  0.0
# Family reasons (unification / escape)                 0.0  0.0
# Needed more space                                     0.0  0.0
# Other (specify)                                       0.0  0.0
# Place no longer available                             0.0  0.0
# Political reasons                                     0.0  0.0
#
# 203a Reason for Location                            Access to work  \
# 205b Reason for leaving
# -1                                                           318.0
# -3                                                             0.0
# Access to work                                                84.0
# Cost of rent (too high& somewhere else much che...             9.0
# Crime or insecurity                                            4.0
# DK/RA                                                          2.0
# Education (for self or others)                                 0.0
# Evicted                                                        2.0
# Family reasons (unification / escape)                          8.0
# Needed more space                                              6.0
# Other (specify)                                               12.0
# Place no longer available                                      4.0
# Political reasons                                              0.0
#
# 203a Reason for Location                            Cost of rent (too high& somewhere else much cheaper)  \
# 205b Reason for leaving
# -1                                                                                               29.0
# -3                                                                                                0.0
# Access to work                                                                                    2.0
# Cost of rent (too high& somewhere else much che...                                                1.0
# Crime or insecurity                                                                               0.0
# DK/RA                                                                                             0.0
# Education (for self or others)                                                                    0.0
# Evicted                                                                                           0.0
# Family reasons (unification / escape)                                                             0.0
# Needed more space                                                                                 0.0
# Other (specify)                                                                                   0.0
# Place no longer available                                                                         0.0
# Political reasons                                                                                 0.0
#
# 203a Reason for Location                            Crime or insecurity  \
# 205b Reason for leaving
# -1                                                                  6.0
# -3                                                                  0.0
# Access to work                                                      1.0
# Cost of rent (too high& somewhere else much che...                  1.0
# Crime or insecurity                                                 0.0
# DK/RA                                                               0.0
# Education (for self or others)                                      1.0
# Evicted                                                             0.0
# Family reasons (unification / escape)                               0.0
# Needed more space                                                   0.0
# Other (specify)                                                     0.0
# Place no longer available                                           0.0
# Political reasons                                                   0.0
#
# 203a Reason for Location                            Cultural reasons (language& to be close to other countrymen)  \
# 205b Reason for leaving
# -1                                                                                                0.0
# -3                                                                                                0.0
# Access to work                                                                                    1.0
# Cost of rent (too high& somewhere else much che...                                                0.0
# Crime or insecurity                                                                               0.0
# DK/RA                                                                                             0.0
# Education (for self or others)                                                                    0.0
# Evicted                                                                                           0.0
# Family reasons (unification / escape)                                                             0.0
# Needed more space                                                                                 0.0
# Other (specify)                                                                                   0.0
# Place no longer available                                                                         0.0
# Political reasons                                                                                 0.0
#
# 203a Reason for Location                            DK/RA  \
# 205b Reason for leaving
# -1                                                    0.0
# -3                                                    0.0
# Access to work                                        0.0
# Cost of rent (too high& somewhere else much che...    0.0
# Crime or insecurity                                   0.0
# DK/RA                                                 0.0
# Education (for self or others)                        0.0
# Evicted                                               0.0
# Family reasons (unification / escape)                 1.0
# Needed more space                                     0.0
# Other (specify)                                       0.0
# Place no longer available                             0.0
# Political reasons                                     0.0
#
# 203a Reason for Location                            Education (for self or others)  \
# 205b Reason for leaving
# -1                                                                            33.0
# -3                                                                             0.0
# Access to work                                                                19.0
# Cost of rent (too high& somewhere else much che...                             1.0
# Crime or insecurity                                                            0.0
# DK/RA                                                                          0.0
# Education (for self or others)                                                15.0
# Evicted                                                                        0.0
# Family reasons (unification / escape)                                          7.0
# Needed more space                                                              0.0
# Other (specify)                                                                9.0
# Place no longer available                                                      0.0
# Political reasons                                                              0.0
#
# 203a Reason for Location                            Evicted  \
# 205b Reason for leaving
# -1                                                      4.0
# -3                                                      0.0
# Access to work                                          1.0
# Cost of rent (too high& somewhere else much che...      0.0
# Crime or insecurity                                     0.0
# DK/RA                                                   0.0
# Education (for self or others)                          0.0
# Evicted                                                 0.0
# Family reasons (unification / escape)                   1.0
# Needed more space                                       0.0
# Other (specify)                                         1.0
# Place no longer available                               0.0
# Political reasons                                       1.0
#
# 203a Reason for Location                            Family reasons (unification / escape)  \
# 205b Reason for leaving
# -1                                                                                   98.0
# -3                                                                                    0.0
# Access to work                                                                       25.0
# Cost of rent (too high& somewhere else much che...                                    0.0
# Crime or insecurity                                                                   0.0
# DK/RA                                                                                 1.0
# Education (for self or others)                                                        2.0
# Evicted                                                                               1.0
# Family reasons (unification / escape)                                                26.0
# Needed more space                                                                     3.0
# Other (specify)                                                                       5.0
# Place no longer available                                                             0.0
# Political reasons                                                                     0.0
#
# 203a Reason for Location                            Needed more space  Other  \
# 205b Reason for leaving
# -1                                                               16.0   26.0
# -3                                                                0.0    0.0
# Access to work                                                    1.0   11.0
# Cost of rent (too high& somewhere else much che...                0.0    1.0
# Crime or insecurity                                               0.0    0.0
# DK/RA                                                             0.0    1.0
# Education (for self or others)                                    1.0    1.0
# Evicted                                                           0.0    0.0
# Family reasons (unification / escape)                             1.0    1.0
# Needed more space                                                 0.0    0.0
# Other (specify)                                                   1.0   10.0
# Place no longer available                                         0.0    0.0
# Political reasons                                                 0.0    0.0
#
# 203a Reason for Location                            Place no longer available  \
# 205b Reason for leaving
# -1                                                                        2.0
# -3                                                                        0.0
# Access to work                                                            0.0
# Cost of rent (too high& somewhere else much che...                        1.0
# Crime or insecurity                                                       0.0
# DK/RA                                                                     0.0
# Education (for self or others)                                            0.0
# Evicted                                                                   0.0
# Family reasons (unification / escape)                                     0.0
# Needed more space                                                         0.0
# Other (specify)                                                           0.0
# Place no longer available                                                 0.0
# Political reasons                                                         0.0
#
# 203a Reason for Location                            Political reason
# 205b Reason for leaving
# -1                                                               4.0
# -3                                                               0.0
# Access to work                                                   1.0
# Cost of rent (too high& somewhere else much che...               0.0
# Crime or insecurity                                              0.0
# DK/RA                                                            0.0
# Education (for self or others)                                   0.0
# Evicted                                                          0.0
# Family reasons (unification / escape)                            0.0
# Needed more space                                                0.0
# Other (specify)                                                  0.0
# Place no longer available                                        0.0
# Political reasons                                                0.0
# <AxesSubplot:ylabel='205b Reason for leaving'>

# %%
V = ['203a Reason for Location', '300 Means to Generate Income']

subset = survey[V]
subset['count'] = 1
counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)
display(counts)

counts = counts.drop(axis='columns', labels=['-1', '-3']).drop(axis='rows', labels=['-1', '-3'])

counts.plot(kind='barh', stacked=True,
            figsize=(8.5,5))
# Out:
# 203a Reason for Location                        -1   -3  Access to work  \
# 300 Means to Generate Income
# -1                                             2.0  1.0             0.0
# -3                                             0.0  0.0             1.0
# Agricultural Labourer                         26.0  0.0            18.0
# Car Guard                                      2.0  0.0             1.0
# Construction                                  36.0  0.0            25.0
# DK/RA                                         80.0  0.0             5.0
# Doctor                                         4.0  0.0             1.0
# Domestic Worker/Caretaker/Custodian           43.0  0.0            38.0
# Driver                                        19.0  0.0            19.0
# Factory Worker/Sweat Shop                     19.0  0.0            18.0
# Hawker (no fixed location)                    43.0  0.0            27.0
# Housewife/Homemaker                           12.0  0.0             6.0
# Journalist/Media Professional                  3.0  0.0             2.0
# Lawyer                                         1.0  0.0             0.0
# Mechanic                                      16.0  0.0            16.0
# Missionary/Religious work                      1.0  0.0             2.0
# NGO                                            2.0  0.0             1.0
# Not working                                  182.0  0.0            78.0
# Own Business/Businessman/Businesswoman       144.0  0.0            82.0
# Petty Trading (fixed location)                47.0  0.0            24.0
# Primary or Secondary School Student           26.0  0.0            12.0
# Restaurant Employee                           24.0  0.0            24.0
# Security Guard                                16.0  0.0             9.0
# Shoe Repair                                    5.0  0.0             4.0
# Small Scale Farmer                             6.0  0.0            15.0
# Teacher                                       13.0  0.0             6.0
# University/technikon/correspondence student   45.0  0.0            11.0
# Volunteer Work                                 2.0  0.0             4.0
#
# 203a Reason for Location                     Cost of rent (too high& somewhere else much cheaper)  \
# 300 Means to Generate Income
# -1                                                                                         0.0
# -3                                                                                         0.0
# Agricultural Labourer                                                                      0.0
# Car Guard                                                                                  0.0
# Construction                                                                               1.0
# DK/RA                                                                                      0.0
# Doctor                                                                                     0.0
# Domestic Worker/Caretaker/Custodian                                                        2.0
# Driver                                                                                     1.0
# Factory Worker/Sweat Shop                                                                  1.0
# Hawker (no fixed location)                                                                 1.0
# Housewife/Homemaker                                                                        1.0
# Journalist/Media Professional                                                              0.0
# Lawyer                                                                                     0.0
# Mechanic                                                                                   2.0
# Missionary/Religious work                                                                  0.0
# NGO                                                                                        0.0
# Not working                                                                               10.0
# Own Business/Businessman/Businesswoman                                                     6.0
# Petty Trading (fixed location)                                                             1.0
# Primary or Secondary School Student                                                        0.0
# Restaurant Employee                                                                        2.0
# Security Guard                                                                             1.0
# Shoe Repair                                                                                0.0
# Small Scale Farmer                                                                         0.0
# Teacher                                                                                    1.0
# University/technikon/correspondence student                                                2.0
# Volunteer Work                                                                             0.0
#
# 203a Reason for Location                     Crime or insecurity  \
# 300 Means to Generate Income
# -1                                                           0.0
# -3                                                           0.0
# Agricultural Labourer                                        0.0
# Car Guard                                                    0.0
# Construction                                                 0.0
# DK/RA                                                        0.0
# Doctor                                                       0.0
# Domestic Worker/Caretaker/Custodian                          0.0
# Driver                                                       0.0
# Factory Worker/Sweat Shop                                    1.0
# Hawker (no fixed location)                                   1.0
# Housewife/Homemaker                                          0.0
# Journalist/Media Professional                                0.0
# Lawyer                                                       0.0
# Mechanic                                                     0.0
# Missionary/Religious work                                    0.0
# NGO                                                          0.0
# Not working                                                  3.0
# Own Business/Businessman/Businesswoman                       0.0
# Petty Trading (fixed location)                               0.0
# Primary or Secondary School Student                          2.0
# Restaurant Employee                                          0.0
# Security Guard                                               0.0
# Shoe Repair                                                  0.0
# Small Scale Farmer                                           0.0
# Teacher                                                      0.0
# University/technikon/correspondence student                  2.0
# Volunteer Work                                               0.0
#
# 203a Reason for Location                     Cultural reasons (language& to be close to other countrymen)  \
# 300 Means to Generate Income
# -1                                                                                         0.0
# -3                                                                                         0.0
# Agricultural Labourer                                                                      0.0
# Car Guard                                                                                  0.0
# Construction                                                                               0.0
# DK/RA                                                                                      0.0
# Doctor                                                                                     0.0
# Domestic Worker/Caretaker/Custodian                                                        0.0
# Driver                                                                                     0.0
# Factory Worker/Sweat Shop                                                                  0.0
# Hawker (no fixed location)                                                                 0.0
# Housewife/Homemaker                                                                        0.0
# Journalist/Media Professional                                                              0.0
# Lawyer                                                                                     0.0
# Mechanic                                                                                   0.0
# Missionary/Religious work                                                                  0.0
# NGO                                                                                        0.0
# Not working                                                                                1.0
# Own Business/Businessman/Businesswoman                                                     0.0
# Petty Trading (fixed location)                                                             0.0
# Primary or Secondary School Student                                                        0.0
# Restaurant Employee                                                                        0.0
# Security Guard                                                                             0.0
# Shoe Repair                                                                                0.0
# Small Scale Farmer                                                                         0.0
# Teacher                                                                                    0.0
# University/technikon/correspondence student                                                0.0
# Volunteer Work                                                                             0.0
#
# 203a Reason for Location                     DK/RA  \
# 300 Means to Generate Income
# -1                                             0.0
# -3                                             0.0
# Agricultural Labourer                          0.0
# Car Guard                                      0.0
# Construction                                   0.0
# DK/RA                                          1.0
# Doctor                                         0.0
# Domestic Worker/Caretaker/Custodian            0.0
# Driver                                         0.0
# Factory Worker/Sweat Shop                      0.0
# Hawker (no fixed location)                     0.0
# Housewife/Homemaker                            0.0
# Journalist/Media Professional                  0.0
# Lawyer                                         0.0
# Mechanic                                       0.0
# Missionary/Religious work                      0.0
# NGO                                            0.0
# Not working                                    0.0
# Own Business/Businessman/Businesswoman         0.0
# Petty Trading (fixed location)                 0.0
# Primary or Secondary School Student            0.0
# Restaurant Employee                            0.0
# Security Guard                                 0.0
# Shoe Repair                                    0.0
# Small Scale Farmer                             0.0
# Teacher                                        0.0
# University/technikon/correspondence student    0.0
# Volunteer Work                                 0.0
#
# 203a Reason for Location                     Education (for self or others)  \
# 300 Means to Generate Income
# -1                                                                      0.0
# -3                                                                      0.0
# Agricultural Labourer                                                   1.0
# Car Guard                                                               0.0
# Construction                                                            1.0
# DK/RA                                                                   5.0
# Doctor                                                                  0.0
# Domestic Worker/Caretaker/Custodian                                     1.0
# Driver                                                                  1.0
# Factory Worker/Sweat Shop                                               3.0
# Hawker (no fixed location)                                              2.0
# Housewife/Homemaker                                                     0.0
# Journalist/Media Professional                                           2.0
# Lawyer                                                                  0.0
# Mechanic                                                                0.0
# Missionary/Religious work                                               0.0
# NGO                                                                     0.0
# Not working                                                            18.0
# Own Business/Businessman/Businesswoman                                 10.0
# Petty Trading (fixed location)                                          2.0
# Primary or Secondary School Student                                    14.0
# Restaurant Employee                                                     3.0
# Security Guard                                                          1.0
# Shoe Repair                                                             1.0
# Small Scale Farmer                                                      0.0
# Teacher                                                                 3.0
# University/technikon/correspondence student                            16.0
# Volunteer Work                                                          0.0
#
# 203a Reason for Location                     Evicted  \
# 300 Means to Generate Income
# -1                                               0.0
# -3                                               0.0
# Agricultural Labourer                            2.0
# Car Guard                                        0.0
# Construction                                     0.0
# DK/RA                                            0.0
# Doctor                                           0.0
# Domestic Worker/Caretaker/Custodian              1.0
# Driver                                           1.0
# Factory Worker/Sweat Shop                        0.0
# Hawker (no fixed location)                       0.0
# Housewife/Homemaker                              0.0
# Journalist/Media Professional                    1.0
# Lawyer                                           0.0
# Mechanic                                         0.0
# Missionary/Religious work                        0.0
# NGO                                              0.0
# Not working                                      1.0
# Own Business/Businessman/Businesswoman           0.0
# Petty Trading (fixed location)                   0.0
# Primary or Secondary School Student              1.0
# Restaurant Employee                              0.0
# Security Guard                                   0.0
# Shoe Repair                                      0.0
# Small Scale Farmer                               0.0
# Teacher                                          0.0
# University/technikon/correspondence student      1.0
# Volunteer Work                                   0.0
#
# 203a Reason for Location                     Family reasons (unification / escape)  \
# 300 Means to Generate Income
# -1                                                                             0.0
# -3                                                                             0.0
# Agricultural Labourer                                                          4.0
# Car Guard                                                                      0.0
# Construction                                                                   6.0
# DK/RA                                                                          3.0
# Doctor                                                                         0.0
# Domestic Worker/Caretaker/Custodian                                            8.0
# Driver                                                                         1.0
# Factory Worker/Sweat Shop                                                      6.0
# Hawker (no fixed location)                                                     9.0
# Housewife/Homemaker                                                            6.0
# Journalist/Media Professional                                                  1.0
# Lawyer                                                                         0.0
# Mechanic                                                                       3.0
# Missionary/Religious work                                                      0.0
# NGO                                                                            1.0
# Not working                                                                   46.0
# Own Business/Businessman/Businesswoman                                        23.0
# Petty Trading (fixed location)                                                14.0
# Primary or Secondary School Student                                           17.0
# Restaurant Employee                                                            6.0
# Security Guard                                                                 0.0
# Shoe Repair                                                                    0.0
# Small Scale Farmer                                                             1.0
# Teacher                                                                        2.0
# University/technikon/correspondence student                                    2.0
# Volunteer Work                                                                 2.0
#
# 203a Reason for Location                     Needed more space  Other  \
# 300 Means to Generate Income
# -1                                                         0.0    0.0
# -3                                                         0.0    0.0
# Agricultural Labourer                                      0.0    1.0
# Car Guard                                                  0.0    0.0
# Construction                                               1.0    1.0
# DK/RA                                                      0.0    1.0
# Doctor                                                     0.0    0.0
# Domestic Worker/Caretaker/Custodian                        1.0    2.0
# Driver                                                     0.0    1.0
# Factory Worker/Sweat Shop                                  0.0    3.0
# Hawker (no fixed location)                                 0.0    3.0
# Housewife/Homemaker                                        0.0    2.0
# Journalist/Media Professional                              0.0    0.0
# Lawyer                                                     0.0    0.0
# Mechanic                                                   0.0    0.0
# Missionary/Religious work                                  0.0    1.0
# NGO                                                        0.0    0.0
# Not working                                                9.0   14.0
# Own Business/Businessman/Businesswoman                     2.0   15.0
# Petty Trading (fixed location)                             2.0    2.0
# Primary or Secondary School Student                        3.0    1.0
# Restaurant Employee                                        0.0    1.0
# Security Guard                                             0.0    0.0
# Shoe Repair                                                0.0    1.0
# Small Scale Farmer                                         0.0    1.0
# Teacher                                                    0.0    1.0
# University/technikon/correspondence student                2.0    0.0
# Volunteer Work                                             0.0    0.0
#
# 203a Reason for Location                     Place no longer available  \
# 300 Means to Generate Income
# -1                                                                 0.0
# -3                                                                 0.0
# Agricultural Labourer                                              0.0
# Car Guard                                                          0.0
# Construction                                                       0.0
# DK/RA                                                              0.0
# Doctor                                                             0.0
# Domestic Worker/Caretaker/Custodian                                0.0
# Driver                                                             0.0
# Factory Worker/Sweat Shop                                          0.0
# Hawker (no fixed location)                                         1.0
# Housewife/Homemaker                                                0.0
# Journalist/Media Professional                                      0.0
# Lawyer                                                             0.0
# Mechanic                                                           0.0
# Missionary/Religious work                                          0.0
# NGO                                                                0.0
# Not working                                                        1.0
# Own Business/Businessman/Businesswoman                             1.0
# Petty Trading (fixed location)                                     0.0
# Primary or Secondary School Student                                0.0
# Restaurant Employee                                                0.0
# Security Guard                                                     0.0
# Shoe Repair                                                        0.0
# Small Scale Farmer                                                 0.0
# Teacher                                                            0.0
# University/technikon/correspondence student                        0.0
# Volunteer Work                                                     0.0
#
# 203a Reason for Location                     Political reason
# 300 Means to Generate Income
# -1                                                        0.0
# -3                                                        0.0
# Agricultural Labourer                                     0.0
# Car Guard                                                 0.0
# Construction                                              1.0
# DK/RA                                                     0.0
# Doctor                                                    0.0
# Domestic Worker/Caretaker/Custodian                       0.0
# Driver                                                    0.0
# Factory Worker/Sweat Shop                                 0.0
# Hawker (no fixed location)                                0.0
# Housewife/Homemaker                                       0.0
# Journalist/Media Professional                             1.0
# Lawyer                                                    0.0
# Mechanic                                                  0.0
# Missionary/Religious work                                 0.0
# NGO                                                       0.0
# Not working                                               1.0
# Own Business/Businessman/Businesswoman                    1.0
# Petty Trading (fixed location)                            0.0
# Primary or Secondary School Student                       0.0
# Restaurant Employee                                       0.0
# Security Guard                                            1.0
# Shoe Repair                                               0.0
# Small Scale Farmer                                        0.0
# Teacher                                                   0.0
# University/technikon/correspondence student               0.0
# Volunteer Work                                            0.0
# <AxesSubplot:ylabel='300 Means to Generate Income'>

# %%
V = ['203a Reason for Location', '303 Current Employment Status']

subset = survey[V]
subset['count'] = 1
counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)
display(counts)

counts = counts.drop(axis='columns', labels=['-1', '-3']).drop(axis='rows', labels=['-1', '-3'])

counts.plot(kind='barh', stacked=True,
            figsize=(8.5,5))
# Out:
# 203a Reason for Location                               -1   -3  \
# 303 Current Employment Status
# -1                                                    2.0  1.0
# -3                                                    1.0  0.0
# Casual employment/temporary worker                   42.0  0.0
# Doing casual jobs                                    54.0  0.0
# Housewife/homemaker                                  10.0  0.0
# Other                                                63.0  0.0
# Self-employed (run small business/income genera...  263.0  0.0
# Unemployed                                          178.0  0.0
# University/technikon/correspondence student          37.0  0.0
# Voluntary worker (receive no money)                   3.0  0.0
# Working full-time (formal/informal sector)          109.0  0.0
# Working part-time (formal/informal sector)           57.0  0.0
#
# 203a Reason for Location                            Access to work  \
# 303 Current Employment Status
# -1                                                             0.0
# -3                                                             1.0
# Casual employment/temporary worker                            30.0
# Doing casual jobs                                             38.0
# Housewife/homemaker                                            5.0
# Other                                                         12.0
# Self-employed (run small business/income genera...           176.0
# Unemployed                                                    67.0
# University/technikon/correspondence student                    1.0
# Voluntary worker (receive no money)                            3.0
# Working full-time (formal/informal sector)                    95.0
# Working part-time (formal/informal sector)                    21.0
#
# 203a Reason for Location                            Cost of rent (too high& somewhere else much cheaper)  \
# 303 Current Employment Status
# -1                                                                                                0.0
# -3                                                                                                0.0
# Casual employment/temporary worker                                                                3.0
# Doing casual jobs                                                                                 2.0
# Housewife/homemaker                                                                               0.0
# Other                                                                                             0.0
# Self-employed (run small business/income genera...                                               11.0
# Unemployed                                                                                        7.0
# University/technikon/correspondence student                                                       2.0
# Voluntary worker (receive no money)                                                               0.0
# Working full-time (formal/informal sector)                                                        7.0
# Working part-time (formal/informal sector)                                                        0.0
#
# 203a Reason for Location                            Crime or insecurity  \
# 303 Current Employment Status
# -1                                                                  0.0
# -3                                                                  0.0
# Casual employment/temporary worker                                  0.0
# Doing casual jobs                                                   0.0
# Housewife/homemaker                                                 0.0
# Other                                                               1.0
# Self-employed (run small business/income genera...                  2.0
# Unemployed                                                          2.0
# University/technikon/correspondence student                         0.0
# Voluntary worker (receive no money)                                 0.0
# Working full-time (formal/informal sector)                          1.0
# Working part-time (formal/informal sector)                          3.0
#
# 203a Reason for Location                            Cultural reasons (language& to be close to other countrymen)  \
# 303 Current Employment Status
# -1                                                                                                0.0
# -3                                                                                                0.0
# Casual employment/temporary worker                                                                0.0
# Doing casual jobs                                                                                 0.0
# Housewife/homemaker                                                                               0.0
# Other                                                                                             0.0
# Self-employed (run small business/income genera...                                                1.0
# Unemployed                                                                                        0.0
# University/technikon/correspondence student                                                       0.0
# Voluntary worker (receive no money)                                                               0.0
# Working full-time (formal/informal sector)                                                        0.0
# Working part-time (formal/informal sector)                                                        0.0
#
# 203a Reason for Location                            DK/RA  \
# 303 Current Employment Status
# -1                                                    0.0
# -3                                                    0.0
# Casual employment/temporary worker                    0.0
# Doing casual jobs                                     0.0
# Housewife/homemaker                                   0.0
# Other                                                 0.0
# Self-employed (run small business/income genera...    0.0
# Unemployed                                            0.0
# University/technikon/correspondence student           0.0
# Voluntary worker (receive no money)                   0.0
# Working full-time (formal/informal sector)            1.0
# Working part-time (formal/informal sector)            0.0
#
# 203a Reason for Location                            Education (for self or others)  \
# 303 Current Employment Status
# -1                                                                             0.0
# -3                                                                             0.0
# Casual employment/temporary worker                                             4.0
# Doing casual jobs                                                              5.0
# Housewife/homemaker                                                            1.0
# Other                                                                          2.0
# Self-employed (run small business/income genera...                            21.0
# Unemployed                                                                    19.0
# University/technikon/correspondence student                                   17.0
# Voluntary worker (receive no money)                                            1.0
# Working full-time (formal/informal sector)                                    11.0
# Working part-time (formal/informal sector)                                     3.0
#
# 203a Reason for Location                            Evicted  \
# 303 Current Employment Status
# -1                                                      0.0
# -3                                                      0.0
# Casual employment/temporary worker                      0.0
# Doing casual jobs                                       0.0
# Housewife/homemaker                                     0.0
# Other                                                   0.0
# Self-employed (run small business/income genera...      3.0
# Unemployed                                              5.0
# University/technikon/correspondence student             0.0
# Voluntary worker (receive no money)                     0.0
# Working full-time (formal/informal sector)              0.0
# Working part-time (formal/informal sector)              0.0
#
# 203a Reason for Location                            Family reasons (unification / escape)  \
# 303 Current Employment Status
# -1                                                                                    0.0
# -3                                                                                    0.0
# Casual employment/temporary worker                                                    9.0
# Doing casual jobs                                                                    12.0
# Housewife/homemaker                                                                   5.0
# Other                                                                                 6.0
# Self-employed (run small business/income genera...                                   68.0
# Unemployed                                                                           31.0
# University/technikon/correspondence student                                           5.0
# Voluntary worker (receive no money)                                                   2.0
# Working full-time (formal/informal sector)                                           21.0
# Working part-time (formal/informal sector)                                            2.0
#
# 203a Reason for Location                            Needed more space  Other  \
# 303 Current Employment Status
# -1                                                                0.0    0.0
# -3                                                                0.0    0.0
# Casual employment/temporary worker                                1.0    0.0
# Doing casual jobs                                                 0.0    3.0
# Housewife/homemaker                                               0.0    4.0
# Other                                                             0.0    3.0
# Self-employed (run small business/income genera...                6.0   31.0
# Unemployed                                                       10.0    5.0
# University/technikon/correspondence student                       0.0    0.0
# Voluntary worker (receive no money)                               0.0    0.0
# Working full-time (formal/informal sector)                        2.0    2.0
# Working part-time (formal/informal sector)                        1.0    3.0
#
# 203a Reason for Location                            Place no longer available  \
# 303 Current Employment Status
# -1                                                                        0.0
# -3                                                                        0.0
# Casual employment/temporary worker                                        0.0
# Doing casual jobs                                                         0.0
# Housewife/homemaker                                                       0.0
# Other                                                                     0.0
# Self-employed (run small business/income genera...                        3.0
# Unemployed                                                                0.0
# University/technikon/correspondence student                               0.0
# Voluntary worker (receive no money)                                       0.0
# Working full-time (formal/informal sector)                                0.0
# Working part-time (formal/informal sector)                                0.0
#
# 203a Reason for Location                            Political reason
# 303 Current Employment Status
# -1                                                               0.0
# -3                                                               0.0
# Casual employment/temporary worker                               0.0
# Doing casual jobs                                                0.0
# Housewife/homemaker                                              0.0
# Other                                                            0.0
# Self-employed (run small business/income genera...               2.0
# Unemployed                                                       1.0
# University/technikon/correspondence student                      0.0
# Voluntary worker (receive no money)                              0.0
# Working full-time (formal/informal sector)                       1.0
# Working part-time (formal/informal sector)                       1.0
# <AxesSubplot:ylabel='303 Current Employment Status'>

# %%
V = ['203a Reason for Location', '307 Kind of Work']

subset = survey[V]
subset['count'] = 1
counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)
display(counts)

counts = counts.drop(axis='columns', labels=['-1', '-3']).drop(axis='rows', labels=['-1', '-3'])

counts.plot(kind='barh', stacked=True,
            figsize=(8.5,5))
# Out:
# 203a Reason for Location                               -1   -3  \
# 307 Kind of Work
# -1                                                    2.0  1.0
# -3                                                   17.0  0.0
# Casual employment/temporary worker                   48.0  0.0
# Doing casual jobs                                    46.0  0.0
# Housewife/homemaker                                   9.0  0.0
# Other (specify)                                      53.0  0.0
# Self-employed (run small business/income genera...  268.0  0.0
# Unemployed                                          170.0  0.0
# University/technikon/correspondence student          39.0  0.0
# Voluntary worker (receive no money)                   3.0  0.0
# Working full-time (formal/informal sector)          120.0  0.0
# Working part-time (formal/informal sector)           44.0  0.0
#
# 203a Reason for Location                            Access to work  \
# 307 Kind of Work
# -1                                                             0.0
# -3                                                             6.0
# Casual employment/temporary worker                            29.0
# Doing casual jobs                                             36.0
# Housewife/homemaker                                            6.0
# Other (specify)                                               15.0
# Self-employed (run small business/income genera...           178.0
# Unemployed                                                    61.0
# University/technikon/correspondence student                    1.0
# Voluntary worker (receive no money)                            5.0
# Working full-time (formal/informal sector)                    93.0
# Working part-time (formal/informal sector)                    19.0
#
# 203a Reason for Location                            Cost of rent (too high& somewhere else much cheaper)  \
# 307 Kind of Work
# -1                                                                                                0.0
# -3                                                                                                1.0
# Casual employment/temporary worker                                                                3.0
# Doing casual jobs                                                                                 2.0
# Housewife/homemaker                                                                               0.0
# Other (specify)                                                                                   0.0
# Self-employed (run small business/income genera...                                               11.0
# Unemployed                                                                                        7.0
# University/technikon/correspondence student                                                       1.0
# Voluntary worker (receive no money)                                                               0.0
# Working full-time (formal/informal sector)                                                        7.0
# Working part-time (formal/informal sector)                                                        0.0
#
# 203a Reason for Location                            Crime or insecurity  \
# 307 Kind of Work
# -1                                                                  0.0
# -3                                                                  0.0
# Casual employment/temporary worker                                  0.0
# Doing casual jobs                                                   0.0
# Housewife/homemaker                                                 0.0
# Other (specify)                                                     0.0
# Self-employed (run small business/income genera...                  2.0
# Unemployed                                                          1.0
# University/technikon/correspondence student                         2.0
# Voluntary worker (receive no money)                                 0.0
# Working full-time (formal/informal sector)                          1.0
# Working part-time (formal/informal sector)                          3.0
#
# 203a Reason for Location                            Cultural reasons (language& to be close to other countrymen)  \
# 307 Kind of Work
# -1                                                                                                0.0
# -3                                                                                                0.0
# Casual employment/temporary worker                                                                0.0
# Doing casual jobs                                                                                 0.0
# Housewife/homemaker                                                                               0.0
# Other (specify)                                                                                   0.0
# Self-employed (run small business/income genera...                                                1.0
# Unemployed                                                                                        0.0
# University/technikon/correspondence student                                                       0.0
# Voluntary worker (receive no money)                                                               0.0
# Working full-time (formal/informal sector)                                                        0.0
# Working part-time (formal/informal sector)                                                        0.0
#
# 203a Reason for Location                            DK/RA  \
# 307 Kind of Work
# -1                                                    0.0
# -3                                                    0.0
# Casual employment/temporary worker                    0.0
# Doing casual jobs                                     0.0
# Housewife/homemaker                                   0.0
# Other (specify)                                       0.0
# Self-employed (run small business/income genera...    0.0
# Unemployed                                            0.0
# University/technikon/correspondence student           0.0
# Voluntary worker (receive no money)                   0.0
# Working full-time (formal/informal sector)            1.0
# Working part-time (formal/informal sector)            0.0
#
# 203a Reason for Location                            Education (for self or others)  \
# 307 Kind of Work
# -1                                                                             0.0
# -3                                                                             2.0
# Casual employment/temporary worker                                             5.0
# Doing casual jobs                                                              5.0
# Housewife/homemaker                                                            1.0
# Other (specify)                                                                2.0
# Self-employed (run small business/income genera...                            21.0
# Unemployed                                                                    18.0
# University/technikon/correspondence student                                   16.0
# Voluntary worker (receive no money)                                            1.0
# Working full-time (formal/informal sector)                                    10.0
# Working part-time (formal/informal sector)                                     3.0
#
# 203a Reason for Location                            Evicted  \
# 307 Kind of Work
# -1                                                      0.0
# -3                                                      1.0
# Casual employment/temporary worker                      0.0
# Doing casual jobs                                       0.0
# Housewife/homemaker                                     0.0
# Other (specify)                                         0.0
# Self-employed (run small business/income genera...      3.0
# Unemployed                                              4.0
# University/technikon/correspondence student             0.0
# Voluntary worker (receive no money)                     0.0
# Working full-time (formal/informal sector)              0.0
# Working part-time (formal/informal sector)              0.0
#
# 203a Reason for Location                            Family reasons (unification / escape)  \
# 307 Kind of Work
# -1                                                                                    0.0
# -3                                                                                    2.0
# Casual employment/temporary worker                                                    8.0
# Doing casual jobs                                                                    11.0
# Housewife/homemaker                                                                   6.0
# Other (specify)                                                                       8.0
# Self-employed (run small business/income genera...                                   67.0
# Unemployed                                                                           27.0
# University/technikon/correspondence student                                           5.0
# Voluntary worker (receive no money)                                                   2.0
# Working full-time (formal/informal sector)                                           19.0
# Working part-time (formal/informal sector)                                            6.0
#
# 203a Reason for Location                            Needed more space  Other  \
# 307 Kind of Work
# -1                                                                0.0    0.0
# -3                                                                0.0    0.0
# Casual employment/temporary worker                                1.0    1.0
# Doing casual jobs                                                 0.0    2.0
# Housewife/homemaker                                               0.0    4.0
# Other (specify)                                                   0.0    1.0
# Self-employed (run small business/income genera...                6.0   32.0
# Unemployed                                                       10.0    6.0
# University/technikon/correspondence student                       0.0    0.0
# Voluntary worker (receive no money)                               0.0    0.0
# Working full-time (formal/informal sector)                        1.0    2.0
# Working part-time (formal/informal sector)                        2.0    3.0
#
# 203a Reason for Location                            Place no longer available  \
# 307 Kind of Work
# -1                                                                        0.0
# -3                                                                        0.0
# Casual employment/temporary worker                                        0.0
# Doing casual jobs                                                         0.0
# Housewife/homemaker                                                       0.0
# Other (specify)                                                           0.0
# Self-employed (run small business/income genera...                        3.0
# Unemployed                                                                0.0
# University/technikon/correspondence student                               0.0
# Voluntary worker (receive no money)                                       0.0
# Working full-time (formal/informal sector)                                0.0
# Working part-time (formal/informal sector)                                0.0
#
# 203a Reason for Location                            Political reason
# 307 Kind of Work
# -1                                                               0.0
# -3                                                               0.0
# Casual employment/temporary worker                               0.0
# Doing casual jobs                                                0.0
# Housewife/homemaker                                              0.0
# Other (specify)                                                  0.0
# Self-employed (run small business/income genera...               3.0
# Unemployed                                                       0.0
# University/technikon/correspondence student                      0.0
# Voluntary worker (receive no money)                              0.0
# Working full-time (formal/informal sector)                       1.0
# Working part-time (formal/informal sector)                       1.0
# <AxesSubplot:ylabel='307 Kind of Work'>

# %% [markdown]
# ## 303. Current Employment Status

# %%
survey[['303 Current Employment Status', '205b Reason for leaving', ]]

# %%
V = ['303 Current Employment Status', '205b Reason for leaving']

subset = survey[V]
subset['count'] = 1
counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)
display(counts)

counts = counts.drop(axis='columns', labels=['-1', '-3']).drop(axis='rows', labels=['-1', '-3'])

counts.plot(kind='barh', stacked=True,
            figsize=(8.5,5))
# Out:
# 303 Current Employment Status                        -1   -3  \
# 205b Reason for leaving
# -1                                                  2.0  2.0
# -3                                                  1.0  0.0
# Access to work                                      0.0  0.0
# Cost of rent (too high& somewhere else much che...  0.0  0.0
# Crime or insecurity                                 0.0  0.0
# DK/RA                                               0.0  0.0
# Education (for self or others)                      0.0  0.0
# Evicted                                             0.0  0.0
# Family reasons (unification / escape)               0.0  0.0
# Needed more space                                   0.0  0.0
# Other (specify)                                     0.0  0.0
# Place no longer available                           0.0  0.0
# Political reasons                                   0.0  0.0
#
# 303 Current Employment Status                       Casual employment/temporary worker  \
# 205b Reason for leaving
# -1                                                                                76.0
# -3                                                                                 0.0
# Access to work                                                                     8.0
# Cost of rent (too high& somewhere else much che...                                 0.0
# Crime or insecurity                                                                0.0
# DK/RA                                                                              0.0
# Education (for self or others)                                                     2.0
# Evicted                                                                            0.0
# Family reasons (unification / escape)                                              1.0
# Needed more space                                                                  0.0
# Other (specify)                                                                    2.0
# Place no longer available                                                          0.0
# Political reasons                                                                  0.0
#
# 303 Current Employment Status                       Doing casual jobs  \
# 205b Reason for leaving
# -1                                                               90.0
# -3                                                                0.0
# Access to work                                                   13.0
# Cost of rent (too high& somewhere else much che...                2.0
# Crime or insecurity                                               0.0
# DK/RA                                                             2.0
# Education (for self or others)                                    0.0
# Evicted                                                           0.0
# Family reasons (unification / escape)                             4.0
# Needed more space                                                 1.0
# Other (specify)                                                   1.0
# Place no longer available                                         1.0
# Political reasons                                                 0.0
#
# 303 Current Employment Status                       Housewife/homemaker  \
# 205b Reason for leaving
# -1                                                                 21.0
# -3                                                                  0.0
# Access to work                                                      1.0
# Cost of rent (too high& somewhere else much che...                  0.0
# Crime or insecurity                                                 0.0
# DK/RA                                                               0.0
# Education (for self or others)                                      0.0
# Evicted                                                             0.0
# Family reasons (unification / escape)                               2.0
# Needed more space                                                   0.0
# Other (specify)                                                     1.0
# Place no longer available                                           0.0
# Political reasons                                                   0.0
#
# 303 Current Employment Status                       Other  \
# 205b Reason for leaving
# -1                                                   82.0
# -3                                                    0.0
# Access to work                                        2.0
# Cost of rent (too high& somewhere else much che...    0.0
# Crime or insecurity                                   0.0
# DK/RA                                                 1.0
# Education (for self or others)                        1.0
# Evicted                                               0.0
# Family reasons (unification / escape)                 0.0
# Needed more space                                     0.0
# Other (specify)                                       1.0
# Place no longer available                             0.0
# Political reasons                                     0.0
#
# 303 Current Employment Status                       Self-employed (run small business/income generation project)  \
# 205b Reason for leaving
# -1                                                                                              457.0
# -3                                                                                                0.0
# Access to work                                                                                   64.0
# Cost of rent (too high& somewhere else much che...                                                6.0
# Crime or insecurity                                                                               3.0
# DK/RA                                                                                             1.0
# Education (for self or others)                                                                    7.0
# Evicted                                                                                           1.0
# Family reasons (unification / escape)                                                            17.0
# Needed more space                                                                                 5.0
# Other (specify)                                                                                  23.0
# Place no longer available                                                                         2.0
# Political reasons                                                                                 1.0
#
# 303 Current Employment Status                       Unemployed   \
# 205b Reason for leaving
# -1                                                        280.0
# -3                                                          0.0
# Access to work                                             23.0
# Cost of rent (too high& somewhere else much che...          1.0
# Crime or insecurity                                         0.0
# DK/RA                                                       0.0
# Education (for self or others)                              2.0
# Evicted                                                     1.0
# Family reasons (unification / escape)                      11.0
# Needed more space                                           2.0
# Other (specify)                                             5.0
# Place no longer available                                   0.0
# Political reasons                                           0.0
#
# 303 Current Employment Status                       University/technikon/correspondence student  \
# 205b Reason for leaving
# -1                                                                                         50.0
# -3                                                                                          0.0
# Access to work                                                                              2.0
# Cost of rent (too high& somewhere else much che...                                          0.0
# Crime or insecurity                                                                         0.0
# DK/RA                                                                                       0.0
# Education (for self or others)                                                              4.0
# Evicted                                                                                     0.0
# Family reasons (unification / escape)                                                       3.0
# Needed more space                                                                           0.0
# Other (specify)                                                                             3.0
# Place no longer available                                                                   0.0
# Political reasons                                                                           0.0
#
# 303 Current Employment Status                       Voluntary worker (receive no money)  \
# 205b Reason for leaving
# -1                                                                                  8.0
# -3                                                                                  0.0
# Access to work                                                                      0.0
# Cost of rent (too high& somewhere else much che...                                  0.0
# Crime or insecurity                                                                 0.0
# DK/RA                                                                               0.0
# Education (for self or others)                                                      1.0
# Evicted                                                                             0.0
# Family reasons (unification / escape)                                               0.0
# Needed more space                                                                   0.0
# Other (specify)                                                                     0.0
# Place no longer available                                                           0.0
# Political reasons                                                                   0.0
#
# 303 Current Employment Status                       Working full-time (formal/informal sector)  \
# 205b Reason for leaving
# -1                                                                                       204.0
# -3                                                                                         0.0
# Access to work                                                                            29.0
# Cost of rent (too high& somewhere else much che...                                         5.0
# Crime or insecurity                                                                        0.0
# DK/RA                                                                                      0.0
# Education (for self or others)                                                             2.0
# Evicted                                                                                    1.0
# Family reasons (unification / escape)                                                      5.0
# Needed more space                                                                          1.0
# Other (specify)                                                                            2.0
# Place no longer available                                                                  1.0
# Political reasons                                                                          0.0
#
# 303 Current Employment Status                       Working part-time (formal/informal sector)
# 205b Reason for leaving
# -1                                                                                        83.0
# -3                                                                                         0.0
# Access to work                                                                             4.0
# Cost of rent (too high& somewhere else much che...                                         0.0
# Crime or insecurity                                                                        1.0
# DK/RA                                                                                      0.0
# Education (for self or others)                                                             1.0
# Evicted                                                                                    0.0
# Family reasons (unification / escape)                                                      2.0
# Needed more space                                                                          0.0
# Other (specify)                                                                            0.0
# Place no longer available                                                                  0.0
# Political reasons                                                                          0.0
# <AxesSubplot:ylabel='205b Reason for leaving'>

# %%
V = ['303 Current Employment Status', '300 Means to Generate Income']

subset = survey[V]
subset['count'] = 1

counts_ = subset.groupby(V).count().reset_index()
counts_ = counts_[]

counts = .pivot(columns=V[0], index=V[1], values='count').fillna(0)
display(counts)

counts = counts.drop(axis='columns', labels=['-1', '-3']).drop(axis='rows', labels=['-1', '-3'])

counts.plot(kind='barh', stacked=True,
            figsize=(8.5,5))
# Out:
# 303 Current Employment Status                 -1   -3  \
# 300 Means to Generate Income
# -1                                           3.0  0.0
# -3                                           0.0  1.0
# Agricultural Labourer                        0.0  0.0
# Car Guard                                    0.0  0.0
# Construction                                 0.0  0.0
# DK/RA                                        0.0  0.0
# Doctor                                       0.0  0.0
# Domestic Worker/Caretaker/Custodian          0.0  0.0
# Driver                                       0.0  0.0
# Factory Worker/Sweat Shop                    0.0  0.0
# Hawker (no fixed location)                   0.0  0.0
# Housewife/Homemaker                          0.0  0.0
# Journalist/Media Professional                0.0  0.0
# Lawyer                                       0.0  0.0
# Mechanic                                     0.0  0.0
# Missionary/Religious work                    0.0  0.0
# NGO                                          0.0  0.0
# Not working                                  0.0  0.0
# Own Business/Businessman/Businesswoman       0.0  0.0
# Petty Trading (fixed location)               0.0  0.0
# Primary or Secondary School Student          0.0  0.0
# Restaurant Employee                          0.0  0.0
# Security Guard                               0.0  0.0
# Shoe Repair                                  0.0  0.0
# Small Scale Farmer                           0.0  0.0
# Teacher                                      0.0  1.0
# University/technikon/correspondence student  0.0  0.0
# Volunteer Work                               0.0  0.0
#
# 303 Current Employment Status                Casual employment/temporary worker  \
# 300 Means to Generate Income
# -1                                                                          0.0
# -3                                                                          0.0
# Agricultural Labourer                                                       6.0
# Car Guard                                                                   0.0
# Construction                                                                8.0
# DK/RA                                                                       6.0
# Doctor                                                                      0.0
# Domestic Worker/Caretaker/Custodian                                         9.0
# Driver                                                                      4.0
# Factory Worker/Sweat Shop                                                   2.0
# Hawker (no fixed location)                                                  7.0
# Housewife/Homemaker                                                         0.0
# Journalist/Media Professional                                               0.0
# Lawyer                                                                      0.0
# Mechanic                                                                    2.0
# Missionary/Religious work                                                   0.0
# NGO                                                                         0.0
# Not working                                                                 8.0
# Own Business/Businessman/Businesswoman                                      9.0
# Petty Trading (fixed location)                                              8.0
# Primary or Secondary School Student                                         6.0
# Restaurant Employee                                                         7.0
# Security Guard                                                              1.0
# Shoe Repair                                                                 0.0
# Small Scale Farmer                                                          1.0
# Teacher                                                                     2.0
# University/technikon/correspondence student                                 3.0
# Volunteer Work                                                              0.0
#
# 303 Current Employment Status                Doing casual jobs  \
# 300 Means to Generate Income
# -1                                                         0.0
# -3                                                         0.0
# Agricultural Labourer                                     13.0
# Car Guard                                                  1.0
# Construction                                               7.0
# DK/RA                                                      7.0
# Doctor                                                     0.0
# Domestic Worker/Caretaker/Custodian                       16.0
# Driver                                                     1.0
# Factory Worker/Sweat Shop                                  2.0
# Hawker (no fixed location)                                 9.0
# Housewife/Homemaker                                        1.0
# Journalist/Media Professional                              0.0
# Lawyer                                                     0.0
# Mechanic                                                   3.0
# Missionary/Religious work                                  0.0
# NGO                                                        0.0
# Not working                                               22.0
# Own Business/Businessman/Businesswoman                     6.0
# Petty Trading (fixed location)                             7.0
# Primary or Secondary School Student                        3.0
# Restaurant Employee                                        6.0
# Security Guard                                             2.0
# Shoe Repair                                                1.0
# Small Scale Farmer                                         5.0
# Teacher                                                    1.0
# University/technikon/correspondence student                1.0
# Volunteer Work                                             0.0
#
# 303 Current Employment Status                Housewife/homemaker  Other  \
# 300 Means to Generate Income
# -1                                                           0.0    0.0
# -3                                                           0.0    0.0
# Agricultural Labourer                                        0.0    0.0
# Car Guard                                                    0.0    1.0
# Construction                                                 0.0    1.0
# DK/RA                                                        1.0    4.0
# Doctor                                                       0.0    1.0
# Domestic Worker/Caretaker/Custodian                          2.0    2.0
# Driver                                                       0.0   10.0
# Factory Worker/Sweat Shop                                    1.0    2.0
# Hawker (no fixed location)                                   1.0    4.0
# Housewife/Homemaker                                          9.0    0.0
# Journalist/Media Professional                                0.0    0.0
# Lawyer                                                       0.0    0.0
# Mechanic                                                     0.0    1.0
# Missionary/Religious work                                    0.0    1.0
# NGO                                                          0.0    0.0
# Not working                                                  7.0   28.0
# Own Business/Businessman/Businesswoman                       1.0   13.0
# Petty Trading (fixed location)                               0.0    6.0
# Primary or Secondary School Student                          1.0    5.0
# Restaurant Employee                                          1.0    1.0
# Security Guard                                               0.0    1.0
# Shoe Repair                                                  0.0    2.0
# Small Scale Farmer                                           1.0    1.0
# Teacher                                                      0.0    0.0
# University/technikon/correspondence student                  0.0    3.0
# Volunteer Work                                               0.0    0.0
#
# 303 Current Employment Status                Self-employed (run small business/income generation project)  \
# 300 Means to Generate Income
# -1                                                                                         0.0
# -3                                                                                         0.0
# Agricultural Labourer                                                                     24.0
# Car Guard                                                                                  0.0
# Construction                                                                              14.0
# DK/RA                                                                                     34.0
# Doctor                                                                                     1.0
# Domestic Worker/Caretaker/Custodian                                                       19.0
# Driver                                                                                     8.0
# Factory Worker/Sweat Shop                                                                 17.0
# Hawker (no fixed location)                                                                49.0
# Housewife/Homemaker                                                                        9.0
# Journalist/Media Professional                                                              7.0
# Lawyer                                                                                     0.0
# Mechanic                                                                                  17.0
# Missionary/Religious work                                                                  2.0
# NGO                                                                                        1.0
# Not working                                                                               63.0
# Own Business/Businessman/Businesswoman                                                   206.0
# Petty Trading (fixed location)                                                            52.0
# Primary or Secondary School Student                                                       16.0
# Restaurant Employee                                                                       15.0
# Security Guard                                                                             1.0
# Shoe Repair                                                                                7.0
# Small Scale Farmer                                                                        11.0
# Teacher                                                                                    3.0
# University/technikon/correspondence student                                                8.0
# Volunteer Work                                                                             3.0
#
# 303 Current Employment Status                Unemployed   \
# 300 Means to Generate Income
# -1                                                   0.0
# -3                                                   0.0
# Agricultural Labourer                                5.0
# Car Guard                                            1.0
# Construction                                        11.0
# DK/RA                                               12.0
# Doctor                                               0.0
# Domestic Worker/Caretaker/Custodian                 12.0
# Driver                                               5.0
# Factory Worker/Sweat Shop                            4.0
# Hawker (no fixed location)                           5.0
# Housewife/Homemaker                                  7.0
# Journalist/Media Professional                        0.0
# Lawyer                                               1.0
# Mechanic                                             5.0
# Missionary/Religious work                            1.0
# NGO                                                  1.0
# Not working                                        172.0
# Own Business/Businessman/Businesswoman              24.0
# Petty Trading (fixed location)                       6.0
# Primary or Secondary School Student                 18.0
# Restaurant Employee                                 11.0
# Security Guard                                       1.0
# Shoe Repair                                          0.0
# Small Scale Farmer                                   0.0
# Teacher                                              4.0
# University/technikon/correspondence student         16.0
# Volunteer Work                                       3.0
#
# 303 Current Employment Status                University/technikon/correspondence student  \
# 300 Means to Generate Income
# -1                                                                                   0.0
# -3                                                                                   0.0
# Agricultural Labourer                                                                0.0
# Car Guard                                                                            0.0
# Construction                                                                         1.0
# DK/RA                                                                                9.0
# Doctor                                                                               0.0
# Domestic Worker/Caretaker/Custodian                                                  0.0
# Driver                                                                               0.0
# Factory Worker/Sweat Shop                                                            1.0
# Hawker (no fixed location)                                                           0.0
# Housewife/Homemaker                                                                  1.0
# Journalist/Media Professional                                                        0.0
# Lawyer                                                                               0.0
# Mechanic                                                                             0.0
# Missionary/Religious work                                                            0.0
# NGO                                                                                  0.0
# Not working                                                                         10.0
# Own Business/Businessman/Businesswoman                                               0.0
# Petty Trading (fixed location)                                                       0.0
# Primary or Secondary School Student                                                  8.0
# Restaurant Employee                                                                  0.0
# Security Guard                                                                       1.0
# Shoe Repair                                                                          0.0
# Small Scale Farmer                                                                   0.0
# Teacher                                                                              0.0
# University/technikon/correspondence student                                         31.0
# Volunteer Work                                                                       0.0
#
# 303 Current Employment Status                Voluntary worker (receive no money)  \
# 300 Means to Generate Income
# -1                                                                           0.0
# -3                                                                           0.0
# Agricultural Labourer                                                        0.0
# Car Guard                                                                    0.0
# Construction                                                                 0.0
# DK/RA                                                                        1.0
# Doctor                                                                       0.0
# Domestic Worker/Caretaker/Custodian                                          0.0
# Driver                                                                       0.0
# Factory Worker/Sweat Shop                                                    0.0
# Hawker (no fixed location)                                                   0.0
# Housewife/Homemaker                                                          0.0
# Journalist/Media Professional                                                0.0
# Lawyer                                                                       0.0
# Mechanic                                                                     1.0
# Missionary/Religious work                                                    0.0
# NGO                                                                          0.0
# Not working                                                                  4.0
# Own Business/Businessman/Businesswoman                                       0.0
# Petty Trading (fixed location)                                               0.0
# Primary or Secondary School Student                                          1.0
# Restaurant Employee                                                          1.0
# Security Guard                                                               0.0
# Shoe Repair                                                                  0.0
# Small Scale Farmer                                                           0.0
# Teacher                                                                      0.0
# University/technikon/correspondence student                                  0.0
# Volunteer Work                                                               1.0
#
# 303 Current Employment Status                Working full-time (formal/informal sector)  \
# 300 Means to Generate Income
# -1                                                                                  0.0
# -3                                                                                  0.0
# Agricultural Labourer                                                               4.0
# Car Guard                                                                           0.0
# Construction                                                                       20.0
# DK/RA                                                                              14.0
# Doctor                                                                              3.0
# Domestic Worker/Caretaker/Custodian                                                21.0
# Driver                                                                             12.0
# Factory Worker/Sweat Shop                                                          15.0
# Hawker (no fixed location)                                                          6.0
# Housewife/Homemaker                                                                 0.0
# Journalist/Media Professional                                                       3.0
# Lawyer                                                                              0.0
# Mechanic                                                                            6.0
# Missionary/Religious work                                                           0.0
# NGO                                                                                 2.0
# Not working                                                                        36.0
# Own Business/Businessman/Businesswoman                                             22.0
# Petty Trading (fixed location)                                                      9.0
# Primary or Secondary School Student                                                14.0
# Restaurant Employee                                                                14.0
# Security Guard                                                                     17.0
# Shoe Repair                                                                         1.0
# Small Scale Farmer                                                                  4.0
# Teacher                                                                            14.0
# University/technikon/correspondence student                                        12.0
# Volunteer Work                                                                      1.0
#
# 303 Current Employment Status                Working part-time (formal/informal sector)
# 300 Means to Generate Income
# -1                                                                                  0.0
# -3                                                                                  0.0
# Agricultural Labourer                                                               0.0
# Car Guard                                                                           0.0
# Construction                                                                       10.0
# DK/RA                                                                               7.0
# Doctor                                                                              0.0
# Domestic Worker/Caretaker/Custodian                                                15.0
# Driver                                                                              3.0
# Factory Worker/Sweat Shop                                                           7.0
# Hawker (no fixed location)                                                          6.0
# Housewife/Homemaker                                                                 0.0
# Journalist/Media Professional                                                       0.0
# Lawyer                                                                              0.0
# Mechanic                                                                            2.0
# Missionary/Religious work                                                           0.0
# NGO                                                                                 0.0
# Not working                                                                        14.0
# Own Business/Businessman/Businesswoman                                              3.0
# Petty Trading (fixed location)                                                      4.0
# Primary or Secondary School Student                                                 4.0
# Restaurant Employee                                                                 4.0
# Security Guard                                                                      4.0
# Shoe Repair                                                                         0.0
# Small Scale Farmer                                                                  0.0
# Teacher                                                                             1.0
# University/technikon/correspondence student                                         7.0
# Volunteer Work                                                                      0.0
# <AxesSubplot:ylabel='300 Means to Generate Income'>

# %%
V = ['303 Current Employment Status', '301 Economic Activity ']

subset = survey[V]
subset['count'] = 1

categories = subset.groupby(V[1]).count().reset_index().sort_values(by='count', ascending=False)

display(categories.head(20))

# find top categories
topcats = ['Na', '99', '-3', 'Not Working', 'Business', 'Petty Trading', 'Mechanic', 'Hawking', 'Own Business', 'Nothing', 'Security Guard', 'Student', 'Driving', 'Domestic Worker', 'Hawker', 'Teaching', 'Construction']

# replace all lesser categories
subset.loc[~(subset['301 Economic Activity '].isin(topcats)), '301 Economic Activity '] = 'Other Activity'
display(subset)
counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)
display(counts)

counts = counts.drop(axis='columns', labels=['-1', '-3']).drop(axis='rows', labels=['99', '-3', 'Na', 'Other Activity'])


counts.plot(kind='barh', stacked=True,
            figsize=(8.5,5))
# Out:
#     301 Economic Activity   303 Current Employment Status  count
# 408                     Na                             60     60
# 16                      99                             57     57
# 2                       -3                             54     54
# 425            Not Working                             44     44
# 708             Unemployed                             35     35
# 51                Business                             30     30
# 475          Petty Trading                             26     26
# 388               Mechanic                             25     25
# 218                Hawking                             25     25
# 454           Own Business                             24     24
# 430                Nothing                             21     21
# 540         Security Guard                             19     19
# 666                Student                             19     19
# 154                Driving                             18     18
# 146        Domestic Worker                             18     18
# 217                 Hawker                             17     17
# 688               Teaching                             14     14
# 364  Kpadamopuni@Gmail.Com                             11     11
# 783                Working                             10     10
# 102           Construction                             10     10
#                             303 Current Employment Status  \
# ID
# 276785                                                 -3
# 276788                                                 -1
# 276802                                  Doing casual jobs
# 276814                                  Doing casual jobs
# 276822         Working part-time (formal/informal sector)
# ...                                                   ...
# 297661        University/technikon/correspondence student
# 297663  Self-employed (run small business/income gener...
# 297666         Working full-time (formal/informal sector)
# 297667        University/technikon/correspondence student
# 297668         Working full-time (formal/informal sector)
#
#        301 Economic Activity   count
# ID
# 276785                     -3      1
# 276788         Other Activity      1
# 276802         Other Activity      1
# 276814         Other Activity      1
# 276822               Teaching      1
# ...                       ...    ...
# 297661         Other Activity      1
# 297663         Other Activity      1
# 297666         Other Activity      1
# 297667         Other Activity      1
# 297668         Other Activity      1
#
# [1644 rows x 3 columns]
# 303 Current Employment Status   -1   -3  Casual employment/temporary worker  \
# 301 Economic Activity
# -3                             0.0  1.0                                 2.0
# 99                             0.0  0.0                                 1.0
# Business                       0.0  0.0                                 0.0
# Construction                   0.0  0.0                                 3.0
# Domestic Worker                0.0  0.0                                 0.0
# Driving                        0.0  0.0                                 1.0
# Hawker                         0.0  0.0                                 0.0
# Hawking                        0.0  0.0                                 3.0
# Mechanic                       0.0  0.0                                 2.0
# Na                             0.0  0.0                                 2.0
# Not Working                    0.0  0.0                                 4.0
# Nothing                        0.0  0.0                                 0.0
# Other Activity                 3.0  0.0                                67.0
# Own Business                   0.0  0.0                                 0.0
# Petty Trading                  0.0  0.0                                 0.0
# Security Guard                 0.0  0.0                                 1.0
# Student                        0.0  0.0                                 1.0
# Teaching                       0.0  1.0                                 2.0
#
# 303 Current Employment Status  Doing casual jobs  Housewife/homemaker  Other  \
# 301 Economic Activity
# -3                                           1.0                  0.0    0.0
# 99                                           1.0                  1.0    2.0
# Business                                     1.0                  0.0    0.0
# Construction                                 1.0                  0.0    0.0
# Domestic Worker                              4.0                  0.0    0.0
# Driving                                      0.0                  0.0    3.0
# Hawker                                       1.0                  0.0    0.0
# Hawking                                      4.0                  0.0    1.0
# Mechanic                                     1.0                  0.0    1.0
# Na                                           3.0                  1.0    4.0
# Not Working                                  4.0                  0.0    3.0
# Nothing                                      0.0                  0.0    0.0
# Other Activity                              88.0                 23.0   68.0
# Own Business                                 0.0                  0.0    0.0
# Petty Trading                                2.0                  0.0    1.0
# Security Guard                               2.0                  0.0    1.0
# Student                                      1.0                  0.0    3.0
# Teaching                                     0.0                  0.0    0.0
#
# 303 Current Employment Status  Self-employed (run small business/income generation project)  \
# 301 Economic Activity
# -3                                                                           9.0
# 99                                                                           3.0
# Business                                                                    22.0
# Construction                                                                 2.0
# Domestic Worker                                                              5.0
# Driving                                                                      3.0
# Hawker                                                                      10.0
# Hawking                                                                     14.0
# Mechanic                                                                     7.0
# Na                                                                          17.0
# Not Working                                                                  9.0
# Nothing                                                                      4.0
# Other Activity                                                             433.0
# Own Business                                                                22.0
# Petty Trading                                                               22.0
# Security Guard                                                               3.0
# Student                                                                      1.0
# Teaching                                                                     1.0
#
# 303 Current Employment Status  Unemployed   \
# 301 Economic Activity
# -3                                    20.0
# 99                                    32.0
# Business                               6.0
# Construction                           2.0
# Domestic Worker                        2.0
# Driving                                4.0
# Hawker                                 0.0
# Hawking                                3.0
# Mechanic                               2.0
# Na                                    21.0
# Not Working                           20.0
# Nothing                               14.0
# Other Activity                       189.0
# Own Business                           1.0
# Petty Trading                          0.0
# Security Guard                         3.0
# Student                                5.0
# Teaching                               1.0
#
# 303 Current Employment Status  University/technikon/correspondence student  \
# 301 Economic Activity
# -3                                                                     4.0
# 99                                                                     6.0
# Business                                                               0.0
# Construction                                                           0.0
# Domestic Worker                                                        0.0
# Driving                                                                0.0
# Hawker                                                                 0.0
# Hawking                                                                0.0
# Mechanic                                                               0.0
# Na                                                                     4.0
# Not Working                                                            2.0
# Nothing                                                                0.0
# Other Activity                                                        38.0
# Own Business                                                           0.0
# Petty Trading                                                          0.0
# Security Guard                                                         0.0
# Student                                                                8.0
# Teaching                                                               0.0
#
# 303 Current Employment Status  Voluntary worker (receive no money)  \
# 301 Economic Activity
# -3                                                             0.0
# 99                                                             1.0
# Business                                                       0.0
# Construction                                                   0.0
# Domestic Worker                                                0.0
# Driving                                                        0.0
# Hawker                                                         0.0
# Hawking                                                        0.0
# Mechanic                                                       1.0
# Na                                                             1.0
# Not Working                                                    1.0
# Nothing                                                        0.0
# Other Activity                                                 5.0
# Own Business                                                   0.0
# Petty Trading                                                  0.0
# Security Guard                                                 0.0
# Student                                                        0.0
# Teaching                                                       0.0
#
# 303 Current Employment Status  Working full-time (formal/informal sector)  \
# 301 Economic Activity
# -3                                                                   12.0
# 99                                                                    7.0
# Business                                                              1.0
# Construction                                                          0.0
# Domestic Worker                                                       3.0
# Driving                                                               7.0
# Hawker                                                                4.0
# Hawking                                                               0.0
# Mechanic                                                              9.0
# Na                                                                    3.0
# Not Working                                                           0.0
# Nothing                                                               1.0
# Other Activity                                                      187.0
# Own Business                                                          1.0
# Petty Trading                                                         1.0
# Security Guard                                                        7.0
# Student                                                               0.0
# Teaching                                                              7.0
#
# 303 Current Employment Status  Working part-time (formal/informal sector)
# 301 Economic Activity
# -3                                                                    5.0
# 99                                                                    3.0
# Business                                                              0.0
# Construction                                                          2.0
# Domestic Worker                                                       4.0
# Driving                                                               0.0
# Hawker                                                                2.0
# Hawking                                                               0.0
# Mechanic                                                              2.0
# Na                                                                    4.0
# Not Working                                                           1.0
# Nothing                                                               2.0
# Other Activity                                                       62.0
# Own Business                                                          0.0
# Petty Trading                                                         0.0
# Security Guard                                                        2.0
# Student                                                               0.0
# Teaching                                                              2.0
# <AxesSubplot:ylabel='301 Economic Activity '>

# %%
V = ['303 Current Employment Status', '307 Kind of Work']

subset = survey[V]
subset['count'] = 1
counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)
display(counts)

counts = counts.drop(axis='columns', labels=['-1', '-3']).drop(axis='rows', labels=['-1', '-3'])

counts.plot(kind='barh', stacked=True,
            figsize=(8.5,5))
# Out:
# 303 Current Employment Status                        -1   -3  \
# 307 Kind of Work
# -1                                                  3.0  0.0
# -3                                                  0.0  2.0
# Casual employment/temporary worker                  0.0  0.0
# Doing casual jobs                                   0.0  0.0
# Housewife/homemaker                                 0.0  0.0
# Other (specify)                                     0.0  0.0
# Self-employed (run small business/income genera...  0.0  0.0
# Unemployed                                          0.0  0.0
# University/technikon/correspondence student         0.0  0.0
# Voluntary worker (receive no money)                 0.0  0.0
# Working full-time (formal/informal sector)          0.0  0.0
# Working part-time (formal/informal sector)          0.0  0.0
#
# 303 Current Employment Status                       Casual employment/temporary worker  \
# 307 Kind of Work
# -1                                                                                 0.0
# -3                                                                                 2.0
# Casual employment/temporary worker                                                74.0
# Doing casual jobs                                                                  8.0
# Housewife/homemaker                                                                0.0
# Other (specify)                                                                    1.0
# Self-employed (run small business/income genera...                                 0.0
# Unemployed                                                                         0.0
# University/technikon/correspondence student                                        0.0
# Voluntary worker (receive no money)                                                0.0
# Working full-time (formal/informal sector)                                         1.0
# Working part-time (formal/informal sector)                                         3.0
#
# 303 Current Employment Status                       Doing casual jobs  \
# 307 Kind of Work
# -1                                                                0.0
# -3                                                                7.0
# Casual employment/temporary worker                               15.0
# Doing casual jobs                                                87.0
# Housewife/homemaker                                               1.0
# Other (specify)                                                   1.0
# Self-employed (run small business/income genera...                2.0
# Unemployed                                                        1.0
# University/technikon/correspondence student                       0.0
# Voluntary worker (receive no money)                               0.0
# Working full-time (formal/informal sector)                        0.0
# Working part-time (formal/informal sector)                        0.0
#
# 303 Current Employment Status                       Housewife/homemaker  \
# 307 Kind of Work
# -1                                                                  0.0
# -3                                                                  0.0
# Casual employment/temporary worker                                  0.0
# Doing casual jobs                                                   0.0
# Housewife/homemaker                                                23.0
# Other (specify)                                                     1.0
# Self-employed (run small business/income genera...                  0.0
# Unemployed                                                          0.0
# University/technikon/correspondence student                         1.0
# Voluntary worker (receive no money)                                 0.0
# Working full-time (formal/informal sector)                          0.0
# Working part-time (formal/informal sector)                          0.0
#
# 303 Current Employment Status                       Other  \
# 307 Kind of Work
# -1                                                    0.0
# -3                                                    1.0
# Casual employment/temporary worker                    1.0
# Doing casual jobs                                     0.0
# Housewife/homemaker                                   0.0
# Other (specify)                                      55.0
# Self-employed (run small business/income genera...   15.0
# Unemployed                                            4.0
# University/technikon/correspondence student           2.0
# Voluntary worker (receive no money)                   0.0
# Working full-time (formal/informal sector)            5.0
# Working part-time (formal/informal sector)            4.0
#
# 303 Current Employment Status                       Self-employed (run small business/income generation project)  \
# 307 Kind of Work
# -1                                                                                                0.0
# -3                                                                                                7.0
# Casual employment/temporary worker                                                                2.0
# Doing casual jobs                                                                                 1.0
# Housewife/homemaker                                                                               1.0
# Other (specify)                                                                                  11.0
# Self-employed (run small business/income genera...                                              559.0
# Unemployed                                                                                        3.0
# University/technikon/correspondence student                                                       0.0
# Voluntary worker (receive no money)                                                               0.0
# Working full-time (formal/informal sector)                                                        3.0
# Working part-time (formal/informal sector)                                                        0.0
#
# 303 Current Employment Status                       Unemployed   \
# 307 Kind of Work
# -1                                                          0.0
# -3                                                          3.0
# Casual employment/temporary worker                          1.0
# Doing casual jobs                                           1.0
# Housewife/homemaker                                         1.0
# Other (specify)                                             7.0
# Self-employed (run small business/income genera...         15.0
# Unemployed                                                293.0
# University/technikon/correspondence student                 2.0
# Voluntary worker (receive no money)                         0.0
# Working full-time (formal/informal sector)                  1.0
# Working part-time (formal/informal sector)                  1.0
#
# 303 Current Employment Status                       University/technikon/correspondence student  \
# 307 Kind of Work
# -1                                                                                          0.0
# -3                                                                                          1.0
# Casual employment/temporary worker                                                          0.0
# Doing casual jobs                                                                           0.0
# Housewife/homemaker                                                                         0.0
# Other (specify)                                                                             0.0
# Self-employed (run small business/income genera...                                          0.0
# Unemployed                                                                                  2.0
# University/technikon/correspondence student                                                59.0
# Voluntary worker (receive no money)                                                         0.0
# Working full-time (formal/informal sector)                                                  0.0
# Working part-time (formal/informal sector)                                                  0.0
#
# 303 Current Employment Status                       Voluntary worker (receive no money)  \
# 307 Kind of Work
# -1                                                                                  0.0
# -3                                                                                  0.0
# Casual employment/temporary worker                                                  0.0
# Doing casual jobs                                                                   0.0
# Housewife/homemaker                                                                 0.0
# Other (specify)                                                                     0.0
# Self-employed (run small business/income genera...                                  0.0
# Unemployed                                                                          0.0
# University/technikon/correspondence student                                         0.0
# Voluntary worker (receive no money)                                                 9.0
# Working full-time (formal/informal sector)                                          0.0
# Working part-time (formal/informal sector)                                          0.0
#
# 303 Current Employment Status                       Working full-time (formal/informal sector)  \
# 307 Kind of Work
# -1                                                                                         0.0
# -3                                                                                         3.0
# Casual employment/temporary worker                                                         1.0
# Doing casual jobs                                                                          0.0
# Housewife/homemaker                                                                        0.0
# Other (specify)                                                                            3.0
# Self-employed (run small business/income genera...                                         2.0
# Unemployed                                                                                 0.0
# University/technikon/correspondence student                                                0.0
# Voluntary worker (receive no money)                                                        1.0
# Working full-time (formal/informal sector)                                               232.0
# Working part-time (formal/informal sector)                                                 8.0
#
# 303 Current Employment Status                       Working part-time (formal/informal sector)
# 307 Kind of Work
# -1                                                                                         0.0
# -3                                                                                         3.0
# Casual employment/temporary worker                                                         1.0
# Doing casual jobs                                                                          5.0
# Housewife/homemaker                                                                        0.0
# Other (specify)                                                                            0.0
# Self-employed (run small business/income genera...                                         2.0
# Unemployed                                                                                 1.0
# University/technikon/correspondence student                                                0.0
# Voluntary worker (receive no money)                                                        1.0
# Working full-time (formal/informal sector)                                                13.0
# Working part-time (formal/informal sector)                                                65.0
# <AxesSubplot:ylabel='307 Kind of Work'>

# %%
V = ['300 Means to Generate Income', '301 Economic Activity ']

subset = survey[V]
subset['count'] = 1

categories = subset.groupby(V[1]).count().reset_index().sort_values(by='count', ascending=False)

display(categories.head(20))

# find top categories
topcats = ['Na', '99', '-3', 'Not Working', 'Business', 'Petty Trading', 'Mechanic', 'Hawking', 'Own Business', 'Nothing', 'Security Guard', 'Student', 'Driving', 'Domestic Worker', 'Hawker', 'Teaching', 'Construction']

# replace all lesser categories
subset.loc[~(subset['301 Economic Activity '].isin(topcats)), '301 Economic Activity '] = 'Other Activity'
display(subset)
counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)
display(counts)

counts = counts.drop(axis='columns', labels=['-1', '-3']).drop(axis='rows', labels=['99', '-3', 'Na', 'Other Activity'])


counts.plot(kind='barh', stacked=True,
            figsize=(8.5,5))

# %% [markdown]
# ## 310 Send Money

# %%
sbar(['310 Send Money', '320 Financial Support'], ['grey', 'darkgrey', 'red', 'green'])
# Out:
# 310 Send Money          -1   -3     No    Yes
# 320 Financial Support
# -1                     3.0  0.0    0.0    0.0
# -3                     0.0  4.0    0.0    1.0
# No                     0.0  0.0  552.0  699.0
# Yes                    0.0  0.0  209.0  176.0

# %% [markdown]
# ## 334 Optimism

# %%
sbar(['334 Optimism ', '330 Change in Economic Status'], ['grey', 'darkgrey', 'red', 'green'])
# Out:
# 334 Optimism                                   -1   -3  Beyond control  \
# 330 Change in Economic Status
# -1                                            3.0  0.0             0.0
# -3                                            0.0  5.0             0.0
# Better off economically than you are now      0.0  1.0           131.0
# DK/RA (do not read)                           0.0  0.0             6.0
# Has always lived in City Name (donâ€™t read)  0.0  0.0            38.0
# Not Applicable                                0.0  0.0             8.0
# The same                                      0.0  0.0            72.0
# Worse off economically than you are now       0.0  0.0           106.0
#
# 334 Optimism                                  Can overcome  DK/RA
# 330 Change in Economic Status
# -1                                                     0.0    0.0
# -3                                                     0.0    0.0
# Better off economically than you are now             543.0   13.0
# DK/RA (do not read)                                   10.0    6.0
# Has always lived in City Name (donâ€™t read)         138.0    3.0
# Not Applicable                                        44.0    7.0
# The same                                             159.0    9.0
# Worse off economically than you are now              332.0   10.0

# %%
sbar(['334 Optimism ', '331 Future Economic Status'], ['grey', 'darkgrey', 'red', 'green'])
# Out:
# 334 Optimism                                   -1   -3  Beyond control  \
# 331 Future Economic Status
# -1                                            3.0  0.0             0.0
# -3                                            0.0  5.0             0.0
# Dk/Ra (Do Not Read)                           0.0  0.0            58.0
# Has Always Lived In City Name (Donâ€™T Read)  0.0  0.0            49.0
# No                                            0.0  0.0            63.0
# Not Applicable                                0.0  0.0            15.0
# Yes                                           0.0  1.0           176.0
#
# 334 Optimism                                  Can overcome  DK/RA
# 331 Future Economic Status
# -1                                                     0.0    0.0
# -3                                                     0.0    0.0
# Dk/Ra (Do Not Read)                                   65.0    8.0
# Has Always Lived In City Name (Donâ€™T Read)         159.0    5.0
# No                                                    94.0    7.0
# Not Applicable                                        51.0    7.0
# Yes                                                  857.0   21.0

# %%
sbar(['334 Optimism ', '332 Economic Outlook'], ['grey', 'darkgrey', 'red', 'green'])
# Out:
# 334 Optimism           -1   -3  Beyond control  Can overcome  DK/RA
# 332 Economic Outlook
# -1                    3.0  0.0             0.0           0.0    0.0
# -3                    0.0  5.0             0.0           0.0    0.0
# Dk/Ra                 0.0  0.0             7.0          10.0    4.0
# No                    0.0  0.0           105.0         588.0   25.0
# Yes                   0.0  1.0           249.0         628.0   19.0

# %%
sbar(['334 Optimism ', '333 Outlook on Life'], ['grey', 'darkgrey', 'red', 'green'])
# Out:
# 334 Optimism          -1   -3  Beyond control  Can overcome  DK/RA
# 333 Outlook on Life
# -1                   3.0  0.0             0.0           0.0    0.0
# -3                   0.0  5.0             0.0           0.0    0.0
# Dk/Ra                0.0  0.0            14.0          36.0   12.0
# No                   0.0  0.0            46.0         364.0   16.0
# Yes                  0.0  1.0           301.0         826.0   20.0

# %%
sbar(['334 Optimism ', '335 Adapted'], ['grey', 'darkgrey', 'red', 'green'])
# Out:
# 334 Optimism    -1   -3  Beyond control  Can overcome  DK/RA
# 335 Adapted
# -1             3.0  0.0             0.0           0.0    0.0
# -3             0.0  6.0             0.0           0.0    0.0
# DK/RA          0.0  0.0             5.0          14.0    6.0
# No             0.0  0.0           293.0        1006.0   34.0
# Yes            0.0  0.0            63.0         206.0    8.0

# %%
V = ['334 Optimism ', '205b Reason for leaving']

subset = survey[V]
subset['count'] = 1

counts = subset.groupby(V).count().reset_index().pivot(columns=V[0], index=V[1], values='count').fillna(0)
display(counts)

counts = counts.drop(axis='rows', labels=['-1', '-3']) #.drop(axis='columns', labels=['-1', '-3'])

counts.plot(kind='barh', stacked=True, color=['grey', 'darkgrey', 'red', 'green'],
            figsize=(8.5,5))
# Out:
# 334 Optimism                                         -1   -3  Beyond control  \
# 205b Reason for leaving
# -1                                                  2.0  4.0           290.0
# -3                                                  1.0  0.0             0.0
# Access to work                                      0.0  2.0            38.0
# Cost of rent (too high& somewhere else much che...  0.0  0.0             3.0
# Crime or insecurity                                 0.0  0.0             1.0
# DK/RA                                               0.0  0.0             1.0
# Education (for self or others)                      0.0  0.0             5.0
# Evicted                                             0.0  0.0             1.0
# Family reasons (unification / escape)               0.0  0.0            12.0
# Needed more space                                   0.0  0.0             2.0
# Other (specify)                                     0.0  0.0             7.0
# Place no longer available                           0.0  0.0             0.0
# Political reasons                                   0.0  0.0             1.0
#
# 334 Optimism                                        Can overcome  DK/RA
# 205b Reason for leaving
# -1                                                        1020.0   39.0
# -3                                                           0.0    0.0
# Access to work                                             101.0    5.0
# Cost of rent (too high& somewhere else much che...          11.0    0.0
# Crime or insecurity                                          3.0    0.0
# DK/RA                                                        2.0    1.0
# Education (for self or others)                              15.0    0.0
# Evicted                                                      2.0    0.0
# Family reasons (unification / escape)                       32.0    1.0
# Needed more space                                            7.0    0.0
# Other (specify)                                             29.0    2.0
# Place no longer available                                    4.0    0.0
# Political reasons                                            0.0    0.0
# <AxesSubplot:ylabel='205b Reason for leaving'>

# %%
sbar(['334 Optimism ', '8 Identify City '], ['grey', 'darkgrey', 'red', 'green'])
# Out:
# 334 Optimism       -1   -3  Beyond control  Can overcome  DK/RA
# 8 Identify City
# Accra             0.0  1.0            47.0         508.0   25.0
# Johannesburg      0.0  1.0           138.0         365.0   11.0
# Nairobi           3.0  4.0           176.0         353.0   12.0

# %%
sbar(['334 Optimism ', '100: Village, City or Town'], ['grey', 'darkgrey', 'red', 'green'])
# Out:
# 334 Optimism                 -1   -3  Beyond control  Can overcome  DK/RA
# 100: Village, City or Town
# City                        0.0  0.0            49.0         231.0    9.0
# Town                        1.0  4.0           107.0         507.0   23.0
# Village                     2.0  2.0           205.0         488.0   16.0

# %%
V = ['334 Optimism ', '100: Village, City or Town', '8 Identify City ']

subset = survey[V]
subset['count'] = 1
subset['Trajectory'] = subset['100: Village, City or Town'] + ' to ' + subset['8 Identify City ']
subset = subset[['334 Optimism ', 'Trajectory', 'count']]

display(subset)

counts = subset.groupby(['334 Optimism ', 'Trajectory']).count().reset_index().pivot(columns='334 Optimism ', index='Trajectory', values='count').fillna(0)
display(counts)

percents = counts.copy()
percents['Beyond control %'] = percents['Beyond control'] / percents.sum(axis=1)
percents['Can overcome %'] = percents['Can overcome'] / percents.sum(axis=1)
percents['Other %'] = 1 - percents['Beyond control %'] - percents['Can overcome %']
percents = percents[['Beyond control %', 'Can overcome %', 'Other %']]

display(counts)
display(percents)

#counts = counts.drop(axis='rows', labels=['-1', '-3']) #.drop(axis='columns', labels=['-1', '-3'])

counts.plot(kind='barh', stacked=True, color=['grey', 'darkgrey', 'red', 'green'],
            figsize=(8.5,5))

percents.plot(kind='barh', stacked=True, color=['red', 'green', 'grey'],
            figsize=(8.5,5))
# Out:
#          334 Optimism                Trajectory  count
# ID
# 276785              -3         Town to Nairobi       1
# 276788              -1      Village to Nairobi       1
# 276802    Can overcome         Town to Nairobi       1
# 276814              -3      Village to Nairobi       1
# 276822  Beyond control         City to Nairobi       1
# ...                ...                      ...    ...
# 297661    Can overcome     City to Johannesburg      1
# 297663    Can overcome  Village to Johannesburg      1
# 297666    Can overcome  Village to Johannesburg      1
# 297667    Can overcome     City to Johannesburg      1
# 297668    Can overcome     Town to Johannesburg      1
#
# [1644 rows x 3 columns]
# 334 Optimism              -1   -3  Beyond control  Can overcome  DK/RA
# Trajectory
# City to Accra            0.0  0.0            18.0         111.0    6.0
# City to Johannesburg     0.0  0.0            23.0         100.0    2.0
# City to Nairobi          0.0  0.0             8.0          20.0    1.0
# Town to Accra            0.0  1.0            21.0         304.0   13.0
# Town to Johannesburg     0.0  1.0            55.0         120.0    6.0
# Town to Nairobi          1.0  2.0            31.0          83.0    4.0
# Village to Accra         0.0  0.0             8.0          93.0    6.0
# Village to Johannesburg  0.0  0.0            60.0         145.0    3.0
# Village to Nairobi       2.0  2.0           137.0         250.0    7.0
# 334 Optimism              -1   -3  Beyond control  Can overcome  DK/RA
# Trajectory
# City to Accra            0.0  0.0            18.0         111.0    6.0
# City to Johannesburg     0.0  0.0            23.0         100.0    2.0
# City to Nairobi          0.0  0.0             8.0          20.0    1.0
# Town to Accra            0.0  1.0            21.0         304.0   13.0
# Town to Johannesburg     0.0  1.0            55.0         120.0    6.0
# Town to Nairobi          1.0  2.0            31.0          83.0    4.0
# Village to Accra         0.0  0.0             8.0          93.0    6.0
# Village to Johannesburg  0.0  0.0            60.0         145.0    3.0
# Village to Nairobi       2.0  2.0           137.0         250.0    7.0
# 334 Optimism             Beyond control %  Can overcome %   Other %
# Trajectory
# City to Accra                    0.133333        0.821411  0.045256
# City to Johannesburg             0.184000        0.798824  0.017176
# City to Nairobi                  0.275862        0.683157  0.040981
# Town to Accra                    0.061947        0.896591  0.041462
# Town to Johannesburg             0.302198        0.658248  0.039555
# Town to Nairobi                  0.256198        0.684501  0.059301
# Village to Accra                 0.074766        0.868552  0.056682
# Village to Johannesburg          0.288462        0.696150  0.015389
# Village to Nairobi               0.344221        0.627598  0.028181
# <AxesSubplot:ylabel='Trajectory'>

# %% [markdown]
# ## 700 Stay or go

# %%
v = '700 Stay or go'

V = [v, '100: Village, City or Town', '8 Identify City ']

subset = survey[V]
subset['count'] = 1
subset['Trajectory'] = subset['100: Village, City or Town'] + ' to ' + subset['8 Identify City ']
subset = subset[[v, 'Trajectory', 'count']]

display(subset)

counts = subset.groupby([v, 'Trajectory']).count().reset_index().pivot(columns=v, index='Trajectory', values='count').fillna(0)

percents = counts.copy()
percents['Leave %'] = percents['Leave the country'] / percents.sum(axis=1)
percents['Stay Neighborhood %'] = percents['Stay here in neighbourhood'] / percents.sum(axis=1)
percents['Stay Country %'] = percents['Stay in country but move to another neighbourhood'] / percents.sum(axis=1)
percents['Other %'] = 1 - percents['Leave %'] - percents['Stay Neighborhood %'] - percents['Stay Country %']
percents = percents[['Leave %', 'Stay Country %', 'Stay Neighborhood %',  'Other %']]

display(counts)
display(percents)

#counts = counts.drop(axis='rows', labels=['-1', '-3']) #.drop(axis='columns', labels=['-1', '-3'])

counts.plot(kind='barh', stacked=True, color=['grey', 'red', 'green', 'gold'],
            figsize=(8.5,5))

percents.plot(kind='barh', stacked=True, color=['red', 'gold', 'green', 'grey'],
            figsize=(8.5,5))
# Out:
#                                            700 Stay or go  \
# ID
# 276785                                                 -1
# 276788                                                 -1
# 276802  Stay in country but move to another neighbourhood
# 276814                                                 -1
# 276822                                                 -1
# ...                                                   ...
# 297661  Stay in country but move to another neighbourhood
# 297663                         Stay here in neighbourhood
# 297666                         Stay here in neighbourhood
# 297667  Stay in country but move to another neighbourhood
# 297668  Stay in country but move to another neighbourhood
#
#                      Trajectory  count
# ID
# 276785         Town to Nairobi       1
# 276788      Village to Nairobi       1
# 276802         Town to Nairobi       1
# 276814      Village to Nairobi       1
# 276822         City to Nairobi       1
# ...                         ...    ...
# 297661     City to Johannesburg      1
# 297663  Village to Johannesburg      1
# 297666  Village to Johannesburg      1
# 297667     City to Johannesburg      1
# 297668     Town to Johannesburg      1
#
# [1644 rows x 3 columns]
# 700 Stay or go             -1  Leave the country  Stay here in neighbourhood  \
# Trajectory
# City to Accra             1.0               32.0                        69.0
# City to Johannesburg      3.0               13.0                        84.0
# City to Nairobi           5.0                3.0                        13.0
# Town to Accra             3.0               84.0                       164.0
# Town to Johannesburg      2.0               15.0                       119.0
# Town to Nairobi           5.0               30.0                        60.0
# Village to Accra          0.0               34.0                        43.0
# Village to Johannesburg   0.0               25.0                       151.0
# Village to Nairobi       12.0               39.0                       292.0
#
# 700 Stay or go           Stay in country but move to another neighbourhood
# Trajectory
# City to Accra                                                         33.0
# City to Johannesburg                                                  25.0
# City to Nairobi                                                        8.0
# Town to Accra                                                         88.0
# Town to Johannesburg                                                  46.0
# Town to Nairobi                                                       26.0
# Village to Accra                                                      30.0
# Village to Johannesburg                                               32.0
# Village to Nairobi                                                    55.0
# 700 Stay or go            Leave %  Stay Country %  Stay Neighborhood %  \
# Trajectory
# City to Accra            0.237037        0.243099             0.510215
# City to Johannesburg     0.104000        0.198767             0.671441
# City to Nairobi          0.103448        0.270726             0.446682
# Town to Accra            0.247788        0.259028             0.483422
# Town to Johannesburg     0.082418        0.251729             0.653550
# Town to Nairobi          0.247934        0.213565             0.494854
# Village to Accra         0.317757        0.278504             0.400679
# Village to Johannesburg  0.120192        0.153223             0.725542
# Village to Nairobi       0.097990        0.137903             0.733488
#
# 700 Stay or go            Other %
# Trajectory
# City to Accra            0.009649
# City to Johannesburg     0.025792
# City to Nairobi          0.179143
# Town to Accra            0.009762
# Town to Johannesburg     0.012303
# Town to Nairobi          0.043647
# Village to Accra         0.003060
# Village to Johannesburg  0.001042
# Village to Nairobi       0.030619
# <AxesSubplot:ylabel='Trajectory'>

# %% [markdown]
# ## 226 COVID Impact on Mobility

# %%
v = '226 COVID Impact on Mobility'

V = [v, '100: Village, City or Town', '8 Identify City ']

subset = survey[V]
subset['count'] = 1
subset['Trajectory'] = subset['100: Village, City or Town'] + ' to ' + subset['8 Identify City ']
subset = subset[[v, 'Trajectory', 'count']]

display(subset)

counts = subset.groupby([v, 'Trajectory']).count().reset_index().pivot(columns=v, index='Trajectory', values='count').fillna(0)

percents = counts.copy()
percents['No %'] = percents['No'] / percents.sum(axis=1)
percents['Yes %'] = percents['Yes'] / percents.sum(axis=1)
percents['Other %'] = 1 - percents['No %'] - percents['Yes %']
percents = percents[['No %', 'Yes %', 'Other %']]

display(counts)
display(percents)

#counts = counts.drop(axis='rows', labels=['-1', '-3']) #.drop(axis='columns', labels=['-1', '-3'])

counts.plot(kind='barh', stacked=True, color=['grey', 'darkgrey', 'red', 'green', 'gold'],
            figsize=(8.5,5))

percents.plot(kind='barh', stacked=True, color=['red', 'green', 'grey'],
            figsize=(8.5,5))
# Out:
#        226 COVID Impact on Mobility               Trajectory  count
# ID
# 276785                           No         Town to Nairobi       1
# 276788                           -3      Village to Nairobi       1
# 276802                           No         Town to Nairobi       1
# 276814                           No      Village to Nairobi       1
# 276822                           No         City to Nairobi       1
# ...                             ...                      ...    ...
# 297661                           No     City to Johannesburg      1
# 297663                           No  Village to Johannesburg      1
# 297666                           No  Village to Johannesburg      1
# 297667                          Yes     City to Johannesburg      1
# 297668                           No     Town to Johannesburg      1
#
# [1644 rows x 3 columns]
# 226 COVID Impact on Mobility   -1   -3     No   Yes
# Trajectory
# City to Accra                 0.0  0.0  125.0  10.0
# City to Johannesburg          0.0  0.0  120.0   5.0
# City to Nairobi               0.0  0.0   25.0   4.0
# Town to Accra                 0.0  0.0  311.0  28.0
# Town to Johannesburg          0.0  0.0  174.0   8.0
# Town to Nairobi               0.0  0.0  105.0  16.0
# Village to Accra              0.0  0.0   94.0  13.0
# Village to Johannesburg       0.0  0.0  200.0   8.0
# Village to Nairobi            1.0  1.0  354.0  42.0
# 226 COVID Impact on Mobility      No %     Yes %   Other %
# Trajectory
# City to Accra                 0.925926  0.073569  0.000505
# City to Johannesburg          0.960000  0.039695  0.000305
# City to Nairobi               0.862069  0.133949  0.003982
# Town to Accra                 0.917404  0.082373  0.000223
# Town to Johannesburg          0.956044  0.043726  0.000230
# Town to Nairobi               0.867769  0.131290  0.000942
# Village to Accra              0.878505  0.120506  0.000989
# Village to Johannesburg       0.961538  0.038285  0.000177
# Village to Nairobi            0.889447  0.105292  0.005260
# <AxesSubplot:ylabel='Trajectory'>

# %%
counts.groupby('Trajectory').count.transform('sum') * 100
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 counts.groupby('Trajectory').count.transform('sum') * 100
#
# AttributeError: 'function' object has no attribute 'transform'

# %%
survey
# Out:
#         SITE_CODE  TARGET_LATITUDE  TARGET_LONGITUDE  SITE_LATITUDE  \
# ID
# 276785     276785         -1.21003          36.78920       -1.28892
# 276788     276788         -1.21010          36.78923       -1.28872
# 276802     276802         -1.21010          36.78923       -1.28884
# 276814     276814         -1.20987          36.78899       -1.28885
# 276822     276822         -1.20976          36.78888       -1.28873
# ...           ...              ...               ...            ...
# 297661     297661        -26.18491          28.05547      -26.18380
# 297663     297663        -26.18395          28.05459      -26.18328
# 297666     297666        -26.18565          28.05295      -26.18387
# 297667     297667        -26.18630          28.05320      -26.18374
# 297668     297668        -26.18634          28.05294      -26.18391
#
#         SITE_LONGITUDE  SURVEY DURATION IN MINUTES DATE_UPLOADED 3 Migrant  \
# ID
# 276785        36.80449                      139.96        3/4/21       Yes
# 276788        36.80430                       74.59        3/4/21       Yes
# 276802        36.80433                      244.90        3/5/21       Yes
# 276814        36.80435                      125.87        3/4/21       Yes
# 276822        36.80428                       80.18        3/4/21       Yes
# ...                ...                         ...           ...       ...
# 297661        28.05302                       62.78       4/16/21       Yes
# 297663        28.05690                       73.30       4/16/21        No
# 297666        28.05308                       72.04       4/16/21        No
# 297667        28.05300                       54.73       4/16/21        No
# 297668        28.05626                       63.45       4/16/21       Yes
#
#        4 Gender  4 Other Gender  ...                 236 Current Residence  \
# ID                               ...
# 276785     Male              -1  ...                     More than 2 years
# 276788     Male              -1  ...                                    -1
# 276802     Male              -1  ...  One year exactly or/More than a year
# 276814     Male              -1  ...                     More than 2 years
# 276822   Female              -1  ...  One year exactly or/More than a year
# ...         ...             ...  ...                                   ...
# 297661   Female              -1  ...                                    -1
# 297663     Male              -1  ...                     More than 2 years
# 297666     Male              -1  ...                     More than 2 years
# 297667     Male              -1  ...  One year exactly or/More than a year
# 297668   Female              -1  ...  One year exactly or/More than a year
#
#        Migrant Quota Category 237 Returned      238 Places Returned To   \
# ID
# 276785   Medium-Term Resident           No                           -1
# 276788                    NaN           -1                           -1
# 276802           New Resident           No                           -1
# 276814   Medium-Term Resident  Yes& I Have          Nakuru^1^~Kisumu^2^
# 276822           New Resident           No                           -1
# ...                       ...          ...                          ...
# 297661                    NaN           -1                           -1
# 297663   Medium-Term Resident           No                           -1
# 297666   Medium-Term Resident  Yes& I Have  Yeoville^4^~Bloemfontein^2^
# 297667           New Resident  Yes& I Have                  Sandton^10^
# 297668           New Resident  Yes& I Have               Khayelitsha^3^
#
#        Unnamed: 326 Unnamed: 327 Unnamed: 328  Unnamed: 329 Unnamed: 330  \
# ID
# 276785          NaN          NaN          NaN           NaN          NaN
# 276788          NaN          NaN          NaN           NaN          NaN
# 276802          NaN          NaN          NaN           NaN          NaN
# 276814          NaN          NaN          NaN           NaN          NaN
# 276822          NaN          NaN          NaN           NaN          NaN
# ...             ...          ...          ...           ...          ...
# 297661          NaN          NaN          NaN           NaN          NaN
# 297663          NaN          NaN          NaN           NaN          NaN
# 297666          NaN          NaN          NaN           NaN          NaN
# 297667          NaN          NaN          NaN           NaN          NaN
# 297668          NaN          NaN          NaN           NaN          NaN
#
#        Unnamed: 331
# ID
# 276785          NaN
# 276788          NaN
# 276802          NaN
# 276814          NaN
# 276822          NaN
# ...             ...
# 297661          NaN
# 297663          NaN
# 297666          NaN
# 297667          NaN
# 297668          NaN
#
# [1644 rows x 332 columns]

# %%
survey[['100: Village, City or Town', '8 Identify City ']]
# Out:
#        100: Village, City or Town 8 Identify City
# ID
# 276785                       Town         Nairobi
# 276788                    Village         Nairobi
# 276802                       Town         Nairobi
# 276814                    Village         Nairobi
# 276822                       City         Nairobi
# ...                           ...              ...
# 297661                       City     Johannesburg
# 297663                    Village     Johannesburg
# 297666                    Village     Johannesburg
# 297667                       City     Johannesburg
# 297668                       Town     Johannesburg
#
# [1644 rows x 2 columns]

# %%
accra_ids = survey[survey['8 Identify City '].eq('Accra ')]

display(accra_ids) 
display(accra_ids['8 Identify City '])
accra_ids.index
# Out:
#         SITE_CODE  TARGET_LATITUDE  TARGET_LONGITUDE  SITE_LATITUDE  \
# ID
# 277933     277933          5.65003          -0.19394        5.63666
# 278053     278053          5.64907          -0.19409        5.63870
# 278067     278067          5.64980          -0.19092        5.63665
# 278076     278076          5.65003          -0.19394        5.69919
# 278077     278077          5.70639          -0.16915        5.70634
# ...           ...              ...               ...            ...
# 290682     290682          5.66749          -0.15784        5.67016
# 290683     290683          5.54373          -0.22518        5.54529
# 290686     290686          5.67226          -0.15250        5.68597
# 290687     290687          5.67834          -0.16514        5.67821
# 290689     290689          5.73275          -0.15210        5.68654
#
#         SITE_LONGITUDE  SURVEY DURATION IN MINUTES DATE_UPLOADED 3 Migrant  \
# ID
# 277933        -0.18040                      311.23        3/6/21       Yes
# 278053        -0.17833                      291.01        3/7/21       Yes
# 278067        -0.18040                      289.21        3/7/21       Yes
# 278076        -0.16976                      209.03        3/7/21       Yes
# 278077        -0.16909                     2229.94        3/7/21       Yes
# ...                ...                         ...           ...       ...
# 290682        -0.16235                       61.79       3/31/21       Yes
# 290683        -0.22479                       60.26       3/31/21        No
# 290686        -0.16912                       66.39       3/31/21       Yes
# 290687        -0.16655                       52.79       3/31/21       Yes
# 290689        -0.16862                       71.60       3/31/21       Yes
#
#        4 Gender  4 Other Gender  ... 236 Current Residence  \
# ID                               ...
# 277933     Male              -1  ...                    -1
# 278053     Male              -1  ...                    -1
# 278067   Female              -1  ...     More than 2 years
# 278076     Male              -1  ...                    -1
# 278077     Male              -1  ...     More than 2 years
# ...         ...             ...  ...                   ...
# 290682     Male              -1  ...                    -1
# 290683     Male              -1  ...     More than 8 years
# 290686     Male              -1  ...                    -1
# 290687     Male              -1  ...                    -1
# 290689     Male              -1  ...                    -1
#
#        Migrant Quota Category 237 Returned 238 Places Returned To   \
# ID
# 277933                    NaN           -1                      -1
# 278053                    NaN           -1                      -1
# 278067   Medium-Term Resident  Yes& I Have                      -3
# 278076                    NaN           -1                      -1
# 278077   Medium-Term Resident           No                      -1
# ...                       ...          ...                     ...
# 290682                    NaN           -1                      -1
# 290683     Long-Term Resident  Yes& I Have      Kuje ^3^~Abuja ^2^
# 290686                    NaN           -1                      -1
# 290687                    NaN           -1                      -1
# 290689                    NaN           -1                      -1
#
#        Unnamed: 326 Unnamed: 327 Unnamed: 328  Unnamed: 329 Unnamed: 330  \
# ID
# 277933          NaN          NaN          NaN           NaN          NaN
# 278053          NaN          NaN          NaN           NaN          NaN
# 278067          NaN          NaN          NaN           NaN          NaN
# 278076          NaN          NaN          NaN           NaN          NaN
# 278077          NaN          NaN          NaN           NaN          NaN
# ...             ...          ...          ...           ...          ...
# 290682          NaN          NaN          NaN           NaN          NaN
# 290683          NaN          NaN          NaN           NaN          NaN
# 290686          NaN          NaN          NaN           NaN          NaN
# 290687          NaN          NaN          NaN           NaN          NaN
# 290689          NaN          NaN          NaN           NaN          NaN
#
#        Unnamed: 331
# ID
# 277933          NaN
# 278053          NaN
# 278067          NaN
# 278076          NaN
# 278077          NaN
# ...             ...
# 290682          NaN
# 290683          NaN
# 290686          NaN
# 290687          NaN
# 290689          NaN
#
# [581 rows x 332 columns]
# ID
# 277933    Accra
# 278053    Accra
# 278067    Accra
# 278076    Accra
# 278077    Accra
#            ...
# 290682    Accra
# 290683    Accra
# 290686    Accra
# 290687    Accra
# 290689    Accra
# Name: 8 Identify City , Length: 581, dtype: object
# Int64Index([277933, 278053, 278067, 278076, 278077, 278081, 278084, 278086,
#             278087, 278386,
#             ...
#             290671, 290677, 290678, 290679, 290680, 290682, 290683, 290686,
#             290687, 290689],
#            dtype='int64', name='ID', length=581)

# %%
accra_orig = orig[orig.index.isin(accra_ids.index)]
display(accra_orig)

accra_curL = curL[curL.index.isin(accra_ids.index)]
display(accra_curL)
# Out:
#               birthyear   age  duration  interval  \
# respondentID
# 278077             1966    55       0.0     581.0
# 278081             1983    38       NaN       NaN
# 278084               -3  2024       NaN       NaN
# 278086             1977    44       0.0      61.0
# 278087             1983    38       NaN       NaN
# ...                 ...   ...       ...       ...
# 290650             1979    42       NaN       NaN
# 290651             1990    31       NaN       NaN
# 290670             1985    36       0.0     300.0
# 290678             1972    49       NaN       NaN
# 290683             1984    37       0.0     240.0
#
#                                      location_name location_type  \
# respondentID
# 278077                ('Ejisu', 'Kumasi', 'Ghana')        origin
# 278081            ('Surelere', 'Lagos', 'Nigeria')        origin
# 278084                                         NaN        origin
# 278086            ('Kokomlemle', 'Accra', 'Ghana')        origin
# 278087                                         NaN        origin
# ...                                            ...           ...
# 290650        ('Suuru', 'Birnin Kebbi', 'Nigeria')        origin
# 290651            ('Atakpamã©', 'Kpalime', 'Togo')        origin
# 290670              ('Ejigbo', 'Lagos', 'Nigeria')        origin
# 290678           ('Kpowelin', 'Zwedru', 'Liberia')        origin
# 290683                ('Kuje', 'Abuga', 'Nigeria')        origin
#
#                                 location_latlon  \
# respondentID
# 278077                  (6.7163307, -1.5009105)
# 278081                                      NaN
# 278084                                      NaN
# 278086        (5.5755147, -0.20887310000000003)
# 278087                                      NaN
# ...                                         ...
# 290650                                      NaN
# 290651                                      NaN
# 290670          (6.5507230000000005, 3.3067225)
# 290678                                      NaN
# 290683           (8.879631199999999, 7.2272022)
#
#               distance_from_origin_location_km  \
# respondentID
# 278077                                     0.0
# 278081                                     NaN
# 278084                                     NaN
# 278086                                     0.0
# 278087                                     NaN
# ...                                        ...
# 290650                                     NaN
# 290651                                     NaN
# 290670                                     0.0
# 290678                                     NaN
# 290683                                     0.0
#
#               distance_from_previous_location_km  \
# respondentID
# 278077                                       0.0
# 278081                                       NaN
# 278084                                       NaN
# 278086                                       0.0
# 278087                                       NaN
# ...                                          ...
# 290650                                       NaN
# 290651                                       NaN
# 290670                                       0.0
# 290678                                       NaN
# 290683                                       0.0
#
#               distance_from_properties_owned_km  ...  \
# respondentID                                     ...
# 278077                                      NaN  ...
# 278081                                      NaN  ...
# 278084                                      NaN  ...
# 278086                                      NaN  ...
# 278087                                      NaN  ...
# ...                                         ...  ...
# 290650                                      NaN  ...
# 290651                                      NaN  ...
# 290670                                      NaN  ...
# 290678                                      NaN  ...
# 290683                                      NaN  ...
#
#                                                 work_aspiration  \
# respondentID
# 278077                                       Spare Parts Dealer
# 278081        Dealer In Glasses For Designing Doors And Windows
# 278084                                                  Trading
# 278086                                        Trade In Textiles
# 278087                                               Footballer
# ...                                                         ...
# 290650                  Butcher But Import Livestock From Niger
# 290651                                                 Mechanic
# 290670                                Own A Big Electronic Shop
# 290678                                               Contractor
# 290683                                             Own Business
#
#               financial_support children children_since_leaving p_kmGeo  \
# respondentID
# 278077                    200.0      Yes                      1     0.0
# 278081                    300.0      Yes                      2     NaN
# 278084                      NaN      Yes                      0     NaN
# 278086                    500.0      Yes                     -3     0.0
# 278087                    100.0       No                     -1     NaN
# ...                         ...      ...                    ...     ...
# 290650                    400.0      Yes                     -3     NaN
# 290651                  30000.0      Yes                     -3     NaN
# 290670                    500.0       No                     -1     0.0
# 290678                      NaN      Yes                      2     NaN
# 290683                    400.0      Yes                      1     0.0
#
#               p_kmGrC O_kmGeo  O_kmGrC       lat       lon
# respondentID
# 278077            0.0     0.0      0.0  6.716331 -1.500911
# 278081            NaN     NaN      NaN       NaN       NaN
# 278084            NaN     NaN      NaN       NaN       NaN
# 278086            0.0     0.0      0.0  5.575515 -0.208873
# 278087            NaN     NaN      NaN       NaN       NaN
# ...               ...     ...      ...       ...       ...
# 290650            NaN     NaN      NaN       NaN       NaN
# 290651            NaN     NaN      NaN       NaN       NaN
# 290670            0.0     0.0      0.0  6.550723  3.306722
# 290678            NaN     NaN      NaN       NaN       NaN
# 290683            0.0     0.0      0.0  8.879631  7.227202
#
# [356 rows x 24 columns]
#               birthyear   age  duration  interval  \
# respondentID
# 278077             1966    55     671.0       0.0
# 278081             1983    38       0.0       0.0
# 278084               -3  2024       0.0       0.0
# 278086             1977    44      61.0       0.0
# 278087             1983    38       0.0       0.0
# ...                 ...   ...       ...       ...
# 290651             1990    31       0.0       0.0
# 290670             1985    36     427.0       0.0
# 290678             1972    49       0.0       0.0
# 290678             1972    49       0.0       0.0
# 290683             1984    37     324.0       0.0
#
#                                  location_name     location_type  \
# respondentID
# 278077            ('Madina', 'Accra', 'Ghana')  current location
# 278081            ('Madina', 'Accra', 'Ghana')  current location
# 278084            ('Madina', 'Accra', 'Ghana')  current location
# 278086            ('Madina', 'Accra', 'Ghana')  current location
# 278087            ('Madina', 'Accra', 'Ghana')  current location
# ...                                        ...               ...
# 290651        ('Old Fadama', 'Accra', 'Ghana')  current location
# 290670        ('Old Fadama', 'Accra', 'Ghana')  current location
# 290678        ('James Town', 'Accra', 'Ghana')  current location
# 290678        ('James Town', 'Accra', 'Ghana')  current location
# 290683        ('Old Fadama', 'Accra', 'Ghana')  current location
#
#                                         location_latlon  \
# respondentID
# 278077                (5.6864962, -0.16770520000000003)
# 278081                (5.6864962, -0.16770520000000003)
# 278084                (5.6864962, -0.16770520000000003)
# 278086                (5.6864962, -0.16770520000000003)
# 278087                (5.6864962, -0.16770520000000003)
# ...                                                 ...
# 290651                (5.5488671, -0.22252159999999999)
# 290670                (5.5488671, -0.22252159999999999)
# 290678        (5.535796599999999, -0.21036370000000001)
# 290678        (5.535796599999999, -0.21036370000000001)
# 290683                (5.5488671, -0.22252159999999999)
#
#               distance_from_origin_location_km  \
# respondentID
# 278077                              186.387383
# 278081                                0.000000
# 278084                                0.000000
# 278086                               13.092930
# 278087                                0.000000
# ...                                        ...
# 290651                                0.000000
# 290670                              406.099628
# 290678                                0.000000
# 290678                                0.000000
# 290683                              901.352167
#
#               distance_from_previous_location_km  \
# respondentID
# 278077                                  1.954785
# 278081                                  0.000000
# 278084                                  0.000000
# 278086                                 13.092930
# 278087                                  0.000000
# ...                                          ...
# 290651                                  0.000000
# 290670                                  0.000000
# 290678                                  0.000000
# 290678                                  0.000000
# 290683                                935.968422
#
#               distance_from_properties_owned_km  ...  \
# respondentID                                     ...
# 278077                                      NaN  ...
# 278081                                      NaN  ...
# 278084                                      NaN  ...
# 278086                                      NaN  ...
# 278087                                      NaN  ...
# ...                                         ...  ...
# 290651                                      NaN  ...
# 290670                                      NaN  ...
# 290678                                      NaN  ...
# 290678                                      NaN  ...
# 290683                                      NaN  ...
#
#                                                 work_aspiration  \
# respondentID
# 278077                                       Spare Parts Dealer
# 278081        Dealer In Glasses For Designing Doors And Windows
# 278084                                                  Trading
# 278086                                        Trade In Textiles
# 278087                                               Footballer
# ...                                                         ...
# 290651                                                 Mechanic
# 290670                                Own A Big Electronic Shop
# 290678                                               Contractor
# 290678                                               Contractor
# 290683                                             Own Business
#
#               financial_support children children_since_leaving     p_kmGeo  \
# respondentID
# 278077                    200.0      Yes                      1    1.954785
# 278081                    300.0      Yes                      2    0.000000
# 278084                      NaN      Yes                      0    0.000000
# 278086                    500.0      Yes                     -3   13.092930
# 278087                    100.0       No                     -1    0.000000
# ...                         ...      ...                    ...         ...
# 290651                  30000.0      Yes                     -3    0.000000
# 290670                    500.0       No                     -1    0.000000
# 290678                      NaN      Yes                      2    0.000000
# 290678                      NaN      Yes                      2    0.000000
# 290683                    400.0      Yes                      1  935.968422
#
#                  p_kmGrC     O_kmGeo     O_kmGrC       lat       lon
# respondentID
# 278077          1.965516  186.387383  186.635719  5.686496 -0.167705
# 278081          0.000000    0.000000    0.000000  5.686496 -0.167705
# 278084          0.000000    0.000000    0.000000  5.686496 -0.167705
# 278086         13.154605   13.092930   13.154605  5.686496 -0.167705
# 278087          0.000000    0.000000    0.000000  5.686496 -0.167705
# ...                  ...         ...         ...       ...       ...
# 290651          0.000000    0.000000    0.000000  5.548867 -0.222522
# 290670          0.000000  406.099628  405.832499  5.548867 -0.222522
# 290678          0.000000    0.000000    0.000000  5.535797 -0.210364
# 290678          0.000000    0.000000    0.000000  5.535797 -0.210364
# 290683        935.942999  901.352167  901.296363  5.548867 -0.222522
#
# [363 rows x 24 columns]

# %%
A = accra_curL[['distance_from_origin_location_km', 'location_name', 'location_latlon']]
B = accra_orig[['location_name', 'location_latlon']]

accra_OD = A.join(B, how='inner', lsuffix='_O', rsuffix='_D').sort_values('distance_from_origin_location_km', ascending=False)
accra_OD = accra_OD[~(accra_OD['distance_from_origin_location_km'].eq(0))].dropna(axis='rows', subset=['location_latlon_D'])
accra_OD
# Out:
#               distance_from_origin_location_km  \
# respondentID
# 282623                            13164.817731
# 288542                             8636.687459
# 284149                             2043.354639
# 289117                             1636.406244
# 289525                             1542.947991
# ...                                        ...
# 288712                                3.001162
# 287259                                3.001162
# 287404                                1.975834
# 281972                                1.954785
# 284615                                1.954785
#
#                                location_name_O  \
# respondentID
# 282623            ('Madina', 'Accra', 'Ghana')
# 288542            ('Madina', 'Accra', 'Ghana')
# 284149            ('Madina', 'Accra', 'Ghana')
# 289117            ('Madina', 'Accra', 'Ghana')
# 289525        ('Old Fadama', 'Accra', 'Ghana')
# ...                                        ...
# 288712        ('James Town', 'Accra', 'Ghana')
# 287259        ('James Town', 'Accra', 'Ghana')
# 287404        ('James Town', 'Accra', 'Ghana')
# 281972            ('Madina', 'Accra', 'Ghana')
# 284615            ('Madina', 'Accra', 'Ghana')
#
#                                       location_latlon_O  \
# respondentID
# 282623                (5.6864962, -0.16770520000000003)
# 288542                (5.6864962, -0.16770520000000003)
# 284149                (5.6864962, -0.16770520000000003)
# 289117                (5.6864962, -0.16770520000000003)
# 289525                (5.5488671, -0.22252159999999999)
# ...                                                 ...
# 288712        (5.535796599999999, -0.21036370000000001)
# 287259        (5.535796599999999, -0.21036370000000001)
# 287404        (5.535796599999999, -0.21036370000000001)
# 281972                (5.6864962, -0.16770520000000003)
# 284615                (5.6864962, -0.16770520000000003)
#
#                                      location_name_D  \
# respondentID
# 282623           ('Kasama', 'Ziguinchor', 'Senegal')
# 288542           ('Mile 25', 'Abakaliki', 'Nigeria')
# 284149        ('Imo State', 'Anarba State', 'Ghana')
# 289117                  ('Diffa', 'Niamey', 'Niger')
# 289525             ('Goudoumaria', 'Diffa', 'Niger')
# ...                                              ...
# 288712                 ('Chorkor', 'Accra', 'Ghana')
# 287259                 ('Chorkor', 'Accra', 'Ghana')
# 287404                 ('Fadaman', 'Accra', 'Ghana')
# 281972                  ('Adenta', 'Accra', 'Ghana')
# 284615           ('Adanse Fumso', 'Kumasi', 'Ghana')
#
#                                      location_latlon_D
# respondentID
# 282623                       (14.6027831, 121.0050491)
# 288542               (-33.0257159, -71.47651979999999)
# 284149               (-4.3125032999999995, 15.2893612)
# 289117                (13.313074900000002, 12.6136611)
# 289525        (13.710699499999999, 11.188533900000001)
# ...                                                ...
# 288712               (5.5273187, -0.23609339999999998)
# 287259               (5.5273187, -0.23609339999999998)
# 287404               (5.5488671, -0.22252159999999999)
# 281972                         (5.7041391, -0.1687965)
# 284615                         (5.7041391, -0.1687965)
#
# [284 rows x 5 columns]

# %%
accra_OD['distance_from_origin_location_km']
# Out:
#    distance_from_origin_location_km               location_name_O  \
# 0                        160.874430  ('Madina', 'Accra', 'Ghana')
# 1                        844.692547                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
#
#                    location_latlon_O           location_name_D  \
# 0  (5.6864962, -0.16770520000000003)  ('Lome', 'Lome', 'Togo')
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
#
#                   location_latlon_D
# 0    (5.861010299999999, -0.657934)
# 1              (6.130419, 1.215829)
# 2            (6.5536094, 7.4143061)
# 3  (9.4051992, -0.8423985999999999)

# %%
accra_OD.to_csv('230924_Ghana_OD.csv')

# %%
traj[traj.respondentID.eq(282623)]
# Out:
#             respondentID  birthyear  age  duration  interval  \
# Unnamed: 0
# 282623.00         282623       1986   35       0.0     360.0
# 282623.01         282623       1986   35     360.0      27.0
# 282623.02         282623       1986   35       NaN       NaN
# 282623.03         282623       1986   35       NaN       NaN
# 282623.04         282623       1986   35       NaN       NaN
# 282623.05         282623       1986   35     387.0       0.0
# 282623.06         282623       1986   35     436.0      49.0
# 282623.07         282623       1986   35     442.0       6.0
# 282623.08         282623       1986   35     460.0      18.0
# 282623.09         282623       1986   35     556.0      96.0
# 282623.10         282623       1986   35     676.0     120.0
#
#                                   location_name            location_type  \
# Unnamed: 0
# 282623.00   ('Kasama', 'Ziguinchor', 'Senegal')                   origin
# 282623.01         ('Awoshie', 'Accra', 'Ghana')   1st migration location
# 282623.02         ('Saasabi', 'Accra', 'Ghana')   2nd migration location
# 282623.03                                   NaN   3rd migration location
# 282623.04                                   NaN   4th migration location
# 282623.05          ('Madina', 'Accra', 'Ghana')         current location
# 282623.06          ('Madina', 'Accra', 'Ghana')         current location
# 282623.07                                   NaN    aspiration 2-6 months
# 282623.08                                   NaN       planned move 2 yrs
# 282623.09                                   NaN      planned move 10 yrs
# 282623.10                                   NaN  planned move retirement
#
#                               location_latlon  \
# Unnamed: 0
# 282623.00           (14.6027831, 121.0050491)
# 282623.01    (5.5872779999999995, -0.2780901)
# 282623.02                                 NaN
# 282623.03                                 NaN
# 282623.04                                 NaN
# 282623.05   (5.6864962, -0.16770520000000003)
# 282623.06   (5.6864962, -0.16770520000000003)
# 282623.07                                 NaN
# 282623.08                                 NaN
# 282623.09                                 NaN
# 282623.10                                 NaN
#
#             distance_from_origin_location_km  \
# Unnamed: 0
# 282623.00                           0.000000
# 282623.01                       13180.059986
# 282623.02                                NaN
# 282623.03                                NaN
# 282623.04                                NaN
# 282623.05                       13164.817731
# 282623.06                       13164.817731
# 282623.07                                NaN
# 282623.08                                NaN
# 282623.09                                NaN
# 282623.10                                NaN
#
#             distance_from_previous_location_km  ...  work_aspiration  \
# Unnamed: 0                                      ...
# 282623.00                             0.000000  ...        Same Work
# 282623.01                         13180.059986  ...        Same Work
# 282623.02                                  NaN  ...        Same Work
# 282623.03                                  NaN  ...        Same Work
# 282623.04                                  NaN  ...        Same Work
# 282623.05                            16.429647  ...        Same Work
# 282623.06                             0.000000  ...        Same Work
# 282623.07                                  NaN  ...        Same Work
# 282623.08                                  NaN  ...        Same Work
# 282623.09                                  NaN  ...        Same Work
# 282623.10                                  NaN  ...        Same Work
#
#            financial_support  children children_since_leaving       p_kmGeo  \
# Unnamed: 0
# 282623.00              700.0       Yes                      0      0.000000
# 282623.01              700.0       Yes                      0  13180.059986
# 282623.02              700.0       Yes                      0           NaN
# 282623.03              700.0       Yes                      0           NaN
# 282623.04              700.0       Yes                      0           NaN
# 282623.05              700.0       Yes                      0     16.429647
# 282623.06              700.0       Yes                      0      0.000000
# 282623.07              700.0       Yes                      0           NaN
# 282623.08              700.0       Yes                      0           NaN
# 282623.09              700.0       Yes                      0           NaN
# 282623.10              700.0       Yes                      0           NaN
#
#                  p_kmGrC       O_kmGeo       O_kmGrC        lat         lon
# Unnamed: 0
# 282623.00       0.000000      0.000000      0.000000  14.602783  121.005049
# 282623.01   13165.031736  13180.059986  13165.031736   5.587278   -0.278090
# 282623.02            NaN           NaN           NaN        NaN         NaN
# 282623.03            NaN           NaN           NaN        NaN         NaN
# 282623.04            NaN           NaN           NaN        NaN         NaN
# 282623.05      16.459696  13164.817731  13149.786773   5.686496   -0.167705
# 282623.06       0.000000  13164.817731  13149.786773   5.686496   -0.167705
# 282623.07            NaN           NaN           NaN        NaN         NaN
# 282623.08            NaN           NaN           NaN        NaN         NaN
# 282623.09            NaN           NaN           NaN        NaN         NaN
# 282623.10            NaN           NaN           NaN        NaN         NaN
#
# [11 rows x 25 columns]

# %%
traj[traj.respondentID.eq(288542)]
# Out:
#             respondentID  birthyear  age  duration  interval  \
# Unnamed: 0
# 288542.00         288542       1998   23       0.0     209.0
# 288542.01         288542       1998   23     209.0       8.0
# 288542.02         288542       1998   23     217.0      38.0
# 288542.03         288542       1998   23       NaN       NaN
# 288542.04         288542       1998   23       NaN       NaN
# 288542.05         288542       1998   23     255.0       0.0
# 288542.06         288542       1998   23     293.0      38.0
# 288542.07         288542       1998   23     299.0       6.0
# 288542.08         288542       1998   23     317.0      18.0
# 288542.09         288542       1998   23     413.0      96.0
# 288542.10         288542       1998   23     533.0     120.0
#
#                                   location_name            location_type  \
# Unnamed: 0
# 288542.00   ('Mile 25', 'Abakaliki', 'Nigeria')                   origin
# 288542.01        ('Mile 2', 'Lagos', 'Nigeria')   1st migration location
# 288542.02          ('Madina', 'Accra', 'Ghana')   2nd migration location
# 288542.03                                   NaN   3rd migration location
# 288542.04                                   NaN   4th migration location
# 288542.05          ('Madina', 'Accra', 'Ghana')         current location
# 288542.06          ('Madina', 'Accra', 'Ghana')         current location
# 288542.07                                   NaN    aspiration 2-6 months
# 288542.08                                   NaN       planned move 2 yrs
# 288542.09                                   NaN      planned move 10 yrs
# 288542.10                                   NaN  planned move retirement
#
#                               location_latlon  \
# Unnamed: 0
# 288542.00   (-33.0257159, -71.47651979999999)
# 288542.01    (6.76194015, 3.2653968360756123)
# 288542.02   (5.6864962, -0.16770520000000003)
# 288542.03                                 NaN
# 288542.04                                 NaN
# 288542.05   (5.6864962, -0.16770520000000003)
# 288542.06   (5.6864962, -0.16770520000000003)
# 288542.07                                 NaN
# 288542.08                                 NaN
# 288542.09                                 NaN
# 288542.10                                 NaN
#
#             distance_from_origin_location_km  \
# Unnamed: 0
# 288542.00                           0.000000
# 288542.01                        9015.715837
# 288542.02                        8636.687459
# 288542.03                                NaN
# 288542.04                                NaN
# 288542.05                        8636.687459
# 288542.06                        8636.687459
# 288542.07                                NaN
# 288542.08                                NaN
# 288542.09                                NaN
# 288542.10                                NaN
#
#             distance_from_previous_location_km  ...          work_aspiration  \
# Unnamed: 0                                      ...
# 288542.00                             0.000000  ...  Sale 0F Car Spare Parts
# 288542.01                          9015.715837  ...  Sale 0F Car Spare Parts
# 288542.02                           398.106660  ...  Sale 0F Car Spare Parts
# 288542.03                                  NaN  ...  Sale 0F Car Spare Parts
# 288542.04                                  NaN  ...  Sale 0F Car Spare Parts
# 288542.05                             0.000000  ...  Sale 0F Car Spare Parts
# 288542.06                             0.000000  ...  Sale 0F Car Spare Parts
# 288542.07                                  NaN  ...  Sale 0F Car Spare Parts
# 288542.08                                  NaN  ...  Sale 0F Car Spare Parts
# 288542.09                                  NaN  ...  Sale 0F Car Spare Parts
# 288542.10                                  NaN  ...  Sale 0F Car Spare Parts
#
#            financial_support  children children_since_leaving      p_kmGeo  \
# Unnamed: 0
# 288542.00                NaN        No                     -1     0.000000
# 288542.01                NaN        No                     -1  9015.715837
# 288542.02                NaN        No                     -1   398.106660
# 288542.03                NaN        No                     -1          NaN
# 288542.04                NaN        No                     -1          NaN
# 288542.05                NaN        No                     -1     0.000000
# 288542.06                NaN        No                     -1     0.000000
# 288542.07                NaN        No                     -1          NaN
# 288542.08                NaN        No                     -1          NaN
# 288542.09                NaN        No                     -1          NaN
# 288542.10                NaN        No                     -1          NaN
#
#                 p_kmGrC      O_kmGeo      O_kmGrC        lat        lon
# Unnamed: 0
# 288542.00      0.000000     0.000000     0.000000 -33.025716 -71.476520
# 288542.01   9016.446840  9015.715837  9016.446840   6.761940   3.265397
# 288542.02    397.883136  8636.687459  8637.689732   5.686496  -0.167705
# 288542.03           NaN          NaN          NaN        NaN        NaN
# 288542.04           NaN          NaN          NaN        NaN        NaN
# 288542.05      0.000000  8636.687459  8637.689732   5.686496  -0.167705
# 288542.06      0.000000  8636.687459  8637.689732   5.686496  -0.167705
# 288542.07           NaN          NaN          NaN        NaN        NaN
# 288542.08           NaN          NaN          NaN        NaN        NaN
# 288542.09           NaN          NaN          NaN        NaN        NaN
# 288542.10           NaN          NaN          NaN        NaN        NaN
#
# [11 rows x 25 columns]

# %%
traj[traj.respondentID.eq(284149)]
# Out:
#             respondentID  birthyear  age  duration  interval  \
# Unnamed: 0
# 284149.00         284149       1983   38       0.0     240.0
# 284149.01         284149       1983   38     240.0      48.0
# 284149.02         284149       1983   38     288.0     130.0
# 284149.03         284149       1983   38       NaN       NaN
# 284149.04         284149       1983   38       NaN       NaN
# 284149.05         284149       1983   38     418.0       0.0
# 284149.06         284149       1983   38     574.0     156.0
# 284149.07         284149       1983   38     580.0       6.0
# 284149.08         284149       1983   38     598.0      18.0
# 284149.09         284149       1983   38     694.0      96.0
# 284149.10         284149       1983   38     814.0     120.0
#
#                                      location_name            location_type  \
# Unnamed: 0
# 284149.00   ('Imo State', 'Anarba State', 'Ghana')                   origin
# 284149.01          ('Gombe', 'Imo State', 'Ghana')   1st migration location
# 284149.02              ('Abuja', 'Abuja', 'Ghana')   2nd migration location
# 284149.03              ('Bayas', 'Accra', 'Ghana')   3rd migration location
# 284149.04             ('Madina', 'Accra', 'Ghana')   4th migration location
# 284149.05             ('Madina', 'Accra', 'Ghana')         current location
# 284149.06             ('Madina', 'Accra', 'Ghana')         current location
# 284149.07                                      NaN    aspiration 2-6 months
# 284149.08                                      NaN       planned move 2 yrs
# 284149.09                                      NaN      planned move 10 yrs
# 284149.10                                      NaN  planned move retirement
#
#                               location_latlon  \
# Unnamed: 0
# 284149.00   (-4.3125032999999995, 15.2893612)
# 284149.01     (9.04256615, 7.482005489275561)
# 284149.02   (5.6864962, -0.16770520000000003)
# 284149.03                                 NaN
# 284149.04                                 NaN
# 284149.05   (5.6864962, -0.16770520000000003)
# 284149.06   (5.6864962, -0.16770520000000003)
# 284149.07                                 NaN
# 284149.08                                 NaN
# 284149.09                                 NaN
# 284149.10                                 NaN
#
#             distance_from_origin_location_km  \
# Unnamed: 0
# 284149.00                           0.000000
# 284149.01                        1712.207753
# 284149.02                        2043.354639
# 284149.03                                NaN
# 284149.04                                NaN
# 284149.05                        2043.354639
# 284149.06                        2043.354639
# 284149.07                                NaN
# 284149.08                                NaN
# 284149.09                                NaN
# 284149.10                                NaN
#
#             distance_from_previous_location_km  ...  work_aspiration  \
# Unnamed: 0                                      ...
# 284149.00                             0.000000  ...               15
# 284149.01                          1712.207753  ...               15
# 284149.02                           922.414600  ...               15
# 284149.03                                  NaN  ...               15
# 284149.04                                  NaN  ...               15
# 284149.05                             0.000000  ...               15
# 284149.06                             0.000000  ...               15
# 284149.07                                  NaN  ...               15
# 284149.08                                  NaN  ...               15
# 284149.09                                  NaN  ...               15
# 284149.10                                  NaN  ...               15
#
#            financial_support  children children_since_leaving      p_kmGeo  \
# Unnamed: 0
# 284149.00              200.0       Yes                      3     0.000000
# 284149.01              200.0       Yes                      3  1712.207753
# 284149.02              200.0       Yes                      3   922.414600
# 284149.03              200.0       Yes                      3          NaN
# 284149.04              200.0       Yes                      3          NaN
# 284149.05              200.0       Yes                      3     0.000000
# 284149.06              200.0       Yes                      3     0.000000
# 284149.07              200.0       Yes                      3          NaN
# 284149.08              200.0       Yes                      3          NaN
# 284149.09              200.0       Yes                      3          NaN
# 284149.10              200.0       Yes                      3          NaN
#
#                 p_kmGrC      O_kmGeo      O_kmGrC       lat        lon
# Unnamed: 0
# 284149.00      0.000000     0.000000     0.000000 -4.312503  15.289361
# 284149.01   1718.787785  1712.207753  1718.787785  9.042566   7.482005
# 284149.02    922.323509  2043.354639  2045.079053  5.686496  -0.167705
# 284149.03           NaN          NaN          NaN       NaN        NaN
# 284149.04           NaN          NaN          NaN       NaN        NaN
# 284149.05      0.000000  2043.354639  2045.079053  5.686496  -0.167705
# 284149.06      0.000000  2043.354639  2045.079053  5.686496  -0.167705
# 284149.07           NaN          NaN          NaN       NaN        NaN
# 284149.08           NaN          NaN          NaN       NaN        NaN
# 284149.09           NaN          NaN          NaN       NaN        NaN
# 284149.10           NaN          NaN          NaN       NaN        NaN
#
# [11 rows x 25 columns]

# %%
traj[traj.respondentID.eq(289117)]
# Out:
#             respondentID  birthyear  age  duration  interval  \
# Unnamed: 0
# 289117.00         289117       1989   32       0.0     576.0
# 289117.01         289117       1989   32     576.0      48.0
# 289117.02         289117       1989   32     624.0      48.0
# 289117.03         289117       1989   32     672.0      96.0
# 289117.04         289117       1989   32       NaN       NaN
# 289117.05         289117       1989   32     768.0       0.0
# 289117.06         289117       1989   32     864.0      96.0
# 289117.07         289117       1989   32     870.0       6.0
# 289117.08         289117       1989   32     888.0      18.0
# 289117.09         289117       1989   32     984.0      96.0
# 289117.10         289117       1989   32    1104.0     120.0
#
#                              location_name            location_type  \
# Unnamed: 0
# 289117.00     ('Diffa', 'Niamey', 'Niger')                   origin
# 289117.01   ('Mamprobi', 'Accra', 'Ghana')   1st migration location
# 289117.02      ('Kasoa', 'Accra', 'Ghana')   2nd migration location
# 289117.03     ('Madina', 'Accra', 'Ghana')   3rd migration location
# 289117.04                              NaN   4th migration location
# 289117.05     ('Madina', 'Accra', 'Ghana')         current location
# 289117.06     ('Madina', 'Accra', 'Ghana')         current location
# 289117.07                              NaN    aspiration 2-6 months
# 289117.08                              NaN       planned move 2 yrs
# 289117.09                              NaN      planned move 10 yrs
# 289117.10                              NaN  planned move retirement
#
#                               location_latlon  \
# Unnamed: 0
# 289117.00    (13.313074900000002, 12.6136611)
# 289117.01   (5.5356856, -0.24027310000000002)
# 289117.02    (5.532573, -0.43749099999999996)
# 289117.03   (5.6864962, -0.16770520000000003)
# 289117.04                                 NaN
# 289117.05   (5.6864962, -0.16770520000000003)
# 289117.06   (5.6864962, -0.16770520000000003)
# 289117.07                                 NaN
# 289117.08                                 NaN
# 289117.09                                 NaN
# 289117.10                                 NaN
#
#             distance_from_origin_location_km  \
# Unnamed: 0
# 289117.00                           0.000000
# 289117.01                        1652.082214
# 289117.02                        1670.775636
# 289117.03                        1636.406244
# 289117.04                                NaN
# 289117.05                        1636.406244
# 289117.06                        1636.406244
# 289117.07                                NaN
# 289117.08                                NaN
# 289117.09                                NaN
# 289117.10                                NaN
#
#             distance_from_previous_location_km  ...  work_aspiration  \
# Unnamed: 0                                      ...
# 289117.00                             0.000000  ...            Trade
# 289117.01                          1652.082214  ...            Trade
# 289117.02                            21.855257  ...            Trade
# 289117.03                            34.396497  ...            Trade
# 289117.04                                  NaN  ...            Trade
# 289117.05                             0.000000  ...            Trade
# 289117.06                             0.000000  ...            Trade
# 289117.07                                  NaN  ...            Trade
# 289117.08                                  NaN  ...            Trade
# 289117.09                                  NaN  ...            Trade
# 289117.10                                  NaN  ...            Trade
#
#            financial_support  children children_since_leaving      p_kmGeo  \
# Unnamed: 0
# 289117.00                NaN       Yes                      2     0.000000
# 289117.01                NaN       Yes                      2  1652.082214
# 289117.02                NaN       Yes                      2    21.855257
# 289117.03                NaN       Yes                      2    34.396497
# 289117.04                NaN       Yes                      2          NaN
# 289117.05                NaN       Yes                      2     0.000000
# 289117.06                NaN       Yes                      2     0.000000
# 289117.07                NaN       Yes                      2          NaN
# 289117.08                NaN       Yes                      2          NaN
# 289117.09                NaN       Yes                      2          NaN
# 289117.10                NaN       Yes                      2          NaN
#
#                 p_kmGrC      O_kmGeo      O_kmGrC        lat        lon
# Unnamed: 0
# 289117.00      0.000000     0.000000     0.000000  13.313075  12.613661
# 289117.01   1653.016888  1652.082214  1653.016888   5.535686  -0.240273
# 289117.02     21.830189  1670.775636  1671.657246   5.532573  -0.437491
# 289117.03     34.413261  1636.406244  1637.271130   5.686496  -0.167705
# 289117.04           NaN          NaN          NaN        NaN        NaN
# 289117.05      0.000000  1636.406244  1637.271130   5.686496  -0.167705
# 289117.06      0.000000  1636.406244  1637.271130   5.686496  -0.167705
# 289117.07           NaN          NaN          NaN        NaN        NaN
# 289117.08           NaN          NaN          NaN        NaN        NaN
# 289117.09           NaN          NaN          NaN        NaN        NaN
# 289117.10           NaN          NaN          NaN        NaN        NaN
#
# [11 rows x 25 columns]

# %%
traj[traj.respondentID.eq(289525)]
# Out:
#             respondentID  birthyear  age  duration  interval  \
# Unnamed: 0
# 289525.00         289525       1980   41       0.0     240.0
# 289525.01         289525       1980   41     240.0      62.0
# 289525.02         289525       1980   41     302.0      73.0
# 289525.03         289525       1980   41     375.0      42.0
# 289525.04         289525       1980   41     417.0      25.0
# 289525.05         289525       1980   41     442.0       0.0
# 289525.06         289525       1980   41     523.0      81.0
# 289525.07         289525       1980   41     529.0       6.0
# 289525.08         289525       1980   41     547.0      18.0
# 289525.09         289525       1980   41     643.0      96.0
# 289525.10         289525       1980   41     763.0     120.0
#
#                                 location_name            location_type  \
# Unnamed: 0
# 289525.00   ('Goudoumaria', 'Diffa', 'Niger')                   origin
# 289525.01    ('Bawku', 'Bolgatanga', 'Ghana')   1st migration location
# 289525.02   ('Kintampo', 'Techiman', 'Ghana')   2nd migration location
# 289525.03        ('Suame', 'Kumasi', 'Ghana')   3rd migration location
# 289525.04       ('Madina', 'Adenta', 'Ghana')   4th migration location
# 289525.05    ('Old Fadama', 'Accra', 'Ghana')         current location
# 289525.06    ('Old Fadama', 'Accra', 'Ghana')         current location
# 289525.07                                 NaN    aspiration 2-6 months
# 289525.08                                 NaN       planned move 2 yrs
# 289525.09                                 NaN      planned move 10 yrs
# 289525.10                                 NaN  planned move retirement
#
#                                      location_latlon  \
# Unnamed: 0
# 289525.00   (13.710699499999999, 11.188533900000001)
# 289525.01         (11.0607602, -0.24228760000000002)
# 289525.02            (8.053714, -1.7289189999999999)
# 289525.03                    (6.7163628, -1.6369204)
# 289525.04          (5.6864962, -0.16770520000000003)
# 289525.05          (5.5488671, -0.22252159999999999)
# 289525.06          (5.5488671, -0.22252159999999999)
# 289525.07                                        NaN
# 289525.08                                        NaN
# 289525.09                                        NaN
# 289525.10                                        NaN
#
#             distance_from_origin_location_km  \
# Unnamed: 0
# 289525.00                           0.000000
# 289525.01                        1276.932675
# 289525.02                        1544.014705
# 289525.03                        1603.217926
# 289525.04                        1529.017731
# 289525.05                        1542.947991
# 289525.06                        1542.947991
# 289525.07                                NaN
# 289525.08                                NaN
# 289525.09                                NaN
# 289525.10                                NaN
#
#             distance_from_previous_location_km  ...  work_aspiration  \
# Unnamed: 0                                      ...
# 289525.00                             0.000000  ...    Self Employed
# 289525.01                          1276.932675  ...    Self Employed
# 289525.02                           370.472462  ...    Self Employed
# 289525.03                           148.249567  ...    Self Employed
# 289525.04                           198.518221  ...    Self Employed
# 289525.05                            16.386608  ...    Self Employed
# 289525.06                             0.000000  ...    Self Employed
# 289525.07                                  NaN  ...    Self Employed
# 289525.08                                  NaN  ...    Self Employed
# 289525.09                                  NaN  ...    Self Employed
# 289525.10                                  NaN  ...    Self Employed
#
#            financial_support  children children_since_leaving      p_kmGeo  \
# Unnamed: 0
# 289525.00                NaN       Yes                      1     0.000000
# 289525.01                NaN       Yes                      1  1276.932675
# 289525.02                NaN       Yes                      1   370.472462
# 289525.03                NaN       Yes                      1   148.249567
# 289525.04                NaN       Yes                      1   198.518221
# 289525.05                NaN       Yes                      1    16.386608
# 289525.06                NaN       Yes                      1     0.000000
# 289525.07                NaN       Yes                      1          NaN
# 289525.08                NaN       Yes                      1          NaN
# 289525.09                NaN       Yes                      1          NaN
# 289525.10                NaN       Yes                      1          NaN
#
#                 p_kmGrC      O_kmGeo      O_kmGrC        lat        lon
# Unnamed: 0
# 289525.00      0.000000     0.000000     0.000000  13.710700  11.188534
# 289525.01   1275.741950  1276.932675  1275.741950  11.060760  -0.242288
# 289525.02    371.979322  1544.014705  1543.750844   8.053714  -1.728919
# 289525.03    149.052509  1603.217926  1603.688870   6.716363  -1.636920
# 289525.04    198.724268  1529.017731  1530.527642   5.686496  -0.167705
# 289525.05     16.462060  1542.947991  1544.529011   5.548867  -0.222522
# 289525.06      0.000000  1542.947991  1544.529011   5.548867  -0.222522
# 289525.07           NaN          NaN          NaN        NaN        NaN
# 289525.08           NaN          NaN          NaN        NaN        NaN
# 289525.09           NaN          NaN          NaN        NaN        NaN
# 289525.10           NaN          NaN          NaN        NaN        NaN
#
# [11 rows x 25 columns]
