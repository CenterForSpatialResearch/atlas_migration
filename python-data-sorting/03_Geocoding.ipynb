# %%
"""
General Data Science Packages
"""
import numpy as np
import pandas as pd
import geopandas as gpd
# import fiona
# import shapely
from shapely.geometry import shape

"""
Data Managment Packages
"""
# import time
# import os
import ast

"""
Geocoding Packages
"""
# import geopy as gp
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from functools import partial

"""
Distance Calculations
"""
# from geopy.distance import geodesic
# from geopy.distance import great_circleQ

"""
Check Python Version
"""
# !python --version
# Out:
# Python 3.8.3

# %% [markdown]
# # 3. Geocoding

# %% [markdown]
# ## 3.0. Prepare the editted gazetteer

# %%
G_ = pd.read_csv('data_raw/editted_gazetteer/210829_editted_gazetteer.csv')

G_
# Out:
#                                                L1_orig  L2_orig L3_orig  \
# 0                                                   -3       -1      -1
# 1                                                   -1       -1      -1
# 2                                                   46       -1      -1
# 3                                                   99       -1      -1
# 4                                 37 Military Hospital       -1      -1
# ...                                                ...      ...     ...
# 8930                                       Westminster   London      Uk
# 8931                                            Wilcox  Georgia     Usa
# 8932  Would Wish To Move But Destination Still Unknown      NaN     NaN
# 8933                                              York     York  Canada
# 8934                                               NaN      NaN     NaN
#
#                                              tuple_orig        L1_edit  \
# 0                                    ('-3', '-1', '-1')             -3
# 1                                    ('-1', '-1', '-1')             -1
# 2                                    ('46', '-1', '-1')            -16
# 3                                    ('99', '-1', '-1')            -16
# 4                  ('37 Military Hospital', '-1', '-1')            -18
# ...                                                 ...            ...
# 8930                    ('Westminster', 'London', 'Uk')    Westminster
# 8931                       ('Wilcox', 'Georgia', 'Usa')  Wilcox County
# 8932  ('Would Wish To Move But Destination Still Unk...            -15
# 8933                         ('York', 'York', 'Canada')           York
# 8934                                       ('', '', '')            NaN
#
#       L1_chg  L2_edit  L2_chg                   L3_edit  L3_chg
# 0      False       -1   False                        -1   False
# 1      False       -1   False                        -1   False
# 2       True       -1   False                        -1   False
# 3       True       -1   False                        -1   False
# 4       True       -1   False                        -1   False
# ...      ...      ...     ...                       ...     ...
# 8930   False   London   False            United Kingdom    True
# 8931    True  Georgia   False  United States Of America    True
# 8932    True      -11    True                       -11    True
# 8933   False  Toronto    True                    Canada   False
# 8934   False      NaN   False                       NaN   False
#
# [8935 rows x 10 columns]

# %%
# run to reset the working dataframe to original dataframe
G = G_.copy()

# %% [markdown]
# ### 3.0.a. Read and check the original tuples in the editted gazetteer

# %%
# print columns and their position in the data
for i, col in enumerate(list(G.columns)):
    print(str(i) + '\t' + str(col))
# Out:
# 0	L1_orig
# 1	L2_orig
# 2	L3_orig
# 3	tuple_orig
# 4	L1_edit
# 5	L1_chg
# 6	L2_edit
# 7	L2_chg
# 8	L3_edit
# 9	L3_chg

# %% [markdown]
# ##### Check for any problematic duplicate tuples in the rows
#
# Since later the geodata queried will be merged based on the tuples, any duplicate tuples could create problems by reshaping the data. The relationship between original tuples and the cleaned tuples must be one-to-one.

# %%
# check for any potential row-wise errors
print('\nDuplicate rows?:')
print(G.duplicated().value_counts())

# check for duplicate tuples
print('\nUnique tuples?:')
print(G['tuple_orig'].is_unique)

if G['tuple_orig'].is_unique is False:
    
    print('\n======\n\nDUPLICATES DIAGNOSTIC:')
    
    G_dups = G.duplicated(subset='tuple_orig', keep=False)
    
    print('\nDuplicate original tuples counts: ')
    print(G_dups.value_counts())
    
    G_duprows = G.loc[G_dups == True, :]
    
    print('------')
    print('Same number of duplicate editted tuples? \n(If so, rows may be exactly duplicated and mostly likely can be dropped.)')
    print(G_duprows.duplicated(subset=['L1_Edit_Final', 'L2_Edit_Final', 'L3_Edit_Final'], keep=False).value_counts())
    
    print('\nIndices of the duplicated rows: ')
    print(G_duprows.index)
    
    G_dupcount = pd.DataFrame(G_duprows['tuple_orig'].value_counts()).reset_index()

    print('\nUnique tuples within the duplicated rows: ')
    print(len(G_dupcount.index))
    
    print('\nValue counts of tuples in duplicated rows: ')
    display(G_dupcount)
# Out:
# Duplicate rows?:
# False    8935
# dtype: int64
#
# Unique tuples?:
# True

# %% [markdown]
# ##### Function to evaluate the strings of the CSV as tuple literals

# %%
# function to map over the string elements of the dataframe
def str_eval(e):
    """
    A function to evaluate string element in a dataframe literally, such as the multilocation tuples.
    
    RETURNS: The Python literal. 
    """
    # 01 | Ensure the element is read by ast.literal_eval() as a string to avoid errors.
    e = str(e)
    
    # 02 | Filter out any null values
    if (e != 'nan'):
        
        # 03 | Evaluate the string literally
        try:
            ml = ast.literal_eval(e)
        
        # If unable to read the string, print it so it can be traced back to address issues
        except:
            print(e)
            ml = None
    
    # Return null values as null values
    else:
        ml = None
        
    return ml

# %% [markdown]
# ### 3.0.b Clean the editted columns to create the query columns

# %% [markdown]
# ##### Filter out null indicators

# %%
# list of bad values to avoid querying
badvals = ['NaN', '0', '-1', '-3', '1', '5', '-10', '-11', '-13', '-15', '-16', '-18']

G['L1_query'] = G['L1_edit'].replace(badvals, np.nan)
G['L2_query'] = G['L2_edit'].replace(badvals, np.nan)
G['L3_query'] = G['L3_edit'].replace(badvals, np.nan)

G
# Out:
#                                                L1_orig  L2_orig L3_orig  \
# 0                                                   -3       -1      -1
# 1                                                   -1       -1      -1
# 2                                                   46       -1      -1
# 3                                                   99       -1      -1
# 4                                 37 Military Hospital       -1      -1
# ...                                                ...      ...     ...
# 8930                                       Westminster   London      Uk
# 8931                                            Wilcox  Georgia     Usa
# 8932  Would Wish To Move But Destination Still Unknown      NaN     NaN
# 8933                                              York     York  Canada
# 8934                                               NaN      NaN     NaN
#
#                                              tuple_orig        L1_edit  \
# 0                                    ('-3', '-1', '-1')             -3
# 1                                    ('-1', '-1', '-1')             -1
# 2                                    ('46', '-1', '-1')            -16
# 3                                    ('99', '-1', '-1')            -16
# 4                  ('37 Military Hospital', '-1', '-1')            -18
# ...                                                 ...            ...
# 8930                    ('Westminster', 'London', 'Uk')    Westminster
# 8931                       ('Wilcox', 'Georgia', 'Usa')  Wilcox County
# 8932  ('Would Wish To Move But Destination Still Unk...            -15
# 8933                         ('York', 'York', 'Canada')           York
# 8934                                       ('', '', '')            NaN
#
#       L1_chg  L2_edit  L2_chg                   L3_edit  L3_chg  \
# 0      False       -1   False                        -1   False
# 1      False       -1   False                        -1   False
# 2       True       -1   False                        -1   False
# 3       True       -1   False                        -1   False
# 4       True       -1   False                        -1   False
# ...      ...      ...     ...                       ...     ...
# 8930   False   London   False            United Kingdom    True
# 8931    True  Georgia   False  United States Of America    True
# 8932    True      -11    True                       -11    True
# 8933   False  Toronto    True                    Canada   False
# 8934   False      NaN   False                       NaN   False
#
#            L1_query L2_query                  L3_query
# 0               NaN      NaN                       NaN
# 1               NaN      NaN                       NaN
# 2               NaN      NaN                       NaN
# 3               NaN      NaN                       NaN
# 4               NaN      NaN                       NaN
# ...             ...      ...                       ...
# 8930    Westminster   London            United Kingdom
# 8931  Wilcox County  Georgia  United States Of America
# 8932            NaN      NaN                       NaN
# 8933           York  Toronto                    Canada
# 8934            NaN      NaN                       NaN
#
# [8935 rows x 13 columns]

# %% [markdown]
# ##### Replace incomplete edits with original

# %%
for L in ['L1', 'L2']:
    
    # 01 | locate rows where the edit column is blank but the original column is not blank
    row_blank = G[G[(L+'_edit')].isna() & ~G[(L+'_orig')].isna()]

    print('======\n{} rows for {}'.format(len(row_blank.index), L))
    
    print('Before: ')
    display(row_blank[[L+'_orig', L+'_edit', L+'_query']].head(6))

    # 02 | put the original names back into the query column
    G.at[row_blank.index, L+'_query'] = G.loc[row_blank.index, L+'_orig']

    print('After: ')
    display(pd.DataFrame(G.loc[row_blank.index, L+'_query']).head(6))
# Out:
# ======
# 1560 rows for L1
# Before:
#                            L1_orig L1_edit L1_query
# 3239  Democratic Republic Of Congo     NaN      NaN
# 5075                          Juja     NaN      NaN
# 5081                 Mountain View     NaN      NaN
# 5084                        Wilson     NaN      NaN
# 5086                      Windhoek     NaN      NaN
# 5116           All Parts Of  Niger     NaN      NaN
# After:
#                           L1_query
# 3239  Democratic Republic Of Congo
# 5075                          Juja
# 5081                 Mountain View
# 5084                        Wilson
# 5086                      Windhoek
# 5116           All Parts Of  Niger
# ======
# 873 rows for L2
# Before:
#                   L2_orig L2_edit L2_query
# 5084               Wilson     NaN      NaN
# 5086             Windhoek     NaN      NaN
# 5091                Bilma     NaN      NaN
# 5092      Birmingham Koni     NaN      NaN
# 5098  Harobanda In Niamey     NaN      NaN
# 5104              Moradey     NaN      NaN
# After:
#                  L2_query
# 5084               Wilson
# 5086             Windhoek
# 5091                Bilma
# 5092      Birmingham Koni
# 5098  Harobanda In Niamey
# 5104              Moradey

# %%
for L in ['L1', 'L2']:

    # 01 | locate rows where a -19 was added for unsearchable
    row_19 = G[G[L+'_edit'] == '-19']

    print('======\n{} rows for {}'.format(len(row_blank.index), L))
    
    print('Before: ')
    display(row_19[[L+'_orig', L+'_edit', L+'_query']].head(6))

    # 02 | put the original names back into the query column
    G.at[row_19.index, L+'_query'] = G.loc[row_19.index, L+'_orig'].replace('-19', np.nan)

    print('After: ')
    display(pd.DataFrame(G.loc[row_19.index, L+'_query']).head(6))
# Out:
# ======
# 873 rows for L1
# Before:
#           L1_orig L1_edit L1_query
# 42            -19     -19      -19
# 230     Ashabiena     -19      -19
# 269  Benin  Dagbo     -19      -19
# 276         Dzefa     -19      -19
# 277          Ekpe     -19      -19
# 278      Fidzrose     -19      -19
# After:
#          L1_query
# 42            NaN
# 230     Ashabiena
# 269  Benin  Dagbo
# 276         Dzefa
# 277          Ekpe
# 278      Fidzrose
# ======
# 873 rows for L2
# Before:
#                   L2_orig L2_edit L2_query
# 250  Dakunbrua Banglacesh     -19      -19
# 262                  Weme     -19      -19
# 308            Kgamodishe     -19      -19
# 325            Nyamurenge     -19      -19
# 331                Ruvira     -19      -19
# 392                 Tutsi     -19      -19
# After:
#                  L2_query
# 250  Dakunbrua Banglacesh
# 262                  Weme
# 308            Kgamodishe
# 325            Nyamurenge
# 331                Ruvira
# 392                 Tutsi

# %% [markdown]
# ### 3.0.c. Bind query columns into multilocation tuples

# %%
# function to perform the binds
def bind(l1, l2, l3):
    """
    A function that binds column values into a multilocation array
    based on the column names passed in.
    
    RETURNS: An tuple of multilocation array(s).
    """
    # 01 | Create an array of strings from the values passed in 
    if all(l is np.nan for l in [l1, l2, l3]):
        return np.nan
    else:
        a = np.array([l1, l2, l3])
        t = tuple(a)
        
    return t

# %%
G['tuple_query'] = G.apply(lambda row : bind( row['L1_query'],
                                              row['L2_query'],
                                              row['L3_query'] ), axis=1)

display(G[['L1_query', 'L2_query', 'L3_query', 'tuple_query']])
# Out:
#            L1_query L2_query                  L3_query  \
# 0               NaN      NaN                       NaN
# 1               NaN      NaN                       NaN
# 2               NaN      NaN                       NaN
# 3               NaN      NaN                       NaN
# 4               NaN      NaN                       NaN
# ...             ...      ...                       ...
# 8930    Westminster   London            United Kingdom
# 8931  Wilcox County  Georgia  United States Of America
# 8932            NaN      NaN                       NaN
# 8933           York  Toronto                    Canada
# 8934            NaN      NaN                       NaN
#
#                                             tuple_query
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8930              (Westminster, London, United Kingdom)
# 8931  (Wilcox County, Georgia, United States Of Amer...
# 8932                                                NaN
# 8933                            (York, Toronto, Canada)
# 8934                                                NaN
#
# [8935 rows x 4 columns]

# %% [markdown]
# ### 3.0.d. Create Query Strings to call through Nominatim

# %%
# Method A: L1 + L3
G['str_query_A'] = G['L1_query'] + ', ' + G['L3_query']

# Method B: L1 + L2 + L3 (backup)
G['str_query_B'] = G['L1_query'] + ', ' + G['L2_query'] + ', ' + G['L3_query']

G
# Out:
#                                                L1_orig  L2_orig L3_orig  \
# 0                                                   -3       -1      -1
# 1                                                   -1       -1      -1
# 2                                                   46       -1      -1
# 3                                                   99       -1      -1
# 4                                 37 Military Hospital       -1      -1
# ...                                                ...      ...     ...
# 8930                                       Westminster   London      Uk
# 8931                                            Wilcox  Georgia     Usa
# 8932  Would Wish To Move But Destination Still Unknown      NaN     NaN
# 8933                                              York     York  Canada
# 8934                                               NaN      NaN     NaN
#
#                                              tuple_orig        L1_edit  \
# 0                                    ('-3', '-1', '-1')             -3
# 1                                    ('-1', '-1', '-1')             -1
# 2                                    ('46', '-1', '-1')            -16
# 3                                    ('99', '-1', '-1')            -16
# 4                  ('37 Military Hospital', '-1', '-1')            -18
# ...                                                 ...            ...
# 8930                    ('Westminster', 'London', 'Uk')    Westminster
# 8931                       ('Wilcox', 'Georgia', 'Usa')  Wilcox County
# 8932  ('Would Wish To Move But Destination Still Unk...            -15
# 8933                         ('York', 'York', 'Canada')           York
# 8934                                       ('', '', '')            NaN
#
#       L1_chg  L2_edit  L2_chg                   L3_edit  L3_chg  \
# 0      False       -1   False                        -1   False
# 1      False       -1   False                        -1   False
# 2       True       -1   False                        -1   False
# 3       True       -1   False                        -1   False
# 4       True       -1   False                        -1   False
# ...      ...      ...     ...                       ...     ...
# 8930   False   London   False            United Kingdom    True
# 8931    True  Georgia   False  United States Of America    True
# 8932    True      -11    True                       -11    True
# 8933   False  Toronto    True                    Canada   False
# 8934   False      NaN   False                       NaN   False
#
#            L1_query L2_query                  L3_query  \
# 0               NaN      NaN                       NaN
# 1               NaN      NaN                       NaN
# 2               NaN      NaN                       NaN
# 3               NaN      NaN                       NaN
# 4               NaN      NaN                       NaN
# ...             ...      ...                       ...
# 8930    Westminster   London            United Kingdom
# 8931  Wilcox County  Georgia  United States Of America
# 8932            NaN      NaN                       NaN
# 8933           York  Toronto                    Canada
# 8934            NaN      NaN                       NaN
#
#                                             tuple_query  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8930              (Westminster, London, United Kingdom)
# 8931  (Wilcox County, Georgia, United States Of Amer...
# 8932                                                NaN
# 8933                            (York, Toronto, Canada)
# 8934                                                NaN
#
#                                  string_query  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 8930              Westminster, United Kingdom
# 8931  Wilcox County, United States Of America
# 8932                                      NaN
# 8933                             York, Canada
# 8934                                      NaN
#
#                                   str_query_A  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 8930              Westminster, United Kingdom
# 8931  Wilcox County, United States Of America
# 8932                                      NaN
# 8933                             York, Canada
# 8934                                      NaN
#
#                                            str_query_B
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 8930               Westminster, London, United Kingdom
# 8931  Wilcox County, Georgia, United States Of America
# 8932                                               NaN
# 8933                             York, Toronto, Canada
# 8934                                               NaN
#
# [8935 rows x 17 columns]

# %% [markdown]
# ## 3.1. Query from Nominatim and Add Data to Gazetteer

# %% [markdown]
# ### 3.1.a. Querying for Method A: L1 + L3

# %% [markdown]
# ##### Create a filtered table of only valid and unique queries for Method A

# %%
print('\nUnique Multilocations: \n{}'.format(len(G['str_query_A'])))

to_query = G['str_query_A'].dropna()
print('\nNon-NaN Queries (Method A): \n{}'.format(len(query)))

query = G['str_query_A'].dropna().drop_duplicates()
print('\nUnique Queries (Method A): \n{}'.format(len(query)))
query = pd.DataFrame(query, index=query.index, columns=['str_query_A'])
query['result'] = None

display(query)
# Out:
# Unique Multilocations:
# 8935
#
# Non-NaN Queries (Method A):
# 3866
#
# Unique Queries (Method A):
# 3866
#                                   str_query_A result
# 5                                Accra, Ghana   None
# 6                             Achimota, Ghana   None
# 7                               Adenta, Ghana   None
# 11                        Agbogbloshie, Ghana   None
# 13                           Jamestown, Ghana   None
# ...                                       ...    ...
# 8922                     Victoria, Seychelles   None
# 8924                       Buginyanya, Uganda   None
# 8929              Westminster, United Kingdom   None
# 8931  Wilcox County, United States Of America   None
# 8933                             York, Canada   None
#
# [3866 rows x 2 columns]

# %% [markdown]
# ##### Query from Nominatim API

# %%
# 01 - Create and instance of a Nominatim class
geocoder = Nominatim(user_agent = 'mt')

# 02 - Rate limit to avoid timeout errors or being blocked by the API
geocode = RateLimiter(geocoder.geocode, min_delay_seconds=2, max_retries=2)

# CALL LOCATIONS FROM NOMINATIM
query['result'] = query['str_query_A'].apply(partial(geocode, exactly_one=0, addressdetails=1, extratags=1, geometry='geojson'))

# Back up the original query to avoid having to rerun the query
query_A_backup = query.copy()
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Saint Quen, France',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Saint+Quen%2C+France&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Saint+Quen%2C+France&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Saint+Quen%2C+France&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Saint Quen, France',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Saint+Quen%2C+France&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Saint+Quen%2C+France&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Saint+Quen%2C+France&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('Saint Quen, France',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Saint+Quen%2C+France&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Saint+Quen%2C+France&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Saint+Quen%2C+France&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Britain, United Kingdom',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Britain%2C+United+Kingdom&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Britain%2C+United+Kingdom&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Britain%2C+United+Kingdom&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Britain, United Kingdom',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Britain%2C+United+Kingdom&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Britain%2C+United+Kingdom&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Britain%2C+United+Kingdom&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('Britain, United Kingdom',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Britain%2C+United+Kingdom&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Britain%2C+United+Kingdom&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Britain%2C+United+Kingdom&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Manste Agbona, Ghana',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Manste+Agbona%2C+Ghana&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Manste+Agbona%2C+Ghana&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Manste+Agbona%2C+Ghana&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Manste Agbona, Ghana',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Manste+Agbona%2C+Ghana&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Manste+Agbona%2C+Ghana&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Manste+Agbona%2C+Ghana&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('Manste Agbona, Ghana',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Manste+Agbona%2C+Ghana&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Manste+Agbona%2C+Ghana&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Manste+Agbona%2C+Ghana&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Mile 2 Estate, Nigeria',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
# ...
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('No Area, South Africa',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=No+Area%2C+South+Africa&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=No+Area%2C+South+Africa&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=No+Area%2C+South+Africa&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('No Area, South Africa',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=No+Area%2C+South+Africa&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=No+Area%2C+South+Africa&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=No+Area%2C+South+Africa&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('No Area, South Africa',), **{'exactly_one': 0, 'addressdetails': 1, 'extratags': 1, 'geometry': 'geojson'}).
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 426, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 421, in _make_request
#     httplib_response = conn.getresponse()
#   File "D:\anaconda3\lib\http\client.py", line 1332, in getresponse
#     response.begin()
#   File "D:\anaconda3\lib\http\client.py", line 303, in begin
#     version, status, reason = self._read_status()
#   File "D:\anaconda3\lib\http\client.py", line 264, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "D:\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "D:\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "D:\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 428, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 335, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 752, in urlopen
#     return self.urlopen(
#   File "D:\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 724, in urlopen
#     retries = retries.increment(
#   File "D:\anaconda3\lib\site-packages\urllib3\util\retry.py", line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=No+Area%2C+South+Africa&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 383, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 543, in get
#     return self.request('GET', url, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\sessions.py", line 643, in send
#     r = adapter.send(request, **kwargs)
#   File "D:\anaconda3\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=No+Area%2C+South+Africa&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "D:\anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py", line 294, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "D:\anaconda3\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 373, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "D:\anaconda3\lib\site-packages\geopy\adapters.py", line 395, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=No+Area%2C+South+Africa&format=json&addressdetails=1&extratags=True&polygon_geojson=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))

# %% [markdown]
# ##### Extract the raw attribute of the nominatim result

# %%
# Get the raw attribute of the nominatim places result
def get_raw(x):
    if x is not None: r = [i.raw for i in x]
    else: r = None
    return r

# 01 | missing results
query['missing'] = query['result'].isna()

print('\nMissing results: ')
print(query['missing'].value_counts())

# 02 | raw extraction
query['result_raw'] = query['result'].apply(get_raw)
print('\nExtracted results: \n{}'.format(len(query['result_raw'].dropna())))

display(query)
# Out:
# Missing results:
# False    2488
# True     1378
# Name: missing, dtype: int64
#
# Extracted results:
# 2488
#                                        str_query_A  \
# 0     South Kivu, Democratic Republic of the Congo
# 1                                 Zimmerman, Kenya
# 2                                     Aidan, Ghana
# 3                                   Nyegiti, Kenya
# 4                                  Buchinga, Kenya
# ...                                            ...
# 3861                                Nkwakwa, Ghana
# 3862                                Wangige, Kenya
# 3863                            Amusing Naa, Ghana
# 3864                               Dansoman, Ghana
# 3865                                 Mayera, Ghana
#
#                                                  result  missing  \
# 0     [(Sud-Kivu, République démocratique du Congo, ...    False
# 1     [(Zimmerman, Nairobi, 00618, Kenya, (-1.210396...    False
# 2     [(Ayidan Landfil Site, Ga West Municipal Distr...    False
# 3                                                  None     True
# 4                                                  None     True
# ...                                                 ...      ...
# 3861                                               None     True
# 3862  [(Wangige, Kiambu, Central Kenya, P.O. BOX 307...    False
# 3863                                               None     True
# 3864  [(Dansoman, Accra, Ablekuma West Municipal Dis...    False
# 3865  [(Mayera DA Basic, Sampa - Berekum, Nwereme, J...    False
#
#                                              result_raw
# 0     [{'place_id': 51026579, 'licence': 'Data © Ope...
# 1     [{'place_id': 50567887, 'licence': 'Data © Ope...
# 2     [{'place_id': 254174023, 'licence': 'Data © Op...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 3861                                               None
# 3862  [{'place_id': 59189115, 'licence': 'Data © Ope...
# 3863                                               None
# 3864  [{'place_id': 317138, 'licence': 'Data © OpenS...
# 3865  [{'place_id': 78458900, 'licence': 'Data © Ope...
#
# [3866 rows x 4 columns]

# %% [markdown]
# ##### Generate a table of all results (multiple returned for single query)

# %%
tables = []

# using the indices of the valid results...
for i in list(query['result_raw'].dropna().index):
    # 01 | create a dataframe from the raw results
    ls = query['result_raw'][i]
    df = pd.DataFrame(ls)
    try:
        # 02 | convert the geojson result to geometry with shapely
        df['geometry'] = df['geojson'].apply(shape)
        df = df.set_geometry('geometry')
        # 03 | add reference to the query
        df['str_query_A'] = query['str_query_A'][i]
        # 04 | add the successful table to the list
        tables.append(df)
    except:
        print('Unable to create result table at index {}'.format(i))

print('\nNumber of successful result tables: {}'.format(len(tables)))

# 05 | Combine successful tables into a single table
table = pd.concat(tables)

# Export
table.to_csv('data_gen/gazetteer_geocoded/nominatim_results_A.csv')

# Preview
display(table)
# Out:
# Unable to create result table at index 60
# Unable to create result table at index 173
# Unable to create result table at index 319
# Unable to create result table at index 380
# Unable to create result table at index 913
# Unable to create result table at index 1086
# Unable to create result table at index 1518
# Unable to create result table at index 1585
# Unable to create result table at index 2146
# Unable to create result table at index 2234
# Unable to create result table at index 2465
# Unable to create result table at index 2884
# Unable to create result table at index 3301
# Unable to create result table at index 3343
# Unable to create result table at index 3481
# Unable to create result table at index 3568
#
# Number of successful result tables: 2472
#      place_id                                            licence  osm_type  \
# 0    51026579  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 1   258736587  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 0    50567887  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 0   254174023  Data © OpenStreetMap contributors, ODbL 1.0. h...       way
# 0      726501  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# ..        ...                                                ...       ...
# 1    59699839  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 2    58314385  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 0    78458900  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 1    57816474  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 2    57999595  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
#
#         osm_id                                       boundingbox          lat  \
# 0   4346319745  [-5.8653155, -0.6653155, 25.2705717, 30.4705717]   -3.2653155
# 1      5642699  [-5.0103229, -1.5834068, 26.8105741, 29.4359507]  -3.29689585
# 0   4194272132  [-1.2303969, -1.1903969, 36.8752212, 36.9152212]   -1.2103969
# 0    854265282    [5.7631208, 5.7685128, -0.4249518, -0.4188162]    5.7659029
# 0    262710046    [-28.626667, -28.546667, 31.358056, 31.438056]   -28.586667
# ..         ...                                               ...          ...
# 1   5287091325    [5.5564562, 5.5565562, -0.2701064, -0.2700064]    5.5565062
# 2   5087182231    [5.5623736, 5.5624736, -0.2730803, -0.2729803]    5.5624236
# 0   7248219885    [7.8640237, 7.8641237, -2.6814372, -2.6813372]    7.8640737
# 1   5024320817    [5.7261695, 5.7262695, -0.2765537, -0.2764537]    5.7262195
# 2   5024320814    [5.7355667, 5.7356667, -0.2719004, -0.2718004]    5.7356167
#
#                      lon                                       display_name  \
# 0             27.8705717         Sud-Kivu, République démocratique du Congo
# 1     28.167400763366775         Sud-Kivu, République démocratique du Congo
# 0             36.8952212                   Zimmerman, Nairobi, 00618, Kenya
# 0   -0.42259298126119743  Ayidan Landfil Site, Ga West Municipal Distric...
# 0              31.398056  Melmoth, Mthonjaneni Local Municipality, King ...
# ..                   ...                                                ...
# 1             -0.2700564  Evangelical Presbyterian Church, Ghana, Martei...
# 2             -0.2730303  Dansoman (SSNIT flats), Nsirewa Street, J7, Ot...
# 0             -2.6813872  Mayera DA Basic, Sampa - Berekum, Nwereme, Jam...
# 1             -0.2765037  Mayera Market, yehowa Da, Ga North Municipal D...
# 2             -0.2718504  Mayera/Adusa, yehowa Da, Ga North Municipal Di...
#
#        class              type  importance  \
# 0      place             state    0.750000
# 1   boundary    administrative    0.655702
# 0      place            suburb    0.495000
# 0    landuse          landfill    0.310000
# 0      place              town    0.577719
# ..       ...               ...         ...
# 1    amenity  place_of_worship    0.221000
# 2    highway          bus_stop    0.211000
# 0    amenity            school    0.211000
# 1    highway          bus_stop    0.211000
# 2    highway          bus_stop    0.211000
#
#                                               address  \
# 0   {'place': 'Sud-Kivu', 'country': 'République d...
# 1   {'state': 'Sud-Kivu', 'country': 'République d...
# 0   {'suburb': 'Zimmerman', 'city': 'Nairobi', 'st...
# 0   {'landuse': 'Ayidan Landfil Site', 'county': '...
# 0   {'town': 'Melmoth', 'city': 'Mthonjaneni Local...
# ..                                                ...
# 1   {'amenity': 'Evangelical Presbyterian Church, ...
# 2   {'highway': 'Dansoman (SSNIT flats)', 'road': ...
# 0   {'amenity': 'Mayera DA Basic', 'road': 'Sampa ...
# 1   {'highway': 'Mayera Market', 'road': 'yehowa D...
# 2   {'highway': 'Mayera/Adusa', 'road': 'yehowa Da...
#
#                                               geojson  \
# 0   {'type': 'Point', 'coordinates': [27.8705717, ...
# 1   {'type': 'Polygon', 'coordinates': [[[26.81057...
# 0   {'type': 'Point', 'coordinates': [36.8952212, ...
# 0   {'type': 'Polygon', 'coordinates': [[[-0.42495...
# 0   {'type': 'Point', 'coordinates': [31.398056, -...
# ..                                                ...
# 1   {'type': 'Point', 'coordinates': [-0.2700564, ...
# 2   {'type': 'Point', 'coordinates': [-0.2730303, ...
# 0   {'type': 'Point', 'coordinates': [-2.6813872, ...
# 1   {'type': 'Point', 'coordinates': [-0.2765037, ...
# 2   {'type': 'Point', 'coordinates': [-0.2718504, ...
#
#                                             extratags  \
# 0                   {'timezone': 'Africa/Lubumbashi'}
# 1   {'timezone': 'Africa/Lubumbashi', 'wikidata': ...
# 0                                                  {}
# 0                                                  {}
# 0   {'is_in': 'KwaZulu-Natal, South Africa', 'sagn...
# ..                                                ...
# 1                           {'religion': 'christian'}
# 2      {'bus': 'yes', 'public_transport': 'platform'}
# 0                                                  {}
# 1      {'bus': 'yes', 'public_transport': 'platform'}
# 2      {'bus': 'yes', 'public_transport': 'platform'}
#
#                                                  icon  \
# 0                                                 NaN
# 1   https://nominatim.openstreetmap.org/ui/mapicon...
# 0   https://nominatim.openstreetmap.org/ui/mapicon...
# 0                                                 NaN
# 0   https://nominatim.openstreetmap.org/ui/mapicon...
# ..                                                ...
# 1   https://nominatim.openstreetmap.org/ui/mapicon...
# 2   https://nominatim.openstreetmap.org/ui/mapicon...
# 0   https://nominatim.openstreetmap.org/ui/mapicon...
# 1   https://nominatim.openstreetmap.org/ui/mapicon...
# 2   https://nominatim.openstreetmap.org/ui/mapicon...
#
#                                              geometry  \
# 0                           POINT (27.87057 -3.26532)
# 1   POLYGON ((26.81057 -2.33906, 26.81065 -2.33984...
# 0                           POINT (36.89522 -1.21040)
# 0   POLYGON ((-0.42495 5.76312, -0.42363 5.76324, ...
# 0                          POINT (31.39806 -28.58667)
# ..                                                ...
# 1                            POINT (-0.27006 5.55651)
# 2                            POINT (-0.27303 5.56242)
# 0                            POINT (-2.68139 7.86407)
# 1                            POINT (-0.27650 5.72622)
# 2                            POINT (-0.27185 5.73562)
#
#                                      str_query_A
# 0   South Kivu, Democratic Republic of the Congo
# 1   South Kivu, Democratic Republic of the Congo
# 0                               Zimmerman, Kenya
# 0                                   Aidan, Ghana
# 0                          Melmoth, South Africa
# ..                                           ...
# 1                                Dansoman, Ghana
# 2                                Dansoman, Ghana
# 0                                  Mayera, Ghana
# 1                                  Mayera, Ghana
# 2                                  Mayera, Ghana
#
# [8478 rows x 17 columns]

# %% [markdown]
# ##### Add the results back to the gazetteer

# %%
# 01 | sort table so highest importance results is first
to_merge = table.sort_values('importance', ascending=False)

# 02 | drop duplicate rows, keeping first
to_merge = table.drop_duplicates(subset=['str_query_A'], keep='first')

# Diagnostics
print('Unique key to merge on?: {}'.format(to_merge['str_query_A'].is_unique))
display(to_merge.head(3))

# 03 | perform merge
queried = pd.merge(query, to_merge, on='str_query_A', how='left', validate = '1:1')
G_a = pd.merge(G, queried, on='str_query_A', how='left', validate = 'm:1')

# Diagnostics
print('Non-geocoded gazetteer entries:')
print(G_a['missing'].value_counts())

# Export
G_a.to_csv('data_gen/gazetteer_geocoded/gazetteer_geocoded.csv')

# Preview
display(G_a[['tuple_query', 'missing', 'lat', 'lon', 'geometry']].dropna())
# Out:
# Unique key to merge on?: True
#     place_id                                            licence osm_type  \
# 0   51026579  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
# 0   50567887  Data © OpenStreetMap contributors, ODbL 1.0. h...     node
# 0  254174023  Data © OpenStreetMap contributors, ODbL 1.0. h...      way
#
#        osm_id                                       boundingbox         lat  \
# 0  4346319745  [-5.8653155, -0.6653155, 25.2705717, 30.4705717]  -3.2653155
# 0  4194272132  [-1.2303969, -1.1903969, 36.8752212, 36.9152212]  -1.2103969
# 0   854265282    [5.7631208, 5.7685128, -0.4249518, -0.4188162]   5.7659029
#
#                     lon                                       display_name  \
# 0            27.8705717         Sud-Kivu, République démocratique du Congo
# 0            36.8952212                   Zimmerman, Nairobi, 00618, Kenya
# 0  -0.42259298126119743  Ayidan Landfil Site, Ga West Municipal Distric...
#
#      class      type  importance  \
# 0    place     state       0.750
# 0    place    suburb       0.495
# 0  landuse  landfill       0.310
#
#                                              address  \
# 0  {'place': 'Sud-Kivu', 'country': 'République d...
# 0  {'suburb': 'Zimmerman', 'city': 'Nairobi', 'st...
# 0  {'landuse': 'Ayidan Landfil Site', 'county': '...
#
#                                              geojson  \
# 0  {'type': 'Point', 'coordinates': [27.8705717, ...
# 0  {'type': 'Point', 'coordinates': [36.8952212, ...
# 0  {'type': 'Polygon', 'coordinates': [[[-0.42495...
#
#                            extratags  \
# 0  {'timezone': 'Africa/Lubumbashi'}
# 0                                 {}
# 0                                 {}
#
#                                                 icon  \
# 0                                                NaN
# 0  https://nominatim.openstreetmap.org/ui/mapicon...
# 0                                                NaN
#
#                                             geometry  \
# 0                          POINT (27.87057 -3.26532)
# 0                          POINT (36.89522 -1.21040)
# 0  POLYGON ((-0.42495 5.76312, -0.42363 5.76324, ...
#
#                                     str_query_A
# 0  South Kivu, Democratic Republic of the Congo
# 0                              Zimmerman, Kenya
# 0                                  Aidan, Ghana
# Non-geocoded gazetteer entries:
# False    5241
# True     1738
# Name: missing, dtype: int64
#                                             tuple_query missing         lat  \
# 5                                 (Accra, Accra, Ghana)   False   5.5571096
# 6                              (Achimota, Accra, Ghana)   False   5.6242019
# 7                                (Adenta, Accra, Ghana)   False   5.7041391
# 8                                (Adenta, Accra, Ghana)   False   5.7041391
# 9                                (Adenta, Accra, Ghana)   False   5.7041391
# ...                                                 ...     ...         ...
# 8926  (Washington, Washington, United States Of Amer...   False  38.8949924
# 8929              (Westminster, London, United Kingdom)   False  51.5004439
# 8930              (Westminster, London, United Kingdom)   False  51.5004439
# 8931  (Wilcox County, Georgia, United States Of Amer...   False   31.960784
# 8933                            (York, Toronto, Canada)   False  43.6896191
#
#               lon                                           geometry
# 5      -0.2012376  POLYGON ((-0.28413 5.57195, -0.28386 5.57090, ...
# 6      -0.2276807                           POINT (-0.22768 5.62420)
# 7      -0.1687965                           POINT (-0.16880 5.70414)
# 8      -0.1687965                           POINT (-0.16880 5.70414)
# 9      -0.1687965                           POINT (-0.16880 5.70414)
# ...           ...                                                ...
# 8926  -77.0365581  POLYGON ((-77.11979 38.93435, -77.11977 38.934...
# 8929   -0.1265398                          POINT (-0.12654 51.50044)
# 8930   -0.1265398                          POINT (-0.12654 51.50044)
# 8931  -83.4379708  POLYGON ((-83.61217 31.85394, -83.60108 31.853...
# 8933   -79.479188  POLYGON ((-79.53600 43.70480, -79.53591 43.704...
#
# [5206 rows x 5 columns]

# %% [markdown]
# ### 3.1.a. Querying for Method B: L1 + L2 + L3 (Back-ups)

# %%
missing = G_b[G_b.missing == True]
print('\nMissing Multilocations: \n{}'.format(len(missing['str_query_B'])))

to_query = missing['str_query_B'].dropna()
print('\nNon-NaN Queries (Method B): \n{}'.format(len(query)))

query = missing['str_query_B'].dropna().drop_duplicates()
print('\nUnique Queries (Method B): \n{}'.format(len(query)))

query = pd.DataFrame(query, columns=['str_query_B'])
query['result'] = None

display(query)
# Out:
# Missing Multilocations:
# 1738
#
# Non-NaN Queries (Method B):
# 3866
#
# Unique Queries (Method B):
# 1669
#                                    str_query_B result
# 18                     Ashabiena, Accra, Ghana   None
# 50         Ga Mantse Agbonaa, Jamestown, Ghana   None
# 269                Benin  Dagbo, Allada, Benin   None
# 276                      Dzefa, Cotonou, Benin   None
# 278                   Fidzrose, Cotonou, Benin   None
# ...                                        ...    ...
# 8818             Plumtree, Bulawayo, Zimbambwe   None
# 8845                 Saint Quen, Paris, France   None
# 8846                 Saint-Quen, Paris, France   None
# 8873                 Stugart, Stugart, Germany   None
# 8910  Umlazi, Durban, United States Of America   None
#
# [1669 rows x 2 columns]

# %%
# 01 - Create and instance of a Nominatim class
geocoder = Nominatim(user_agent = 'mtB')

# 02 - Rate limit to avoid timeout errors or being blocked by the API
geocode = RateLimiter(geocoder.geocode, min_delay_seconds=2, max_retries=2)

# CALL LOCATIONS FROM NOMINATIM
query['result'] = query['str_query_B'].apply(partial(geocode, exactly_one=0, addressdetails=1, extratags=1, geometry='geojson'))

# Back up the original query to avoid having to rerun the query
query_B_backup = query.copy()

# %%
# Get the raw attribute of the nominatim places result
def get_raw(x):
    if x is not None: r = [i.raw for i in x]
    else: r = None
    return r

# 01 | missing results
query['missing'] = query['result'].isna()

print('\nMissing results: ')
print(query['missing'].value_counts())

# 02 | raw extraction
query['result_raw'] = query['result'].apply(get_raw)
print('\nExtracted results: \n{}'.format(len(query['result_raw'].dropna())))

display(query)
# Out:
# Missing results:
# True     1667
# False       2
# Name: missing, dtype: int64
#
# Extracted results:
# 2
#                                    str_query_B result  missing result_raw
# 18                     Ashabiena, Accra, Ghana   None     True       None
# 50         Ga Mantse Agbonaa, Jamestown, Ghana   None     True       None
# 269                Benin  Dagbo, Allada, Benin   None     True       None
# 276                      Dzefa, Cotonou, Benin   None     True       None
# 278                   Fidzrose, Cotonou, Benin   None     True       None
# ...                                        ...    ...      ...        ...
# 8818             Plumtree, Bulawayo, Zimbambwe   None     True       None
# 8845                 Saint Quen, Paris, France   None     True       None
# 8846                 Saint-Quen, Paris, France   None     True       None
# 8873                 Stugart, Stugart, Germany   None     True       None
# 8910  Umlazi, Durban, United States Of America   None     True       None
#
# [1669 rows x 4 columns]

# %%
tables = []

# using the indices of the valid results...
for i in list(query['result_raw'].dropna().index):
    # 01 | create a dataframe from the raw results
    ls = query['result_raw'][i]
    df = pd.DataFrame(ls)
    try:
        # 02 | convert the geojson result to geometry with shapely
        df['geometry'] = df['geojson'].apply(shape)
        df = df.set_geometry('geometry')
        # 03 | add reference to the query
        df['str_query_B'] = query['str_query_B'][i]
        # 04 | add the successful table to the list
        tables.append(df)
    except:
        print('Unable to create result table at index {}'.format(i))

print('\nNumber of successful result tables: {}'.format(len(tables)))

# 05 | Combine successful tables into a single table
table = pd.concat(tables)

# Export
table.to_csv('data_gen/gazetteer_geocoded/nominatim_results_B.csv')

# Preview
display(table)

# %%
# 01 | sort table so highest importance results is first
to_merge = table.sort_values('importance', ascending=False)

# 02 | drop duplicate rows, keeping first
to_merge = table.drop_duplicates(subset=['str_query_B'], keep='first')

# Diagnostics
print('Unique key to merge on?: {}'.format(to_merge['str_query_B'].is_unique))
display(to_merge.head(3))

# 03 | perform merge
to_replace = pd.merge(to_query, to_merge, on='str_query_A', how='left')

display(to_replace)

# %%
nominatim_cols = \
['result', 'missing', 'result_raw', 'place_id', 'licence',
 'osm_type', 'osm_id', 'boundingbox', 'lat', 'lon', 'display_name',
 'class', 'type', 'importance', 'address', 'geojson', 'extratags',
 'icon', 'geometry']

# %% [markdown]
# ## 3.2. Add Data to the Survey Multilocations

# %% [markdown]
# ### 3.2.0. Load in datasets to merge together

# %% [markdown]
# ##### Function to evaluate as literals

# %%
# function to map over the string elements of the dataframe
def str_eval(e):
    """
    A function to evaluate string element in a dataframe literally, such as the multilocation tuples.
    
    RETURNS: The Python literal. 
    """
    # 01 | Ensure the element is read by ast.literal_eval() as a string to avoid errors.
    e = str(e)
    
    # 02 | Filter out any null values
    if ((e != 'nan') | (e != 'None')):
        
        # 03 | Evaluate the string literally
        try:
            ml = ast.literal_eval(e)
        
        # If unable to read the string, print it so it can be traced back to address issues
        except:
            ml = None
    
    # Return null values as null values
    else:
        ml = None
        
    return ml

# %% [markdown]
# ##### Geocoded Gazetteer

# %%
G_ = pd.read_csv('data_gen/gazetteer_geocoded/gazetteer_geocoded.csv')
G  = G_.copy()

print('Columns: ')
print(list(G.columns))

print('\nUnique original tuples: ')
print(G['tuple_orig'].is_unique)

G['tuple_orig'] = G['tuple_orig'].apply(str_eval)
G['tuple_query'] = G['tuple_query'].apply(str_eval)

G[['tuple_orig', 'tuple_query', 'lat', 'lon']]
# Out:
# Columns:
# ['Unnamed: 0', 'L1_orig', 'L2_orig', 'L3_orig', 'tuple_orig', 'L1_edit', 'L1_chg', 'L2_edit', 'L2_chg', 'L3_edit', 'L3_chg', 'L1_query', 'L2_query', 'L3_query', 'tuple_query', 'string_query', 'str_query_A', 'str_query_B', 'result', 'missing', 'result_raw', 'place_id', 'licence', 'osm_type', 'osm_id', 'boundingbox', 'lat', 'lon', 'display_name', 'class', 'type', 'importance', 'address', 'geojson', 'extratags', 'icon', 'geometry']
#
# Unique original tuples:
# True
#                                              tuple_orig  \
# 0                                          (-3, -1, -1)
# 1                                          (-1, -1, -1)
# 2                                          (46, -1, -1)
# 3                                          (99, -1, -1)
# 4                        (37 Military Hospital, -1, -1)
# ...                                                 ...
# 8930                          (Westminster, London, Uk)
# 8931                             (Wilcox, Georgia, Usa)
# 8932  (Would Wish To Move But Destination Still Unkn...
# 8933                               (York, York, Canada)
# 8934                                             (, , )
#
#                                             tuple_query        lat        lon
# 0                                                  None        NaN        NaN
# 1                                                  None        NaN        NaN
# 2                                                  None        NaN        NaN
# 3                                                  None        NaN        NaN
# 4                                                  None        NaN        NaN
# ...                                                 ...        ...        ...
# 8930              (Westminster, London, United Kingdom)  51.500444  -0.126540
# 8931  (Wilcox County, Georgia, United States Of Amer...  31.960784 -83.437971
# 8932                                               None        NaN        NaN
# 8933                            (York, Toronto, Canada)  43.689619 -79.479188
# 8934                                               None        NaN        NaN
#
# [8935 rows x 4 columns]

# %% [markdown]
# ##### Survey Multilocations

# %%
# csv of multilocations as tuples
mls_ = pd.read_csv('data_gen/survey_multilocations/survey_multilocations_tuples.csv')

# csv of multilocations as delimited string (alternative)
# mls_ = pd.read_csv('data_gen/survey_multilocations/survey_multilocations_string.csv')

mls = mls_.copy()
mls = mls.set_index('ID')
mls = mls.applymap(str_eval)

print('\nRows, Columns: {}'.format(mls.shape))
mls.head(3)
# Out:
# Rows, Columns: (1644, 44)
#          109                 127  \
# ID
# 276785  None                None
# 276788  None  ((N/A, N/A, N/A),)
# 276802  None                None
#
#                                                       134   142   152  \
# ID
# 276785  ((Kawango, Kisumu, Kenya), (Kawango, Kisumu, K...  None  None
# 276788                                 ((N/A, N/A, N/A),)  None  None
# 276802                         ((Awendo, Migori, Kenya),)  None  None
#
#                                                       201  \
# ID
# 276785                        ((Kawango, Kisumu, Kenya),)
# 276788                                               None
# 276802  ((Machakos, Machakos, Kenya), (Utawala, Nairob...
#
#                                                       202   206   211  214b  \
# ID
# 276785  ((Manyatta, Kisumu, Kenya), (Kawangware, Nairo...  None  None  None
# 276788                                               None  None  None  None
# 276802                                               None  None  None  None
#
#         ...                     100b                         101  \
# ID      ...
# 276785  ...  ((-1, Kawango, Kenya),)  ((Kisumu, Kisumu, Kenya),)
# 276788  ...    ((-1, Kokal, Kenya),)  ((Oyugis, Oyugis, Kenya),)
# 276802  ...   ((-1, Oyugjs, Kenya),)  ((Oyugis, Oyugis, Kenya),)
#
#                                  302                               308  \
# ID
# 276785       ((-3, Nairobi, Kenya),)           ((-3, Nairobi, Kenya),)
# 276788               ((-1, -1, -1),)                   ((-1, -1, -1),)
# 276802  ((Utawala, Nairobi, Kenya),)  ((Nairobi Cbd, Nairobi, Kenya),)
#
#                            229w                             229x  \
# ID
# 276785  ((-1, Nairobi, Kenya),)  ((Kawangware, Nairobi, Kenya),)
# 276788          ((-1, -1, -1),)                  ((-1, -1, -1),)
# 276802  ((-1, Nairobi, Kenya),)    ((Roysambu, Nairobi, Kenya),)
#
#                            229y                     229z  \
# ID
# 276785  ((-1, Nairobi, Kenya),)  ((-1, Nairobi, Kenya),)
# 276788          ((-1, -1, -1),)          ((-1, -1, -1),)
# 276802  ((-1, Nairobi, Kenya),)  ((-1, Nairobi, Kenya),)
#
#                                     231                      238
# ID
# 276785  ((Kawangware, Nairobi, Kenya),)  ((-1, Nairobi, Kenya),)
# 276788                  ((-1, -1, -1),)          ((-1, -1, -1),)
# 276802    ((Roysambu, Nairobi, Kenya),)  ((-1, Nairobi, Kenya),)
#
# [3 rows x 44 columns]

# %% [markdown]
# ### 3.2.1. Merge to create Geocoded Survey

# %% [markdown]
# ##### Functions to grab data from gazetteer and place into tuple multilocations

# %%
def grab_x(e, x):
    grabs = []
    for ml in e:
        grab = G.loc[G['tuple_orig'] == ml, x].item()
        grabs.append(grab)
    return grabs

def grab_clean(e):
    try:
        if e is not None:
            clean = grab_x(e, 'tuple_query')
            if any(clean):
                return tuple(list(clean))
            else:
                return None
        else:
            return None
    except:
        return None

def grab_ll(e):
    try:
        if e is not None:
            
            # grab the late and lon based on the old dataframe element
            lat = grab_x(e, 'lat')
            lon = grab_x(e, 'lon')
            
            # create tuples
            latlons = []
            for i in range(len(lat)):
                ls = [lat[i], lon[i]]
                t = tuple(ls)
                latlons.append(t)
            
            return tuple(latlons)
        else:
            return None
    except:
        return None

# %% [markdown]
# ##### Loop to place multilocations tuples into survey

# %%
mls_ll = mls.copy()

mls_cols = []

for col in list(mls_ll.columns):
    
    col_q = col + '_q'
    col_ll = col + '_ll'
    
    mls_ll[col_q] = mls_ll[col].apply(grab_clean)
    mls_ll[col_ll] = mls_ll[col].apply(grab_ll)
    
    mls_cols.append(col)
    mls_cols.append(col_q) 
    mls_cols.append(col_ll)
    
mls_ll = mls_ll[mls_cols]

mls_ll.to_csv('data_gen/survey_geocoded/survey_multilocations_geocoded.csv')

mls_ll
# Out:
#          109 109_q 109_ll                                                127  \
# ID
# 276785  None  None   None                                               None
# 276788  None  None   None                                 ((N/A, N/A, N/A),)
# 276802  None  None   None                                               None
# 276814  None  None   None  ((Nairobi, Nairobi, Kenya), (London, Nakuru, K...
# 276822  None  None   None                                               None
# ...      ...   ...    ...                                                ...
# 297661  None  None   None                                               None
# 297663  None  None   None  ((Sesambo, Lira City, Uganda), (Sesambo, Lirac...
# 297666  None  None   None                                       ((0, 0, 0),)
# 297667  None  None   None                                               None
# 297668  None  None   None                                       ((0, 0, 0),)
#
#                                                     127_q  \
# ID
# 276785                                               None
# 276788                                               None
# 276802                                               None
# 276814  ((Nairobi, Nairobi, Kenya), (London, Nakuru, K...
# 276822                                               None
# ...                                                   ...
# 297661                                               None
# 297663  ((Sesambo, Lira City, Uganda), (Sesambo, Lirac...
# 297666                                     ((0, 0, nan),)
# 297667                                               None
# 297668                                     ((0, 0, nan),)
#
#                                                    127_ll  \
# ID
# 276785                                               None
# 276788                                      ((nan, nan),)
# 276802                                               None
# 276814  ((-1.30316895, 36.826061224105075), (51.520665...
# 276822                                               None
# ...                                                   ...
# 297661                                               None
# 297663               ((nan, nan), (nan, nan), (nan, nan))
# 297666                                      ((nan, nan),)
# 297667                                               None
# 297668                                      ((nan, nan),)
#
#                                                       134  \
# ID
# 276785  ((Kawango, Kisumu, Kenya), (Kawango, Kisumu, K...
# 276788                                 ((N/A, N/A, N/A),)
# 276802                         ((Awendo, Migori, Kenya),)
# 276814                           ((Bondo, Siaya, Kenya),)
# 276822                              ((None, None, None),)
# ...                                                   ...
# 297661  ((Khongoloti, Khongoloti, Zimbabwe), (Khongolo...
# 297663  ((Khongoloti, Khongoloti, Zimbabwe), (Sesambo,...
# 297666  ((Lububamshi, Katsanga, Democratic Republic Of...
# 297667                                               None
# 297668                                               None
#
#                                                     134_q  \
# ID
# 276785  ((Kawango, Kisumu, Kenya), (Kawango, Kisumu, K...
# 276788                                               None
# 276802                         ((Awendo, Migori, Kenya),)
# 276814                           ((Bondo, Siaya, Kenya),)
# 276822                               ((None, None, nan),)
# ...                                                   ...
# 297661  ((Khongoloti, Khongoloti, Zimbabwe), (Khongolo...
# 297663  ((Khongoloti, Khongoloti, Zimbabwe), (Sesambo,...
# 297666  ((Lububamshi, Katsanga, Democratic Republic of...
# 297667                                               None
# 297668                                               None
#
#                                                    134_ll  \
# ID
# 276785  ((0.0, 31.983333000000002), (0.0, 31.983333000...
# 276788                                      ((nan, nan),)
# 276802                          ((-0.9079812, 34.53172),)
# 276814                        ((-0.0993654, 34.2739935),)
# 276822                                      ((nan, nan),)
# ...                                                   ...
# 297661  ((nan, nan), (nan, nan), (-26.1822222, 28.0533...
# 297663               ((nan, nan), (nan, nan), (nan, nan))
# 297666                                      ((nan, nan),)
# 297667                                               None
# 297668                                               None
#
#                                                       142  ...        229y_ll  \
# ID                                                         ...
# 276785                                               None  ...  ((nan, nan),)
# 276788                                               None  ...  ((nan, nan),)
# 276802                                               None  ...  ((nan, nan),)
# 276814                         ((Kisumu, Kisumu, Kenya),)  ...  ((nan, nan),)
# 276822                                               None  ...  ((nan, nan),)
# ...                                                   ...  ...            ...
# 297661  ((Khongoloti, Khongoloti, Khongoloti), (Khongo...  ...  ((nan, nan),)
# 297663                                               None  ...  ((nan, nan),)
# 297666  ((Katsanga, Katsanga, Democratic Republic Of T...  ...  ((nan, nan),)
# 297667                        ((Lusaka, Lusaka, Zambia),)  ...  ((nan, nan),)
# 297668  ((Cape Town, Cape Town, South Africa), (Cape T...  ...  ((nan, nan),)
#
#                                             229z  \
# ID
# 276785                   ((-1, Nairobi, Kenya),)
# 276788                           ((-1, -1, -1),)
# 276802                   ((-1, Nairobi, Kenya),)
# 276814                   ((-1, Nairobi, Kenya),)
# 276822                   ((-1, Nairobi, Kenya),)
# ...                                          ...
# 297661                           ((-1, -1, -1),)
# 297663    ((Berea, Johannesburg, South Africa),)
# 297666       ((-1, Johannesburg, South Africa),)
# 297667  ((Sandton, Johannesburg, South Africa),)
# 297668       ((-1, Johannesburg, South Africa),)
#
#                                           229z_q  \
# ID
# 276785                  ((nan, Nairobi, Kenya),)
# 276788                                      None
# 276802                  ((nan, Nairobi, Kenya),)
# 276814                  ((nan, Nairobi, Kenya),)
# 276822                  ((nan, Nairobi, Kenya),)
# ...                                          ...
# 297661                                      None
# 297663    ((Berea, Johannesburg, South Africa),)
# 297666      ((nan, Johannesburg, South Africa),)
# 297667  ((Sandton, Johannesburg, South Africa),)
# 297668      ((nan, Johannesburg, South Africa),)
#
#                                              229z_ll  \
# ID
# 276785                                 ((nan, nan),)
# 276788                                 ((nan, nan),)
# 276802                                 ((nan, nan),)
# 276814                                 ((nan, nan),)
# 276822                                 ((nan, nan),)
# ...                                              ...
# 297661                                 ((nan, nan),)
# 297663                  ((-26.1822222, 28.0533333),)
# 297666                                 ((nan, nan),)
# 297667  ((-26.068240600000003, 28.047984399999997),)
# 297668                                 ((nan, nan),)
#
#                                                       231  \
# ID
# 276785                    ((Kawangware, Nairobi, Kenya),)
# 276788                                    ((-1, -1, -1),)
# 276802                      ((Roysambu, Nairobi, Kenya),)
# 276814  ((Umoja, Nairobi, Kenya), (Tena, Nairobi, Kenya))
# 276822                      ((Buruburu, Nairobi, Kenya),)
# ...                                                   ...
# 297661                                    ((-1, -1, -1),)
# 297663  ((Uganda, Johannesburg, South Africa), (Berea,...
# 297666  ((Yeoville, Johannesburg, South Africa), (Bere...
# 297667  ((Sandton, Johannesburg, South Africa), (Berea...
# 297668             ((Berea, Johannesburg, South Africa),)
#
#                                                     231_q  \
# ID
# 276785                    ((Kawangware, Nairobi, Kenya),)
# 276788                                               None
# 276802                      ((Roysambu, Nairobi, Kenya),)
# 276814  ((Umoja, Nairobi, Kenya), (Tena, Nairobi, Kenya))
# 276822                      ((Buruburu, Nairobi, Kenya),)
# ...                                                   ...
# 297661                                               None
# 297663  ((Uganda, Johannesburg, South Africa), (Berea,...
# 297666  ((Yeoville, Johannesburg, South Africa), (Bere...
# 297667  ((Sandton, Johannesburg, South Africa), (Berea...
# 297668             ((Berea, Johannesburg, South Africa),)
#
#                                                    231_ll  \
# ID
# 276785                ((-1.2784631000000002, 36.751643),)
# 276788                                      ((nan, nan),)
# 276802        ((-1.2188396000000001, 36.88673920000001),)
# 276814  ((-1.2818728000000001, 36.899339700000006), (-...
# 276822                         ((-1.2841949, 36.868837),)
# ...                                                   ...
# 297661                                      ((nan, nan),)
# 297663  ((-26.041980499999998, 28.1591284), (-26.18222...
# 297666  ((-26.1838889, 28.0641667), (-26.1822222, 28.0...
# 297667  ((-26.068240600000003, 28.047984399999997), (-...
# 297668                       ((-26.1822222, 28.0533333),)
#
#                                                       238  \
# ID
# 276785                            ((-1, Nairobi, Kenya),)
# 276788                                    ((-1, -1, -1),)
# 276802                            ((-1, Nairobi, Kenya),)
# 276814  ((Nakuru, Nairobi, Kenya), (Kisumu, Nairobi, K...
# 276822                            ((-1, Nairobi, Kenya),)
# ...                                                   ...
# 297661                                    ((-1, -1, -1),)
# 297663                ((-1, Johannesburg, South Africa),)
# 297666  ((Yeoville, Johannesburg, South Africa), (Bloe...
# 297667           ((Sandton, Johannesburg, South Africa),)
# 297668       ((Khayelitsha, Johannesburg, South Africa),)
#
#                                                     238_q  \
# ID
# 276785                           ((nan, Nairobi, Kenya),)
# 276788                                               None
# 276802                           ((nan, Nairobi, Kenya),)
# 276814  ((Nakuru, Nairobi, Kenya), (Kisumu, Nairobi, K...
# 276822                           ((nan, Nairobi, Kenya),)
# ...                                                   ...
# 297661                                               None
# 297663               ((nan, Johannesburg, South Africa),)
# 297666  ((Yeoville, Johannesburg, South Africa), (Bloe...
# 297667           ((Sandton, Johannesburg, South Africa),)
# 297668       ((Khayelitsha, Johannesburg, South Africa),)
#
#                                                    238_ll
# ID
# 276785                                      ((nan, nan),)
# 276788                                      ((nan, nan),)
# 276802                                      ((nan, nan),)
# 276814  ((-0.28027240000000003, 36.0712048), (-0.10291...
# 276822                                      ((nan, nan),)
# ...                                                   ...
# 297661                                      ((nan, nan),)
# 297663                                      ((nan, nan),)
# 297666  ((-26.1838889, 28.0641667), (-29.116395, 26.21...
# 297667       ((-26.068240600000003, 28.047984399999997),)
# 297668                       ((-34.0405905, 18.6674201),)
#
# [1644 rows x 132 columns]
